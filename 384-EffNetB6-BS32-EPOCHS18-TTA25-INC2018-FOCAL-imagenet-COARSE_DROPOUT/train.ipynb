# %% [markdown]
# # Triple Stratified KFold CV with TFRecords
# This is a simple starter notebook for Kaggle's Melanoma Comp showing triple stratifed KFold with TFRecords. Triple stratified KFold is explained [here][2]. There are many configuration variables below to allow you to experiment. Use either GPU or TPU. You can control which size images are loaded, which efficientNets are used, and whether external data is used. You can experiment with different data augmentation, model architecture, loss, optimizers, and learning schedules. The TFRecords contain meta data, so you can input that into your CNN too.
#
# **NOTE:** this notebook lets you run a different experiment in each fold if you want to run lots of experiments. (Then it is like running multiple holdout validaiton experiments but in that case note that the overall CV score is meaningless because LB will be much higher when the multiple experiments are ensembled to predict test). **If you want a proper CV with a reliable overall CV score you need to choose the same configuration for each fold.**
#
# This notebook follows the 5 step process presented in my "How to compete with GPUs Workshop" [here][1]. Some code sections have been reused from AgentAuers' great notebook [here][3]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/gdrive/My Drive/Kaggle/kaggle.json" ~/.kaggle

# %%
# install tf 2.2 following kaggle post instructions

# !pip install tensorflow~=2.2.0 tensorflow_gcs_config~=2.2.0
import tensorflow as tf
import requests
import os
resp = requests.post("http://{}:8475/requestversion/{}".format(os.environ["COLAB_TPU_ADDR"].split(":")[0], tf.__version__))
if resp.status_code != 200:
  print("Failed to switch the TPU to TF {}".format(version))
# Out:
# Collecting tensorflow~=2.2.0
#   Downloading https://files.pythonhosted.org/packages/3d/be/679ce5254a8c8d07470efb4a4c00345fae91f766e64f1c2aece8796d7218/tensorflow-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████████████████████████| 516.2MB 25kB/s
# Collecting tensorflow_gcs_config~=2.2.0
#   Downloading https://files.pythonhosted.org/packages/67/0b/c6fe9b75ba3999c10b7ab77e7d4019c90344bb79609a9378355ca6712598/tensorflow_gcs_config-2.2.0-py3-none-any.whl (392kB)
#      |████████████████████████████████| 399kB 52.8MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.9.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.4.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.1.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.18.5)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/a4/f5/926ae53d6a226ec0fda5208e0e581cffed895ccc89e36ba76a8e60895b78/tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454kB)
#      |████████████████████████████████| 460kB 64.2MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (3.12.4)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.30.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.6.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.34.2)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 58.5MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow~=2.2.0) (49.2.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.7.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.24.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.1.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow, tensorflow-gcs-config
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
#   Found existing installation: tensorflow-gcs-config 2.3.0
#     Uninstalling tensorflow-gcs-config-2.3.0:
#       Successfully uninstalled tensorflow-gcs-config-2.3.0
# Successfully installed tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0 tensorflow-gcs-config-2.2.0

# %% [markdown]
# # Initialize Environment

# %%
# !pip install -q efficientnet >> /dev/null

# %%
import cv2, matplotlib.pyplot as plt
import gc
import pandas as pd, numpy as np
#from kaggle_datasets import KaggleDatasets
import tensorflow as tf, re, math
import tensorflow.keras.backend as K
import efficientnet.tfkeras as efn
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Configuration
# In order to be a proper cross validation with a meaningful overall CV score (aligned with LB score), **you need to choose the same** `IMG_SIZES`, `INC2019`, `INC2018`, and `EFF_NETS` **for each fold**. If your goal is to just run lots of experiments, then you can choose to have a different experiment in each fold. Then each fold is like a holdout validation experiment. When you find a configuration you like, you can use that configuration for all folds.
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 but can be any number between 2 and 15
# * IMG_SIZES - is a Python list of length FOLDS. These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - is a list of length FOLDS. These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - is a list of length FOLDS. These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter.
# * EFF_NETS - is a list of length FOLDS. These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %%
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 42

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 
IMG_SIZES =  [512,512,512,512,512]
IMG_SIZES = [384,384,384,384,384]

# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0,0,0,0,0]
INC2018 = [1,1,1,1,1]

# BATCH SIZE AND EPOCHS
BATCH_SIZES = [32]*FOLDS #[32]*FOLDS
EPOCHS = [18]*FOLDS #12 18

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [7,7,7,7,7]
EFF_NETS = [3,3,3,3,3]
EFF_NETS = [6,6,6,6,6]


DROP_FREQ = [0.75] * FOLDS # between 0 and 1
DROP_CT = [8] * FOLDS # may slow training if CT>16
DROP_SIZE = [0.2] *FOLDS # between 0 and 1

EFF_NET_PRETRAIN = 'imagenet' #''noisy-student

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 25

#Treure de Kaggle
if IMG_SIZES[0]==384:
  #384 images
  GCS1="gs://kds-71b679af6661316328cfa122f5342b4a84fe0c7c1135d809fbee8ca4" #384
  GCS2="gs://kds-9fc526a7f92f5454bc790655a916878883ad270d1e13c91e7d527659"#384
elif IMG_SIZES[0]==512:
  #512
  GCS1 = 'gs://kds-df537acf009e02b1d4427274d18970a1b0101b1ca26824bae39b5b4b'
  GCS2 = 'gs://kds-25423645f76650f9220fbd3613366c3c5a524b3a7d7663b6e3137c57'
  
  

else:
  raise error

MODEL = f'{IMG_SIZES[0]}-EffNetB{EFF_NETS[0]}-BS{BATCH_SIZES[0]}-EPOCHS{EPOCHS[0]}-TTA{TTA}-INC2018-FOCAL-{EFF_NET_PRETRAIN}-COARSE_DROPOUT'
print(MODEL)
# Out:
# 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT

# %%
import os
if not os.path.exists(f'/content/{MODEL}'):
    os.mkdir(f'/content/{MODEL}')

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and single GPU")
    strategy = tf.distribute.get_strategy()

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
# Out:
# connecting to TPU...
# Running on TPU  grpc://10.60.21.202:8470
# initializing  TPU ...
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# TPU initialized

# %% [markdown]
# # Step 1: Preprocess
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section. These TFRecords are discussed [here][1]. The advantage of using different input sizes is discussed [here][2]
#
# [1]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/155579
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147

# %%
GCS_PATH = [None]*FOLDS; GCS_PATH2 = [None]*FOLDS

for i,k in enumerate(IMG_SIZES):
    GCS_PATH[i] = GCS1
    GCS_PATH2[i] = GCS2

files_train = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/train*.tfrec')))
files_test  = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/test*.tfrec')))

# %% [markdown]
# # Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation first shown in this notebook [here][1] and successfully used in Melanoma comp by AgentAuers [here][2]. This notebook also uses horizontal flip, hue, saturation, contrast, brightness augmentation similar to last years winner and also similar to AgentAuers' notebook.
#
# Additionally we can decide to use external data by changing the variables `INC2019` and `INC2018` in the preceeding code section. These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][3]
#
# Consider experimenting with different augmenation and/or external data. The code to load TFRecords is taken from AgentAuers' notebook [here][2]. Thank you AgentAuers, this is great work.
#
# [1]: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
# [2]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [3]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %%
ROT_ = 180.0 #90.0 al submit anterior
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def dropout(image, DIM=256, PROBABILITY = 0.75, CT = 8, SZ = 0.2):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image with CT squares of side size SZ*DIM removed
    
    # DO DROPOUT WITH PROBABILITY DEFINED ABOVE
    P = tf.cast( tf.random.uniform([],0,1)<PROBABILITY, tf.int32)
    if (P==0)|(CT==0)|(SZ==0): return image
    
    for k in range(CT):
        # CHOOSE RANDOM LOCATION
        x = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        y = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        # COMPUTE SQUARE 
        WIDTH = tf.cast( SZ*DIM,tf.int32) * P
        ya = tf.math.maximum(0,y-WIDTH//2)
        yb = tf.math.minimum(DIM,y+WIDTH//2)
        xa = tf.math.maximum(0,x-WIDTH//2)
        xb = tf.math.minimum(DIM,x+WIDTH//2)
        # DROPOUT IMAGE
        one = image[ya:yb,0:xa,:]
        # two = tf.zeros([yb-ya,xb-xa,3],tf.bfloat16) 
        two = tf.zeros([yb-ya,xb-xa,3])
        three = image[ya:yb,xb:DIM,:]
        middle = tf.concat([one,two,three],axis=1)
        image = tf.concat([image[0:ya,:,:],middle,image[yb:DIM,:,:]],axis=0)
            
    # RESHAPE HACK SO TPU COMPILER KNOWS SHAPE OF OUTPUT TENSOR 
    image = tf.reshape(image,[DIM,DIM,3])
    return image

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

# %%
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    #return example['image'], example['target']
    return example['image'], tf.cast(example['target'],tf.float32)
    # return example['image'], tf.cast(example['target'],tf.bfloat16)


def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

 
def prepare_image(img, augment=True, dim=256, droprate=0, dropct=0, dropsize=0):    
    img = tf.image.decode_jpeg(img, channels=3)
    # img = tf.cast(img, tf.bfloat16) / 255.0
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        if (droprate!=0)&(dropct!=0)&(dropsize!=0): 
            img = dropout(img, DIM=dim, PROBABILITY=droprate, CT=dropct, SZ=dropsize)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)

    # img = tf.cast(img, tf.bfloat16)              
    img = tf.reshape(img, [dim,dim, 3])
        
    return img

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256,
                droprate=0, dropct=0, dropsize=0):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*2) #if too large causes OOM in GPU CPU
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO)      
    
    ds = ds.map(lambda img, imgname_or_label: (
                prepare_image(img, augment=augment, dim=dim, 
                              droprate=droprate, dropct=dropct, dropsize=dropsize), 
                imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %% [markdown]
# # Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN.

# %%
import tensorflow_addons as tfa

EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7, efn.EfficientNetL2]

def build_model(dim=128, ef=0):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EFNS[ef](input_shape=(dim,dim,3),weights=EFF_NET_PRETRAIN,include_top=False)
    #base.trainable = True
    #print(base.trainable)
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    # loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    loss = tfa.losses.SigmoidFocalCrossEntropy()
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    return model

# %% [markdown]
# # Step 4: Train Schedule
# This is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
lr_start   = 0.000005
lr_max     = 0.00000125 * REPLICAS * BATCH_SIZES[0]
lr_min     = 0.000001
lr_ramp_ep = 5
lr_sus_ep  = 0
lr_decay   = 0.8

def lrfn(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        
    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max
        
    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
        
    return lr


rng = [i for i in range(EPOCHS[0])]
y = [lrfn(x) for x in rng]
plt.plot(rng, [lrfn(x) for x in rng])
print(y[0], y[-1])
# Out:
# 5e-06 2.2921513078784015e-05

# %%
def get_lr_callback(batch_size=8):
    lr_start   = 0.000005
    lr_max     = 0.00000125 * REPLICAS * batch_size
    lr_min     = 0.000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback

# %% [markdown]
# ## Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []; oof_tar = []; oof_val = []; oof_names = []; oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_by_fold = np.empty([count_data_items(files_test), FOLDS], dtype=float)

for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25); print('#### FOLD',fold+1)
    print('#### Image Size %i with EfficientNet B%i and batch_size %i'%
          (IMG_SIZES[fold],EFF_NETS[fold],BATCH_SIZES[fold]*REPLICAS))
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[fold] + '/test*.tfrec')))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold])
        
    # SAVE BEST MODEL EACH FOLD
    checkpoint_file = f'{MODEL}/fold-%i-bestAUC.h5'%fold
    sv = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    checkpoint_file = f'{MODEL}/fold-%i-bestloss.h5'%fold
    sv2 = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold],
                droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]), 
        epochs=EPOCHS[fold], callbacks = [sv,sv2,get_lr_callback(BATCH_SIZES[fold])], 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid,augment=False,shuffle=False,
                repeat=False,dim=IMG_SIZES[fold], batch_size=BATCH_SIZES[fold]), #class_weight = {0:1,1:2},
        verbose=VERBOSE
    )
    
    print('Loading best model val loss...')
    model.load_weights(checkpoint_file)

    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold],
            droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    #oof_pred.append(model.predict(get_dataset(files_valid,dim=IMG_SIZES[fold]),verbose=1))

    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))

    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold],
            droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,] 
    tta_mean = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += tta_mean * WGTS[fold]
    #new

    preds_by_fold[:,fold] = tta_mean


    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print('#### FOLD %i OOF AUC without TTA = %.3f, with TTA = %.3f'%(fold+1,oof_val[-1],auc))
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] ); y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold]),size=18)
        plt.legend(loc=3)
        plt.show()
        #break
      
    del model
    z = gc.collect()
# Out:
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 1
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0868 - auc: 0.6217WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.58813, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05550, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 207s 1s/step - loss: 0.0868 - auc: 0.6217 - val_loss: 0.0555 - val_auc: 0.5881 - lr: 5.0000e-06
# Epoch 2/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0174 - auc: 0.7658
# Epoch 00002: val_auc improved from 0.58813 to 0.81996, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05550 to 0.00747, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0174 - auc: 0.7658 - val_loss: 0.0075 - val_auc: 0.8200 - lr: 6.8000e-05
# Epoch 3/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0146 - auc: 0.8525
# Epoch 00003: val_auc improved from 0.81996 to 0.86987, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00747 to 0.00687, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0146 - auc: 0.8525 - val_loss: 0.0069 - val_auc: 0.8699 - lr: 1.3100e-04
# Epoch 4/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0137 - auc: 0.8810
# Epoch 00004: val_auc improved from 0.86987 to 0.89351, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00687 to 0.00675, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0137 - auc: 0.8810 - val_loss: 0.0068 - val_auc: 0.8935 - lr: 1.9400e-04
# Epoch 5/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0132 - auc: 0.8953
# Epoch 00005: val_auc improved from 0.89351 to 0.90447, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00675 to 0.00653, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0132 - auc: 0.8953 - val_loss: 0.0065 - val_auc: 0.9045 - lr: 2.5700e-04
# Epoch 6/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0126 - auc: 0.9024
# Epoch 00006: val_auc improved from 0.90447 to 0.91161, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00653 to 0.00622, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0126 - auc: 0.9024 - val_loss: 0.0062 - val_auc: 0.9116 - lr: 3.2000e-04
# Epoch 7/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0118 - auc: 0.9224
# Epoch 00007: val_auc did not improve from 0.91161
#
# Epoch 00007: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0118 - auc: 0.9224 - val_loss: 0.0082 - val_auc: 0.9076 - lr: 2.5620e-04
# Epoch 8/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0113 - auc: 0.9314
# Epoch 00008: val_auc improved from 0.91161 to 0.91881, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00622
# 142/142 [==============================] - 173s 1s/step - loss: 0.0113 - auc: 0.9314 - val_loss: 0.0063 - val_auc: 0.9188 - lr: 2.0516e-04
# Epoch 9/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0106 - auc: 0.9405
# Epoch 00009: val_auc did not improve from 0.91881
#
# Epoch 00009: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0106 - auc: 0.9405 - val_loss: 0.0062 - val_auc: 0.9151 - lr: 1.6433e-04
# Epoch 10/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9467
# Epoch 00010: val_auc improved from 0.91881 to 0.92150, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00622 to 0.00602, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0103 - auc: 0.9467 - val_loss: 0.0060 - val_auc: 0.9215 - lr: 1.3166e-04
# Epoch 11/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0098 - auc: 0.9520
# Epoch 00011: val_auc improved from 0.92150 to 0.92599, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00011: val_loss did not improve from 0.00602
# 142/142 [==============================] - 172s 1s/step - loss: 0.0098 - auc: 0.9520 - val_loss: 0.0063 - val_auc: 0.9260 - lr: 1.0553e-04
# Epoch 12/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0091 - auc: 0.9576
# Epoch 00012: val_auc did not improve from 0.92599
#
# Epoch 00012: val_loss did not improve from 0.00602
# 142/142 [==============================] - 169s 1s/step - loss: 0.0091 - auc: 0.9576 - val_loss: 0.0061 - val_auc: 0.9241 - lr: 8.4624e-05
# Epoch 13/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0089 - auc: 0.9620
# Epoch 00013: val_auc improved from 0.92599 to 0.92846, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00013: val_loss improved from 0.00602 to 0.00598, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0089 - auc: 0.9620 - val_loss: 0.0060 - val_auc: 0.9285 - lr: 6.7899e-05
# Epoch 14/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0086 - auc: 0.9652
# Epoch 00014: val_auc did not improve from 0.92846
#
# Epoch 00014: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0086 - auc: 0.9652 - val_loss: 0.0060 - val_auc: 0.9255 - lr: 5.4519e-05
# Epoch 15/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9669
# Epoch 00015: val_auc did not improve from 0.92846
#
# Epoch 00015: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0083 - auc: 0.9669 - val_loss: 0.0061 - val_auc: 0.9249 - lr: 4.3815e-05
# Epoch 16/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0079 - auc: 0.9703
# Epoch 00016: val_auc improved from 0.92846 to 0.92916, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00016: val_loss did not improve from 0.00598
# 142/142 [==============================] - 172s 1s/step - loss: 0.0079 - auc: 0.9703 - val_loss: 0.0061 - val_auc: 0.9292 - lr: 3.5252e-05
# Epoch 17/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0078 - auc: 0.9722
# Epoch 00017: val_auc did not improve from 0.92916
#
# Epoch 00017: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0078 - auc: 0.9722 - val_loss: 0.0062 - val_auc: 0.9265 - lr: 2.8402e-05
# Epoch 18/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0079 - auc: 0.9715
# Epoch 00018: val_auc did not improve from 0.92916
#
# Epoch 00018: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0079 - auc: 0.9715 - val_loss: 0.0062 - val_auc: 0.9270 - lr: 2.2922e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 639/638 [==============================] - 172s 269ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 290s 271ms/step
# #### FOLD 1 OOF AUC without TTA = 0.929, with TTA = 0.935
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 2
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0900 - auc: 0.5693WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.65671, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.09095, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 142/142 [==============================] - 206s 1s/step - loss: 0.0900 - auc: 0.5693 - val_loss: 0.0909 - val_auc: 0.6567 - lr: 5.0000e-06
# Epoch 2/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0179 - auc: 0.7489
# Epoch 00002: val_auc improved from 0.65671 to 0.80998, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.09095 to 0.00782, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0179 - auc: 0.7489 - val_loss: 0.0078 - val_auc: 0.8100 - lr: 6.8000e-05
# Epoch 3/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0146 - auc: 0.8592
# Epoch 00003: val_auc improved from 0.80998 to 0.84525, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00782 to 0.00724, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0146 - auc: 0.8592 - val_loss: 0.0072 - val_auc: 0.8453 - lr: 1.3100e-04
# Epoch 4/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0134 - auc: 0.8880
# Epoch 00004: val_auc improved from 0.84525 to 0.86043, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00724 to 0.00709, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0134 - auc: 0.8880 - val_loss: 0.0071 - val_auc: 0.8604 - lr: 1.9400e-04
# Epoch 5/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0128 - auc: 0.9031
# Epoch 00005: val_auc improved from 0.86043 to 0.89577, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00709 to 0.00646, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0128 - auc: 0.9031 - val_loss: 0.0065 - val_auc: 0.8958 - lr: 2.5700e-04
# Epoch 6/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0123 - auc: 0.9121
# Epoch 00006: val_auc did not improve from 0.89577
#
# Epoch 00006: val_loss did not improve from 0.00646
# 142/142 [==============================] - 169s 1s/step - loss: 0.0123 - auc: 0.9121 - val_loss: 0.0068 - val_auc: 0.8596 - lr: 3.2000e-04
# Epoch 7/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0115 - auc: 0.9289
# Epoch 00007: val_auc did not improve from 0.89577
#
# Epoch 00007: val_loss did not improve from 0.00646
# 142/142 [==============================] - 169s 1s/step - loss: 0.0115 - auc: 0.9289 - val_loss: 0.0068 - val_auc: 0.8684 - lr: 2.5620e-04
# Epoch 8/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0108 - auc: 0.9401
# Epoch 00008: val_auc improved from 0.89577 to 0.90240, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00646
# 142/142 [==============================] - 173s 1s/step - loss: 0.0108 - auc: 0.9401 - val_loss: 0.0067 - val_auc: 0.9024 - lr: 2.0516e-04
# Epoch 9/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0104 - auc: 0.9433
# Epoch 00009: val_auc improved from 0.90240 to 0.91848, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00646 to 0.00598, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0104 - auc: 0.9433 - val_loss: 0.0060 - val_auc: 0.9185 - lr: 1.6433e-04
# Epoch 10/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0099 - auc: 0.9506
# Epoch 00010: val_auc did not improve from 0.91848
#
# Epoch 00010: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0099 - auc: 0.9506 - val_loss: 0.0061 - val_auc: 0.9138 - lr: 1.3166e-04
# Epoch 11/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0095 - auc: 0.9552
# Epoch 00011: val_auc did not improve from 0.91848
#
# Epoch 00011: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0095 - auc: 0.9552 - val_loss: 0.0065 - val_auc: 0.9123 - lr: 1.0553e-04
# Epoch 12/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0089 - auc: 0.9626
# Epoch 00012: val_auc did not improve from 0.91848
#
# Epoch 00012: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0089 - auc: 0.9626 - val_loss: 0.0066 - val_auc: 0.8972 - lr: 8.4624e-05
# Epoch 13/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9631
# Epoch 00013: val_auc did not improve from 0.91848
#
# Epoch 00013: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0087 - auc: 0.9631 - val_loss: 0.0065 - val_auc: 0.9003 - lr: 6.7899e-05
# Epoch 14/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0085 - auc: 0.9662
# Epoch 00014: val_auc did not improve from 0.91848
#
# Epoch 00014: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0085 - auc: 0.9662 - val_loss: 0.0067 - val_auc: 0.9007 - lr: 5.4519e-05
# Epoch 15/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9670
# Epoch 00015: val_auc did not improve from 0.91848
#
# Epoch 00015: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0084 - auc: 0.9670 - val_loss: 0.0067 - val_auc: 0.9057 - lr: 4.3815e-05
# Epoch 16/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0078 - auc: 0.9721
# Epoch 00016: val_auc did not improve from 0.91848
#
# Epoch 00016: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0078 - auc: 0.9721 - val_loss: 0.0069 - val_auc: 0.9009 - lr: 3.5252e-05
# Epoch 17/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0078 - auc: 0.9722
# Epoch 00017: val_auc did not improve from 0.91848
#
# Epoch 00017: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0078 - auc: 0.9722 - val_loss: 0.0068 - val_auc: 0.9010 - lr: 2.8402e-05
# Epoch 18/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9707
# Epoch 00018: val_auc did not improve from 0.91848
#
# Epoch 00018: val_loss did not improve from 0.00598
# 142/142 [==============================] - 169s 1s/step - loss: 0.0080 - auc: 0.9707 - val_loss: 0.0068 - val_auc: 0.8971 - lr: 2.2922e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 639/638 [==============================] - 174s 272ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 293s 273ms/step
# #### FOLD 2 OOF AUC without TTA = 0.918, with TTA = 0.922
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 3
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0876 - auc: 0.6001WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.67031, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05447, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 206s 1s/step - loss: 0.0876 - auc: 0.6001 - val_loss: 0.0545 - val_auc: 0.6703 - lr: 5.0000e-06
# Epoch 2/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0179 - auc: 0.7464
# Epoch 00002: val_auc improved from 0.67031 to 0.83853, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05447 to 0.00709, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0179 - auc: 0.7464 - val_loss: 0.0071 - val_auc: 0.8385 - lr: 6.8000e-05
# Epoch 3/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0145 - auc: 0.8584
# Epoch 00003: val_auc improved from 0.83853 to 0.87767, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00709 to 0.00659, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0145 - auc: 0.8584 - val_loss: 0.0066 - val_auc: 0.8777 - lr: 1.3100e-04
# Epoch 4/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0137 - auc: 0.8821
# Epoch 00004: val_auc improved from 0.87767 to 0.90744, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00659 to 0.00654, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0137 - auc: 0.8821 - val_loss: 0.0065 - val_auc: 0.9074 - lr: 1.9400e-04
# Epoch 5/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0129 - auc: 0.8980
# Epoch 00005: val_auc improved from 0.90744 to 0.91958, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00654 to 0.00601, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0129 - auc: 0.8980 - val_loss: 0.0060 - val_auc: 0.9196 - lr: 2.5700e-04
# Epoch 6/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0127 - auc: 0.9051
# Epoch 00006: val_auc improved from 0.91958 to 0.92828, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00601 to 0.00576, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0127 - auc: 0.9051 - val_loss: 0.0058 - val_auc: 0.9283 - lr: 3.2000e-04
# Epoch 7/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0118 - auc: 0.9221
# Epoch 00007: val_auc improved from 0.92828 to 0.93309, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00576
# 142/142 [==============================] - 173s 1s/step - loss: 0.0118 - auc: 0.9221 - val_loss: 0.0061 - val_auc: 0.9331 - lr: 2.5620e-04
# Epoch 8/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0112 - auc: 0.9324
# Epoch 00008: val_auc improved from 0.93309 to 0.93890, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.00576 to 0.00561, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0112 - auc: 0.9324 - val_loss: 0.0056 - val_auc: 0.9389 - lr: 2.0516e-04
# Epoch 9/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0107 - auc: 0.9384
# Epoch 00009: val_auc improved from 0.93890 to 0.94112, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00561 to 0.00541, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0107 - auc: 0.9384 - val_loss: 0.0054 - val_auc: 0.9411 - lr: 1.6433e-04
# Epoch 10/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0101 - auc: 0.9480
# Epoch 00010: val_auc improved from 0.94112 to 0.94530, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00010: val_loss did not improve from 0.00541
# 142/142 [==============================] - 173s 1s/step - loss: 0.0101 - auc: 0.9480 - val_loss: 0.0055 - val_auc: 0.9453 - lr: 1.3166e-04
# Epoch 11/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0097 - auc: 0.9521
# Epoch 00011: val_auc improved from 0.94530 to 0.94787, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00011: val_loss improved from 0.00541 to 0.00539, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0097 - auc: 0.9521 - val_loss: 0.0054 - val_auc: 0.9479 - lr: 1.0553e-04
# Epoch 12/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0093 - auc: 0.9579
# Epoch 00012: val_auc improved from 0.94787 to 0.94984, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00012: val_loss improved from 0.00539 to 0.00520, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0093 - auc: 0.9579 - val_loss: 0.0052 - val_auc: 0.9498 - lr: 8.4624e-05
# Epoch 13/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9623
# Epoch 00013: val_auc did not improve from 0.94984
#
# Epoch 00013: val_loss did not improve from 0.00520
# 142/142 [==============================] - 169s 1s/step - loss: 0.0090 - auc: 0.9623 - val_loss: 0.0052 - val_auc: 0.9468 - lr: 6.7899e-05
# Epoch 14/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9653
# Epoch 00014: val_auc did not improve from 0.94984
#
# Epoch 00014: val_loss did not improve from 0.00520
# 142/142 [==============================] - 169s 1s/step - loss: 0.0087 - auc: 0.9653 - val_loss: 0.0053 - val_auc: 0.9498 - lr: 5.4519e-05
# Epoch 15/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0086 - auc: 0.9642
# Epoch 00015: val_auc did not improve from 0.94984
#
# Epoch 00015: val_loss did not improve from 0.00520
# 142/142 [==============================] - 169s 1s/step - loss: 0.0086 - auc: 0.9642 - val_loss: 0.0053 - val_auc: 0.9490 - lr: 4.3815e-05
# Epoch 16/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9688
# Epoch 00016: val_auc did not improve from 0.94984
#
# Epoch 00016: val_loss did not improve from 0.00520
# 142/142 [==============================] - 170s 1s/step - loss: 0.0081 - auc: 0.9688 - val_loss: 0.0054 - val_auc: 0.9469 - lr: 3.5252e-05
# Epoch 17/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0082 - auc: 0.9692
# Epoch 00017: val_auc did not improve from 0.94984
#
# Epoch 00017: val_loss did not improve from 0.00520
# 142/142 [==============================] - 170s 1s/step - loss: 0.0082 - auc: 0.9692 - val_loss: 0.0053 - val_auc: 0.9457 - lr: 2.8402e-05
# Epoch 18/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9709
# Epoch 00018: val_auc did not improve from 0.94984
#
# Epoch 00018: val_loss did not improve from 0.00520
# 142/142 [==============================] - 170s 1s/step - loss: 0.0080 - auc: 0.9709 - val_loss: 0.0054 - val_auc: 0.9454 - lr: 2.2922e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 640/639 [==============================] - 174s 272ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 294s 274ms/step
# #### FOLD 3 OOF AUC without TTA = 0.950, with TTA = 0.955
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 4
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0920 - auc: 0.6120WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.58500, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05570, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 142/142 [==============================] - 206s 1s/step - loss: 0.0920 - auc: 0.6120 - val_loss: 0.0557 - val_auc: 0.5850 - lr: 5.0000e-06
# Epoch 2/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0178 - auc: 0.7497
# Epoch 00002: val_auc improved from 0.58500 to 0.81463, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05570 to 0.00732, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 142/142 [==============================] - 181s 1s/step - loss: 0.0178 - auc: 0.7497 - val_loss: 0.0073 - val_auc: 0.8146 - lr: 6.8000e-05
# Epoch 3/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0144 - auc: 0.8606
# Epoch 00003: val_auc improved from 0.81463 to 0.86440, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00732 to 0.00685, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0144 - auc: 0.8606 - val_loss: 0.0068 - val_auc: 0.8644 - lr: 1.3100e-04
# Epoch 4/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0135 - auc: 0.8831
# Epoch 00004: val_auc improved from 0.86440 to 0.88279, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00685 to 0.00674, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0135 - auc: 0.8831 - val_loss: 0.0067 - val_auc: 0.8828 - lr: 1.9400e-04
# Epoch 5/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0131 - auc: 0.8961
# Epoch 00005: val_auc improved from 0.88279 to 0.90234, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.00674
# 142/142 [==============================] - 172s 1s/step - loss: 0.0131 - auc: 0.8961 - val_loss: 0.0072 - val_auc: 0.9023 - lr: 2.5700e-04
# Epoch 6/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0124 - auc: 0.9108
# Epoch 00006: val_auc improved from 0.90234 to 0.91832, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00674 to 0.00605, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0124 - auc: 0.9108 - val_loss: 0.0061 - val_auc: 0.9183 - lr: 3.2000e-04
# Epoch 7/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0117 - auc: 0.9226
# Epoch 00007: val_auc did not improve from 0.91832
#
# Epoch 00007: val_loss did not improve from 0.00605
# 142/142 [==============================] - 169s 1s/step - loss: 0.0117 - auc: 0.9226 - val_loss: 0.0063 - val_auc: 0.9177 - lr: 2.5620e-04
# Epoch 8/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0112 - auc: 0.9305
# Epoch 00008: val_auc improved from 0.91832 to 0.91873, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00605
# 142/142 [==============================] - 172s 1s/step - loss: 0.0112 - auc: 0.9305 - val_loss: 0.0061 - val_auc: 0.9187 - lr: 2.0516e-04
# Epoch 9/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0107 - auc: 0.9389
# Epoch 00009: val_auc did not improve from 0.91873
#
# Epoch 00009: val_loss did not improve from 0.00605
# 142/142 [==============================] - 169s 1s/step - loss: 0.0107 - auc: 0.9389 - val_loss: 0.0063 - val_auc: 0.9130 - lr: 1.6433e-04
# Epoch 10/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0099 - auc: 0.9495
# Epoch 00010: val_auc improved from 0.91873 to 0.92026, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00605 to 0.00601, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0099 - auc: 0.9495 - val_loss: 0.0060 - val_auc: 0.9203 - lr: 1.3166e-04
# Epoch 11/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0096 - auc: 0.9514
# Epoch 00011: val_auc did not improve from 0.92026
#
# Epoch 00011: val_loss did not improve from 0.00601
# 142/142 [==============================] - 169s 1s/step - loss: 0.0096 - auc: 0.9514 - val_loss: 0.0062 - val_auc: 0.9164 - lr: 1.0553e-04
# Epoch 12/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0091 - auc: 0.9601
# Epoch 00012: val_auc did not improve from 0.92026
#
# Epoch 00012: val_loss did not improve from 0.00601
# 142/142 [==============================] - 169s 1s/step - loss: 0.0091 - auc: 0.9601 - val_loss: 0.0062 - val_auc: 0.9147 - lr: 8.4624e-05
# Epoch 13/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9625
# Epoch 00013: val_auc did not improve from 0.92026
#
# Epoch 00013: val_loss did not improve from 0.00601
# 142/142 [==============================] - 168s 1s/step - loss: 0.0088 - auc: 0.9625 - val_loss: 0.0061 - val_auc: 0.9189 - lr: 6.7899e-05
# Epoch 14/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0085 - auc: 0.9651
# Epoch 00014: val_auc did not improve from 0.92026
#
# Epoch 00014: val_loss did not improve from 0.00601
# 142/142 [==============================] - 169s 1s/step - loss: 0.0085 - auc: 0.9651 - val_loss: 0.0062 - val_auc: 0.9202 - lr: 5.4519e-05
# Epoch 15/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0082 - auc: 0.9683
# Epoch 00015: val_auc improved from 0.92026 to 0.92236, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00015: val_loss did not improve from 0.00601
# 142/142 [==============================] - 172s 1s/step - loss: 0.0082 - auc: 0.9683 - val_loss: 0.0062 - val_auc: 0.9224 - lr: 4.3815e-05
# Epoch 16/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9700
# Epoch 00016: val_auc did not improve from 0.92236
#
# Epoch 00016: val_loss did not improve from 0.00601
# 142/142 [==============================] - 169s 1s/step - loss: 0.0080 - auc: 0.9700 - val_loss: 0.0064 - val_auc: 0.9199 - lr: 3.5252e-05
# Epoch 17/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0077 - auc: 0.9726
# Epoch 00017: val_auc did not improve from 0.92236
#
# Epoch 00017: val_loss did not improve from 0.00601
# 142/142 [==============================] - 169s 1s/step - loss: 0.0077 - auc: 0.9726 - val_loss: 0.0064 - val_auc: 0.9220 - lr: 2.8402e-05
# Epoch 18/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0076 - auc: 0.9741
# Epoch 00018: val_auc did not improve from 0.92236
#
# Epoch 00018: val_loss did not improve from 0.00601
# 142/142 [==============================] - 169s 1s/step - loss: 0.0076 - auc: 0.9741 - val_loss: 0.0065 - val_auc: 0.9215 - lr: 2.2922e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 637/636 [==============================] - 173s 271ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 293s 273ms/step
# #### FOLD 4 OOF AUC without TTA = 0.922, with TTA = 0.933
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.60.21.202:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.60.21.202:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 5
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0962 - auc: 0.6079WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f614cbe2158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.56628, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05831, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 206s 1s/step - loss: 0.0962 - auc: 0.6079 - val_loss: 0.0583 - val_auc: 0.5663 - lr: 5.0000e-06
# Epoch 2/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0180 - auc: 0.7390
# Epoch 00002: val_auc improved from 0.56628 to 0.81480, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05831 to 0.00729, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0180 - auc: 0.7390 - val_loss: 0.0073 - val_auc: 0.8148 - lr: 6.8000e-05
# Epoch 3/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0146 - auc: 0.8533
# Epoch 00003: val_auc improved from 0.81480 to 0.85628, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00729 to 0.00686, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0146 - auc: 0.8533 - val_loss: 0.0069 - val_auc: 0.8563 - lr: 1.3100e-04
# Epoch 4/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0137 - auc: 0.8808
# Epoch 00004: val_auc improved from 0.85628 to 0.88142, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00686 to 0.00636, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0137 - auc: 0.8808 - val_loss: 0.0064 - val_auc: 0.8814 - lr: 1.9400e-04
# Epoch 5/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0132 - auc: 0.8913
# Epoch 00005: val_auc improved from 0.88142 to 0.88941, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.00636
# 142/142 [==============================] - 173s 1s/step - loss: 0.0132 - auc: 0.8913 - val_loss: 0.0064 - val_auc: 0.8894 - lr: 2.5700e-04
# Epoch 6/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0124 - auc: 0.9079
# Epoch 00006: val_auc improved from 0.88941 to 0.90255, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00636 to 0.00618, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0124 - auc: 0.9079 - val_loss: 0.0062 - val_auc: 0.9026 - lr: 3.2000e-04
# Epoch 7/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0119 - auc: 0.9196
# Epoch 00007: val_auc improved from 0.90255 to 0.90582, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.00618 to 0.00592, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0119 - auc: 0.9196 - val_loss: 0.0059 - val_auc: 0.9058 - lr: 2.5620e-04
# Epoch 8/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0109 - auc: 0.9360
# Epoch 00008: val_auc improved from 0.90582 to 0.90826, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00592
# 142/142 [==============================] - 173s 1s/step - loss: 0.0109 - auc: 0.9360 - val_loss: 0.0061 - val_auc: 0.9083 - lr: 2.0516e-04
# Epoch 9/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0105 - auc: 0.9412
# Epoch 00009: val_auc improved from 0.90826 to 0.91360, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.00592
# 142/142 [==============================] - 173s 1s/step - loss: 0.0105 - auc: 0.9412 - val_loss: 0.0060 - val_auc: 0.9136 - lr: 1.6433e-04
# Epoch 10/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0101 - auc: 0.9473
# Epoch 00010: val_auc improved from 0.91360 to 0.91419, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00592 to 0.00587, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0101 - auc: 0.9473 - val_loss: 0.0059 - val_auc: 0.9142 - lr: 1.3166e-04
# Epoch 11/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0097 - auc: 0.9534
# Epoch 00011: val_auc improved from 0.91419 to 0.91733, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00011: val_loss improved from 0.00587 to 0.00582, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0097 - auc: 0.9534 - val_loss: 0.0058 - val_auc: 0.9173 - lr: 1.0553e-04
# Epoch 12/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9564
# Epoch 00012: val_auc improved from 0.91733 to 0.91894, saving model to 384-EffNetB6-BS32-EPOCHS18-TTA25-INC2018-FOCAL-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00582
# 142/142 [==============================] - 172s 1s/step - loss: 0.0094 - auc: 0.9564 - val_loss: 0.0059 - val_auc: 0.9189 - lr: 8.4624e-05
# Epoch 13/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9627
# Epoch 00013: val_auc did not improve from 0.91894
#
# Epoch 00013: val_loss did not improve from 0.00582
# 142/142 [==============================] - 169s 1s/step - loss: 0.0088 - auc: 0.9627 - val_loss: 0.0059 - val_auc: 0.9172 - lr: 6.7899e-05
# Epoch 14/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9631
# Epoch 00014: val_auc did not improve from 0.91894
#
# Epoch 00014: val_loss did not improve from 0.00582
# 142/142 [==============================] - 169s 1s/step - loss: 0.0087 - auc: 0.9631 - val_loss: 0.0060 - val_auc: 0.9178 - lr: 5.4519e-05
# Epoch 15/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9673
# Epoch 00015: val_auc did not improve from 0.91894
#
# Epoch 00015: val_loss did not improve from 0.00582
# 142/142 [==============================] - 169s 1s/step - loss: 0.0084 - auc: 0.9673 - val_loss: 0.0060 - val_auc: 0.9178 - lr: 4.3815e-05
# Epoch 16/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0082 - auc: 0.9686
# Epoch 00016: val_auc did not improve from 0.91894
#
# Epoch 00016: val_loss did not improve from 0.00582
# 142/142 [==============================] - 169s 1s/step - loss: 0.0082 - auc: 0.9686 - val_loss: 0.0061 - val_auc: 0.9142 - lr: 3.5252e-05
# Epoch 17/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9711
# Epoch 00017: val_auc did not improve from 0.91894
#
# Epoch 00017: val_loss did not improve from 0.00582
# 142/142 [==============================] - 169s 1s/step - loss: 0.0080 - auc: 0.9711 - val_loss: 0.0060 - val_auc: 0.9165 - lr: 2.8402e-05
# Epoch 18/18
# 142/142 [==============================] - ETA: 0s - loss: 0.0079 - auc: 0.9704
# Epoch 00018: val_auc did not improve from 0.91894
#
# Epoch 00018: val_loss did not improve from 0.00582
# 142/142 [==============================] - 170s 1s/step - loss: 0.0079 - auc: 0.9704 - val_loss: 0.0063 - val_auc: 0.9160 - lr: 2.2922e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 641/640 [==============================] - 174s 271ms/step
# Predicting Test with TTA...
# 1073/1072 [==============================] - 292s 272ms/step
# #### FOLD 5 OOF AUC without TTA = 0.919, with TTA = 0.923

# %%
preds_by_fold
# Out:
# array([[0.01514785, 0.02579905, 0.01424189, 0.01602976, 0.01519279],
#        [0.03302976, 0.04894529, 0.02355012, 0.03534409, 0.02481494],
#        [0.02689655, 0.02808784, 0.03433836, 0.01961506, 0.02166563],
#        ...,
#        [0.02697057, 0.04772173, 0.05179228, 0.03944836, 0.04939283],
#        [0.04486532, 0.07193381, 0.0710819 , 0.06612262, 0.09542087],
#        [0.02198313, 0.02743204, 0.02732097, 0.01922011, 0.01146444]])

# %% [markdown]
# ## Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred); 
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names); folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{MODEL}/oof.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.932
#      image_name  target      pred  fold
# 0  ISIC_2637011     0.0  0.070328     0
# 1  ISIC_0076262     0.0  0.036890     0
# 2  ISIC_0074268     0.0  0.007701     0
# 3  ISIC_0015719     0.0  0.010888     0
# 4  ISIC_0082543     0.0  0.029887     0

# %%
auc_oof = 0.0
for i in range(FOLDS):
  auc_oof += roc_auc_score(oof_tar[i], oof_pred[i]) / FOLDS
print('Average OOF AUC with TTA = %.3f'%auc_oof)
# Out:
# Average OOF AUC with TTA = 0.934

# %% [markdown]
# # Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.
#
# Aqui, hauriem de posar les features amb XGB, CB, o el que sigui
# OptimizeAUC() del llibre de l'Abishek per trobar els pesos de diferents models per a cada fold
#
# I fer servir el OptimizeAUC per veure els pesos de la metadata

# %% [markdown]
# # Submit To Kaggle

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{MODEL}/submission.csv', index=False)
submission.head()

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
out_preds_by_fold = np.append(np.vstack(image_names), preds_by_fold, 1)
submission_by_fold = pd.DataFrame(out_preds_by_fold)

# #submission = submission.sort_values('image_name') 
submission_by_fold.to_csv(f'{MODEL}/preds_by_fold.csv', index=False)
submission_by_fold.head()
# submission.shape

# %%
preds_by_fold.shape

# %%
from scipy.stats import rankdata

ranked_submission = pd.DataFrame(dict(image_name=image_names, target=0))

ranked_submission['target'] = 0
for i in range(FOLDS):
    ranked_submission['target'] += rankdata(preds_by_fold[:,i]) / (FOLDS)

ranked_submission = ranked_submission.sort_values('image_name')

# %%
ranked_submission.head(100)

# %%
ranked_submission['target'].mean()

# %%
ranked_submission.to_csv(f'{MODEL}/submission_ranked.csv', index=False)

plt.hist(ranked_submission.target,bins=100)
plt.show()

# %%
import os
src = f'/content/{MODEL}'
dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}"'
os.system(f"rm -rf {dest}")
os.system(f"cp -rf {src} {dest}")
print (src)
print(dest)

# %%
import re
import json
import requests
import ipykernel
from notebook.notebookapp import list_running_servers
from requests.compat import urljoin

def get_notebook_name():
    """
    Return the full path of the jupyter notebook.
    """
    kernel_id = re.search('kernel-(.*).json', ipykernel.connect.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in response.json():
            if nn['kernel']['id'] == kernel_id:
                notebook_name = nn['notebook']['name']
                return notebook_name

NOTEBOOK_NAME = get_notebook_name()
copyNotebook = f'cp "/content/gdrive/My Drive/Colab Notebooks/{NOTEBOOK_NAME}" "/content/gdrive/My Drive/saved_models/{MODEL}/train.ipynb"'
os.system(copyNotebook)

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission.csv -m "{MODEL}"

# %%
#!kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission_ranked.csv -m "{MODEL}-Ranked"
