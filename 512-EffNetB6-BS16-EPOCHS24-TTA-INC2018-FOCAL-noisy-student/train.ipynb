# %% [markdown]
# # Triple Stratified KFold CV with TFRecords
# This is a simple starter notebook for Kaggle's Melanoma Comp showing triple stratifed KFold with TFRecords. Triple stratified KFold is explained [here][2]. There are many configuration variables below to allow you to experiment. Use either GPU or TPU. You can control which size images are loaded, which efficientNets are used, and whether external data is used. You can experiment with different data augmentation, model architecture, loss, optimizers, and learning schedules. The TFRecords contain meta data, so you can input that into your CNN too.
#
# **NOTE:** this notebook lets you run a different experiment in each fold if you want to run lots of experiments. (Then it is like running multiple holdout validaiton experiments but in that case note that the overall CV score is meaningless because LB will be much higher when the multiple experiments are ensembled to predict test). **If you want a proper CV with a reliable overall CV score you need to choose the same configuration for each fold.**
#
# This notebook follows the 5 step process presented in my "How to compete with GPUs Workshop" [here][1]. Some code sections have been reused from AgentAuers' great notebook [here][3]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/gdrive/My Drive/Kaggle/kaggle.json" ~/.kaggle

# %% [markdown]
# # Initialize Environment

# %%
# !pip install -q efficientnet >> /dev/null

# %%
import cv2, matplotlib.pyplot as plt
import gc
import pandas as pd, numpy as np
#from kaggle_datasets import KaggleDatasets
import tensorflow as tf, re, math
import tensorflow.keras.backend as K
import efficientnet.tfkeras as efn
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Configuration
# In order to be a proper cross validation with a meaningful overall CV score (aligned with LB score), **you need to choose the same** `IMG_SIZES`, `INC2019`, `INC2018`, and `EFF_NETS` **for each fold**. If your goal is to just run lots of experiments, then you can choose to have a different experiment in each fold. Then each fold is like a holdout validation experiment. When you find a configuration you like, you can use that configuration for all folds.
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 but can be any number between 2 and 15
# * IMG_SIZES - is a Python list of length FOLDS. These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - is a list of length FOLDS. These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - is a list of length FOLDS. These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter.
# * EFF_NETS - is a list of length FOLDS. These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %%
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 42

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 



IMG_SIZES = [384,384,384,384,384]
IMG_SIZES =  [512,512,512,512,512]


# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0,0,0,0,0]
INC2018 = [1,1,1,1,1]

# BATCH SIZE AND EPOCHS
BATCH_SIZES = [16]*FOLDS #[32]*FOLDS
EPOCHS = [24]*FOLDS #12 18

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [3,3,3,3,3]
EFF_NETS = [6,6,6,6,6]

EFF_NET_PRETRAIN = 'noisy-student' #'imagenet'

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 11

#Treure de Kaggle
if IMG_SIZES[0]==384:
  #384 images
  GCS1="gs://kds-e73569ee9d44308363027e79908294593e80b1e12e18e57ef065397c" #384
  GCS2="gs://kds-a2fe5a6e1a508cd8db24774c2db3261e943ace55b723c5ed834193fd"#384
elif IMG_SIZES[0]==512:
  #512
  GCS1 = "gs://kds-154649568d837568b1118f54c8293475e4b9686f2f6b0d89c6a2183e"
  GCS2 = "gs://kds-823a9066a531d4a2cb81f281a88a2235b28df4699c8eaf2a0b1f5208"
  

else:
  raise error

MODEL = f'{IMG_SIZES[0]}-EffNetB{EFF_NETS[0]}-BS{BATCH_SIZES[0]}-EPOCHS{EPOCHS[0]}-TTA-INC2018-FOCAL-{EFF_NET_PRETRAIN}'
print(MODEL)
# Out:
# 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student

# %%
import os
if not os.path.exists(f'/content/{MODEL}'):
    os.mkdir(f'/content/{MODEL}')

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and single GPU")
    strategy = tf.distribute.get_strategy()

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
# Out:
# connecting to TPU...
# Running on TPU  grpc://10.87.142.66:8470
# initializing  TPU ...
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# TPU initialized

# %% [markdown]
# # Step 1: Preprocess
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section. These TFRecords are discussed [here][1]. The advantage of using different input sizes is discussed [here][2]
#
# [1]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/155579
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147

# %%
GCS_PATH = [None]*FOLDS; GCS_PATH2 = [None]*FOLDS

for i,k in enumerate(IMG_SIZES):
    GCS_PATH[i] = GCS1
    GCS_PATH2[i] = GCS2

files_train = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/train*.tfrec')))
files_test  = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/test*.tfrec')))

# %% [markdown]
# # Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation first shown in this notebook [here][1] and successfully used in Melanoma comp by AgentAuers [here][2]. This notebook also uses horizontal flip, hue, saturation, contrast, brightness augmentation similar to last years winner and also similar to AgentAuers' notebook.
#
# Additionally we can decide to use external data by changing the variables `INC2019` and `INC2018` in the preceeding code section. These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][3]
#
# Consider experimenting with different augmenation and/or external data. The code to load TFRecords is taken from AgentAuers' notebook [here][2]. Thank you AgentAuers, this is great work.
#
# [1]: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
# [2]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [3]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %%
ROT_ = 180.0 #90.0 al submit anterior
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

# %%
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['target']


def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

 
def prepare_image(img, augment=True, dim=256):    
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)
                      
    img = tf.reshape(img, [dim,dim, 3])
            
    return img

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
        #todo add color const
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO) 
        #todo add color const     
    
    ds = ds.map(lambda img, imgname_or_label: (prepare_image(img, augment=augment, dim=dim), 
                                               imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %% [markdown]
# # Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN.

# %%
import tensorflow_addons as tfa

EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6]

def build_model(dim=128, ef=0):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EFNS[ef](input_shape=(dim,dim,3),weights=EFF_NET_PRETRAIN,include_top=False)
    #base.trainable = True
    #print(base.trainable)
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    #loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    loss = tfa.losses.SigmoidFocalCrossEntropy()
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    return model

a=build_model()
# Out:
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b0_noisy-student_notop.h5
# 16703488/16696600 [==============================] - 0s 0us/step

# %% [markdown]
# # Step 4: Train Schedule
# This is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
lr_start   = 0.000005
lr_max     = 0.00000125 * REPLICAS * BATCH_SIZES[0]
lr_min     = 0.000001
lr_ramp_ep = 5
lr_sus_ep  = 0
lr_decay   = 0.8

def lrfn(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        
    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max
        
    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
        
    return lr


rng = [i for i in range(EPOCHS[0])]
y = [lrfn(x) for x in rng]
plt.plot(rng, [lrfn(x) for x in rng])
print(y[0], y[-1])
# Out:
# 5e-06 3.864289363007639e-06

# %%
def get_lr_callback(batch_size=8):
    lr_start   = 0.000005
    lr_max     = 0.00000125 * REPLICAS * batch_size
    lr_min     = 0.000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback

# %% [markdown]
# ## Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []; oof_tar = []; oof_val = []; oof_names = []; oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_by_fold = np.empty([count_data_items(files_test), FOLDS], dtype=float)

for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25); print('#### FOLD',fold+1)
    print('#### Image Size %i with EfficientNet B%i and batch_size %i'%
          (IMG_SIZES[fold],EFF_NETS[fold],BATCH_SIZES[fold]*REPLICAS))
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[fold] + '/test*.tfrec')))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold])
        
    # SAVE BEST MODEL EACH FOLD
    checkpoint_file = f'{MODEL}/fold-%i-bestAUC.h5'%fold
    sv = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    checkpoint_file = f'{MODEL}/fold-%i-bestloss.h5'%fold
    sv2 = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold]), 
        epochs=EPOCHS[fold], callbacks = [sv,sv2,get_lr_callback(BATCH_SIZES[fold])], 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid,augment=False,shuffle=False,
                repeat=False,dim=IMG_SIZES[fold]), #class_weight = {0:1,1:2},
        verbose=VERBOSE
    )
    
    print('Loading best model val loss...')
    model.load_weights(checkpoint_file)
    
    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold])
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    #oof_pred.append(model.predict(get_dataset(files_valid,dim=IMG_SIZES[fold]),verbose=1))
    
    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))
    
    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold])
    print(ds_test)
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,] 
    tta_mean = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += tta_mean * WGTS[fold]
    #new

    preds_by_fold[:,fold] = tta_mean

    
    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print('#### FOLD %i OOF AUC without TTA = %.3f, with TTA = %.3f'%(fold+1,oof_val[-1],auc))
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] ); y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold]),size=18)
        plt.legend(loc=3)
        plt.show()
        #break
      
    del model
    z = gc.collect()
# Out:
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 1
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b6_noisy-student_notop.h5
# 165232640/165226952 [==============================] - 2s 0us/step
# Training...
# Epoch 1/24
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 284/284 [==============================] - ETA: 0s - loss: 0.0361 - auc: 0.6054
# Epoch 00001: val_auc improved from -inf to 0.55858, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01438, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 355s 1s/step - loss: 0.0361 - auc: 0.6054 - val_loss: 0.0144 - val_auc: 0.5586 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0169 - auc: 0.7705
# Epoch 00002: val_auc improved from 0.55858 to 0.81925, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01438 to 0.00831, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.0169 - auc: 0.7705 - val_loss: 0.0083 - val_auc: 0.8193 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0146 - auc: 0.8549
# Epoch 00003: val_auc improved from 0.81925 to 0.84713, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00831 to 0.00791, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.0146 - auc: 0.8549 - val_loss: 0.0079 - val_auc: 0.8471 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0142 - auc: 0.8708
# Epoch 00004: val_auc improved from 0.84713 to 0.88079, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00791 to 0.00776, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.0142 - auc: 0.8708 - val_loss: 0.0078 - val_auc: 0.8808 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0133 - auc: 0.8907
# Epoch 00005: val_auc improved from 0.88079 to 0.88554, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00776 to 0.00660, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0133 - auc: 0.8907 - val_loss: 0.0066 - val_auc: 0.8855 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0127 - auc: 0.9022
# Epoch 00006: val_auc improved from 0.88554 to 0.90143, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00660 to 0.00652, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 322s 1s/step - loss: 0.0127 - auc: 0.9022 - val_loss: 0.0065 - val_auc: 0.9014 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0122 - auc: 0.9133
# Epoch 00007: val_auc did not improve from 0.90143
#
# Epoch 00007: val_loss did not improve from 0.00652
# 284/284 [==============================] - 313s 1s/step - loss: 0.0122 - auc: 0.9133 - val_loss: 0.0065 - val_auc: 0.8911 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0118 - auc: 0.9240
# Epoch 00008: val_auc improved from 0.90143 to 0.90857, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.00652 to 0.00629, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0118 - auc: 0.9240 - val_loss: 0.0063 - val_auc: 0.9086 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0110 - auc: 0.9343
# Epoch 00009: val_auc did not improve from 0.90857
#
# Epoch 00009: val_loss improved from 0.00629 to 0.00627, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.0110 - auc: 0.9343 - val_loss: 0.0063 - val_auc: 0.9078 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0107 - auc: 0.9398
# Epoch 00010: val_auc improved from 0.90857 to 0.92114, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00627 to 0.00604, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0107 - auc: 0.9398 - val_loss: 0.0060 - val_auc: 0.9211 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9456
# Epoch 00011: val_auc improved from 0.92114 to 0.92635, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00011: val_loss did not improve from 0.00604
# 284/284 [==============================] - 319s 1s/step - loss: 0.0103 - auc: 0.9456 - val_loss: 0.0061 - val_auc: 0.9263 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0099 - auc: 0.9490
# Epoch 00012: val_auc did not improve from 0.92635
#
# Epoch 00012: val_loss improved from 0.00604 to 0.00597, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.0099 - auc: 0.9490 - val_loss: 0.0060 - val_auc: 0.9244 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9548
# Epoch 00013: val_auc did not improve from 0.92635
#
# Epoch 00013: val_loss did not improve from 0.00597
# 284/284 [==============================] - 314s 1s/step - loss: 0.0094 - auc: 0.9548 - val_loss: 0.0062 - val_auc: 0.9188 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0092 - auc: 0.9581
# Epoch 00014: val_auc did not improve from 0.92635
#
# Epoch 00014: val_loss did not improve from 0.00597
# 284/284 [==============================] - 316s 1s/step - loss: 0.0092 - auc: 0.9581 - val_loss: 0.0063 - val_auc: 0.9235 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0089 - auc: 0.9613
# Epoch 00015: val_auc did not improve from 0.92635
#
# Epoch 00015: val_loss did not improve from 0.00597
# 284/284 [==============================] - 314s 1s/step - loss: 0.0089 - auc: 0.9613 - val_loss: 0.0066 - val_auc: 0.9255 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9610
# Epoch 00016: val_auc did not improve from 0.92635
#
# Epoch 00016: val_loss did not improve from 0.00597
# 284/284 [==============================] - 315s 1s/step - loss: 0.0088 - auc: 0.9610 - val_loss: 0.0063 - val_auc: 0.9228 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9670
# Epoch 00017: val_auc did not improve from 0.92635
#
# Epoch 00017: val_loss did not improve from 0.00597
# 284/284 [==============================] - 316s 1s/step - loss: 0.0084 - auc: 0.9670 - val_loss: 0.0062 - val_auc: 0.9255 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9652
# Epoch 00018: val_auc did not improve from 0.92635
#
# Epoch 00018: val_loss did not improve from 0.00597
# 284/284 [==============================] - 315s 1s/step - loss: 0.0084 - auc: 0.9652 - val_loss: 0.0070 - val_auc: 0.9245 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9657
# Epoch 00019: val_auc did not improve from 0.92635
#
# Epoch 00019: val_loss did not improve from 0.00597
# 284/284 [==============================] - 315s 1s/step - loss: 0.0083 - auc: 0.9657 - val_loss: 0.0064 - val_auc: 0.9258 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9692
# Epoch 00020: val_auc did not improve from 0.92635
#
# Epoch 00020: val_loss did not improve from 0.00597
# 284/284 [==============================] - 315s 1s/step - loss: 0.0081 - auc: 0.9692 - val_loss: 0.0063 - val_auc: 0.9263 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0079 - auc: 0.9703
# Epoch 00021: val_auc improved from 0.92635 to 0.92709, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-0-bestAUC.h5
#
# Epoch 00021: val_loss did not improve from 0.00597
# 284/284 [==============================] - 319s 1s/step - loss: 0.0079 - auc: 0.9703 - val_loss: 0.0064 - val_auc: 0.9271 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0078 - auc: 0.9727
# Epoch 00022: val_auc did not improve from 0.92709
#
# Epoch 00022: val_loss did not improve from 0.00597
# 284/284 [==============================] - 314s 1s/step - loss: 0.0078 - auc: 0.9727 - val_loss: 0.0065 - val_auc: 0.9250 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0076 - auc: 0.9738
# Epoch 00023: val_auc did not improve from 0.92709
#
# Epoch 00023: val_loss did not improve from 0.00597
# 284/284 [==============================] - 314s 1s/step - loss: 0.0076 - auc: 0.9738 - val_loss: 0.0064 - val_auc: 0.9257 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0079 - auc: 0.9708
# Epoch 00024: val_auc did not improve from 0.92709
#
# Epoch 00024: val_loss did not improve from 0.00597
# 284/284 [==============================] - 315s 1s/step - loss: 0.0079 - auc: 0.9708 - val_loss: 0.0065 - val_auc: 0.9238 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 562/561 [==============================] - 140s 248ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 237s 251ms/step
# #### FOLD 1 OOF AUC without TTA = 0.927, with TTA = 0.936
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 2
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0411 - auc: 0.5854WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.57476, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01256, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestloss.h5
# 284/284 [==============================] - 354s 1s/step - loss: 0.0411 - auc: 0.5854 - val_loss: 0.0126 - val_auc: 0.5748 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0172 - auc: 0.7596
# Epoch 00002: val_auc improved from 0.57476 to 0.77552, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01256 to 0.00795, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0172 - auc: 0.7596 - val_loss: 0.0079 - val_auc: 0.7755 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0150 - auc: 0.8450
# Epoch 00003: val_auc improved from 0.77552 to 0.79987, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00003: val_loss did not improve from 0.00795
# 284/284 [==============================] - 321s 1s/step - loss: 0.0150 - auc: 0.8450 - val_loss: 0.0082 - val_auc: 0.7999 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0141 - auc: 0.8680
# Epoch 00004: val_auc improved from 0.79987 to 0.84098, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00795 to 0.00736, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0141 - auc: 0.8680 - val_loss: 0.0074 - val_auc: 0.8410 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0138 - auc: 0.8827
# Epoch 00005: val_auc did not improve from 0.84098
#
# Epoch 00005: val_loss did not improve from 0.00736
# 284/284 [==============================] - 316s 1s/step - loss: 0.0138 - auc: 0.8827 - val_loss: 0.0074 - val_auc: 0.8393 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0128 - auc: 0.9014
# Epoch 00006: val_auc improved from 0.84098 to 0.85567, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00736 to 0.00715, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0128 - auc: 0.9014 - val_loss: 0.0072 - val_auc: 0.8557 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0123 - auc: 0.9109
# Epoch 00007: val_auc improved from 0.85567 to 0.87172, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00715
# 284/284 [==============================] - 322s 1s/step - loss: 0.0123 - auc: 0.9109 - val_loss: 0.0072 - val_auc: 0.8717 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0118 - auc: 0.9225
# Epoch 00008: val_auc improved from 0.87172 to 0.90851, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.00715 to 0.00654, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-1-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0118 - auc: 0.9225 - val_loss: 0.0065 - val_auc: 0.9085 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0110 - auc: 0.9341
# Epoch 00009: val_auc did not improve from 0.90851
#
# Epoch 00009: val_loss did not improve from 0.00654
# 284/284 [==============================] - 316s 1s/step - loss: 0.0110 - auc: 0.9341 - val_loss: 0.0070 - val_auc: 0.8785 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0110 - auc: 0.9357
# Epoch 00010: val_auc did not improve from 0.90851
#
# Epoch 00010: val_loss did not improve from 0.00654
# 284/284 [==============================] - 316s 1s/step - loss: 0.0110 - auc: 0.9357 - val_loss: 0.0073 - val_auc: 0.8861 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9429
# Epoch 00011: val_auc did not improve from 0.90851
#
# Epoch 00011: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0103 - auc: 0.9429 - val_loss: 0.0068 - val_auc: 0.8991 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0100 - auc: 0.9495
# Epoch 00012: val_auc did not improve from 0.90851
#
# Epoch 00012: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0100 - auc: 0.9495 - val_loss: 0.0069 - val_auc: 0.8904 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0097 - auc: 0.9519
# Epoch 00013: val_auc did not improve from 0.90851
#
# Epoch 00013: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0097 - auc: 0.9519 - val_loss: 0.0072 - val_auc: 0.8967 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9565
# Epoch 00014: val_auc did not improve from 0.90851
#
# Epoch 00014: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0094 - auc: 0.9565 - val_loss: 0.0074 - val_auc: 0.8838 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9608
# Epoch 00015: val_auc did not improve from 0.90851
#
# Epoch 00015: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0090 - auc: 0.9608 - val_loss: 0.0068 - val_auc: 0.8985 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9603
# Epoch 00016: val_auc did not improve from 0.90851
#
# Epoch 00016: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0090 - auc: 0.9603 - val_loss: 0.0071 - val_auc: 0.8972 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9618
# Epoch 00017: val_auc did not improve from 0.90851
#
# Epoch 00017: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0087 - auc: 0.9618 - val_loss: 0.0069 - val_auc: 0.9010 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9634
# Epoch 00018: val_auc did not improve from 0.90851
#
# Epoch 00018: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0088 - auc: 0.9634 - val_loss: 0.0070 - val_auc: 0.8951 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0086 - auc: 0.9652
# Epoch 00019: val_auc did not improve from 0.90851
#
# Epoch 00019: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0086 - auc: 0.9652 - val_loss: 0.0071 - val_auc: 0.9030 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0085 - auc: 0.9654
# Epoch 00020: val_auc did not improve from 0.90851
#
# Epoch 00020: val_loss did not improve from 0.00654
# 284/284 [==============================] - 315s 1s/step - loss: 0.0085 - auc: 0.9654 - val_loss: 0.0072 - val_auc: 0.8999 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9694
# Epoch 00021: val_auc did not improve from 0.90851
#
# Epoch 00021: val_loss did not improve from 0.00654
# 284/284 [==============================] - 315s 1s/step - loss: 0.0080 - auc: 0.9694 - val_loss: 0.0073 - val_auc: 0.8989 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9691
# Epoch 00022: val_auc did not improve from 0.90851
#
# Epoch 00022: val_loss did not improve from 0.00654
# 284/284 [==============================] - 316s 1s/step - loss: 0.0081 - auc: 0.9691 - val_loss: 0.0073 - val_auc: 0.8959 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9708
# Epoch 00023: val_auc did not improve from 0.90851
#
# Epoch 00023: val_loss did not improve from 0.00654
# 284/284 [==============================] - 317s 1s/step - loss: 0.0080 - auc: 0.9708 - val_loss: 0.0074 - val_auc: 0.8992 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9698
# Epoch 00024: val_auc did not improve from 0.90851
#
# Epoch 00024: val_loss did not improve from 0.00654
# 284/284 [==============================] - 316s 1s/step - loss: 0.0081 - auc: 0.9698 - val_loss: 0.0072 - val_auc: 0.9003 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 562/561 [==============================] - 143s 254ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 238s 252ms/step
# #### FOLD 2 OOF AUC without TTA = 0.909, with TTA = 0.915
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 3
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0406 - auc: 0.5810WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.59042, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01288, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestloss.h5
# 284/284 [==============================] - 353s 1s/step - loss: 0.0406 - auc: 0.5810 - val_loss: 0.0129 - val_auc: 0.5904 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0173 - auc: 0.7529
# Epoch 00002: val_auc improved from 0.59042 to 0.85417, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01288 to 0.00705, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0173 - auc: 0.7529 - val_loss: 0.0071 - val_auc: 0.8542 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0150 - auc: 0.8432
# Epoch 00003: val_auc improved from 0.85417 to 0.87107, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00003: val_loss did not improve from 0.00705
# 284/284 [==============================] - 319s 1s/step - loss: 0.0150 - auc: 0.8432 - val_loss: 0.0073 - val_auc: 0.8711 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0139 - auc: 0.8705
# Epoch 00004: val_auc improved from 0.87107 to 0.90144, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00705 to 0.00639, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0139 - auc: 0.8705 - val_loss: 0.0064 - val_auc: 0.9014 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0136 - auc: 0.8881
# Epoch 00005: val_auc did not improve from 0.90144
#
# Epoch 00005: val_loss did not improve from 0.00639
# 284/284 [==============================] - 315s 1s/step - loss: 0.0136 - auc: 0.8881 - val_loss: 0.0064 - val_auc: 0.9005 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0129 - auc: 0.8967
# Epoch 00006: val_auc improved from 0.90144 to 0.91816, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00006: val_loss did not improve from 0.00639
# 284/284 [==============================] - 320s 1s/step - loss: 0.0129 - auc: 0.8967 - val_loss: 0.0067 - val_auc: 0.9182 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0126 - auc: 0.9067
# Epoch 00007: val_auc improved from 0.91816 to 0.92102, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00639
# 284/284 [==============================] - 319s 1s/step - loss: 0.0126 - auc: 0.9067 - val_loss: 0.0072 - val_auc: 0.9210 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0119 - auc: 0.9200
# Epoch 00008: val_auc improved from 0.92102 to 0.92290, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00639
# 284/284 [==============================] - 321s 1s/step - loss: 0.0119 - auc: 0.9200 - val_loss: 0.0065 - val_auc: 0.9229 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0111 - auc: 0.9328
# Epoch 00009: val_auc improved from 0.92290 to 0.92569, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00639 to 0.00624, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0111 - auc: 0.9328 - val_loss: 0.0062 - val_auc: 0.9257 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0109 - auc: 0.9337
# Epoch 00010: val_auc improved from 0.92569 to 0.92976, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00624 to 0.00601, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0109 - auc: 0.9337 - val_loss: 0.0060 - val_auc: 0.9298 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0104 - auc: 0.9435
# Epoch 00011: val_auc did not improve from 0.92976
#
# Epoch 00011: val_loss did not improve from 0.00601
# 284/284 [==============================] - 317s 1s/step - loss: 0.0104 - auc: 0.9435 - val_loss: 0.0060 - val_auc: 0.9284 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9449
# Epoch 00012: val_auc improved from 0.92976 to 0.93359, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00601
# 284/284 [==============================] - 322s 1s/step - loss: 0.0103 - auc: 0.9449 - val_loss: 0.0065 - val_auc: 0.9336 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0096 - auc: 0.9541
# Epoch 00013: val_auc did not improve from 0.93359
#
# Epoch 00013: val_loss did not improve from 0.00601
# 284/284 [==============================] - 317s 1s/step - loss: 0.0096 - auc: 0.9541 - val_loss: 0.0062 - val_auc: 0.9328 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0095 - auc: 0.9532
# Epoch 00014: val_auc did not improve from 0.93359
#
# Epoch 00014: val_loss did not improve from 0.00601
# 284/284 [==============================] - 318s 1s/step - loss: 0.0095 - auc: 0.9532 - val_loss: 0.0063 - val_auc: 0.9315 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9576
# Epoch 00015: val_auc improved from 0.93359 to 0.93694, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-2-bestAUC.h5
#
# Epoch 00015: val_loss did not improve from 0.00601
# 284/284 [==============================] - 323s 1s/step - loss: 0.0094 - auc: 0.9576 - val_loss: 0.0064 - val_auc: 0.9369 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9607
# Epoch 00016: val_auc did not improve from 0.93694
#
# Epoch 00016: val_loss did not improve from 0.00601
# 284/284 [==============================] - 317s 1s/step - loss: 0.0090 - auc: 0.9607 - val_loss: 0.0062 - val_auc: 0.9352 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9635
# Epoch 00017: val_auc did not improve from 0.93694
#
# Epoch 00017: val_loss did not improve from 0.00601
# 284/284 [==============================] - 318s 1s/step - loss: 0.0087 - auc: 0.9635 - val_loss: 0.0068 - val_auc: 0.9338 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9621
# Epoch 00018: val_auc did not improve from 0.93694
#
# Epoch 00018: val_loss did not improve from 0.00601
# 284/284 [==============================] - 318s 1s/step - loss: 0.0088 - auc: 0.9621 - val_loss: 0.0062 - val_auc: 0.9357 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9644
# Epoch 00019: val_auc did not improve from 0.93694
#
# Epoch 00019: val_loss did not improve from 0.00601
# 284/284 [==============================] - 316s 1s/step - loss: 0.0087 - auc: 0.9644 - val_loss: 0.0063 - val_auc: 0.9333 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0085 - auc: 0.9652
# Epoch 00020: val_auc did not improve from 0.93694
#
# Epoch 00020: val_loss did not improve from 0.00601
# 284/284 [==============================] - 315s 1s/step - loss: 0.0085 - auc: 0.9652 - val_loss: 0.0065 - val_auc: 0.9346 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0082 - auc: 0.9665
# Epoch 00021: val_auc did not improve from 0.93694
#
# Epoch 00021: val_loss did not improve from 0.00601
# 284/284 [==============================] - 316s 1s/step - loss: 0.0082 - auc: 0.9665 - val_loss: 0.0064 - val_auc: 0.9335 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9670
# Epoch 00022: val_auc did not improve from 0.93694
#
# Epoch 00022: val_loss did not improve from 0.00601
# 284/284 [==============================] - 316s 1s/step - loss: 0.0084 - auc: 0.9670 - val_loss: 0.0065 - val_auc: 0.9342 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9702
# Epoch 00023: val_auc did not improve from 0.93694
#
# Epoch 00023: val_loss did not improve from 0.00601
# 284/284 [==============================] - 316s 1s/step - loss: 0.0081 - auc: 0.9702 - val_loss: 0.0065 - val_auc: 0.9339 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9701
# Epoch 00024: val_auc did not improve from 0.93694
#
# Epoch 00024: val_loss did not improve from 0.00601
# 284/284 [==============================] - 317s 1s/step - loss: 0.0081 - auc: 0.9701 - val_loss: 0.0064 - val_auc: 0.9312 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 564/563 [==============================] - 142s 252ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 239s 253ms/step
# #### FOLD 3 OOF AUC without TTA = 0.937, with TTA = 0.938
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 4
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0322 - auc: 0.5870WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.63174, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01563, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 357s 1s/step - loss: 0.0322 - auc: 0.5870 - val_loss: 0.0156 - val_auc: 0.6317 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0174 - auc: 0.7568
# Epoch 00002: val_auc improved from 0.63174 to 0.84870, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01563 to 0.00698, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0174 - auc: 0.7568 - val_loss: 0.0070 - val_auc: 0.8487 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0150 - auc: 0.8461
# Epoch 00003: val_auc improved from 0.84870 to 0.87253, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00698 to 0.00692, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0150 - auc: 0.8461 - val_loss: 0.0069 - val_auc: 0.8725 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0138 - auc: 0.8751
# Epoch 00004: val_auc improved from 0.87253 to 0.89398, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00692 to 0.00648, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0138 - auc: 0.8751 - val_loss: 0.0065 - val_auc: 0.8940 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0133 - auc: 0.8904
# Epoch 00005: val_auc improved from 0.89398 to 0.90651, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00648 to 0.00634, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0133 - auc: 0.8904 - val_loss: 0.0063 - val_auc: 0.9065 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0129 - auc: 0.9027
# Epoch 00006: val_auc did not improve from 0.90651
#
# Epoch 00006: val_loss did not improve from 0.00634
# 284/284 [==============================] - 316s 1s/step - loss: 0.0129 - auc: 0.9027 - val_loss: 0.0065 - val_auc: 0.9031 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0120 - auc: 0.9147
# Epoch 00007: val_auc improved from 0.90651 to 0.91828, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00634
# 284/284 [==============================] - 321s 1s/step - loss: 0.0120 - auc: 0.9147 - val_loss: 0.0064 - val_auc: 0.9183 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0117 - auc: 0.9247
# Epoch 00008: val_auc did not improve from 0.91828
#
# Epoch 00008: val_loss improved from 0.00634 to 0.00622, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.0117 - auc: 0.9247 - val_loss: 0.0062 - val_auc: 0.9142 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0109 - auc: 0.9345
# Epoch 00009: val_auc improved from 0.91828 to 0.92809, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00622 to 0.00620, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0109 - auc: 0.9345 - val_loss: 0.0062 - val_auc: 0.9281 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9457
# Epoch 00010: val_auc improved from 0.92809 to 0.93228, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00620 to 0.00589, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-3-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0103 - auc: 0.9457 - val_loss: 0.0059 - val_auc: 0.9323 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0102 - auc: 0.9466
# Epoch 00011: val_auc did not improve from 0.93228
#
# ...
#
# Epoch 00023: val_loss did not improve from 0.00587
# 284/284 [==============================] - 319s 1s/step - loss: 0.0078 - auc: 0.9723 - val_loss: 0.0064 - val_auc: 0.9361 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0077 - auc: 0.9718
# Epoch 00024: val_auc did not improve from 0.93862
#
# Epoch 00024: val_loss did not improve from 0.00587
# 284/284 [==============================] - 319s 1s/step - loss: 0.0077 - auc: 0.9718 - val_loss: 0.0065 - val_auc: 0.9364 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 560/559 [==============================] - 142s 254ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 240s 254ms/step
# #### FOLD 4 OOF AUC without TTA = 0.939, with TTA = 0.938
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.87.142.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.87.142.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 5
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0364 - auc: 0.5645WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f25f8749f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.57549, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01476, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 354s 1s/step - loss: 0.0364 - auc: 0.5645 - val_loss: 0.0148 - val_auc: 0.5755 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0172 - auc: 0.7554
# Epoch 00002: val_auc improved from 0.57549 to 0.81809, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01476 to 0.00739, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0172 - auc: 0.7554 - val_loss: 0.0074 - val_auc: 0.8181 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0150 - auc: 0.8432
# Epoch 00003: val_auc improved from 0.81809 to 0.85526, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00739 to 0.00703, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0150 - auc: 0.8432 - val_loss: 0.0070 - val_auc: 0.8553 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0141 - auc: 0.8737
# Epoch 00004: val_auc improved from 0.85526 to 0.88505, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00703 to 0.00656, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0141 - auc: 0.8737 - val_loss: 0.0066 - val_auc: 0.8850 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0134 - auc: 0.8875
# Epoch 00005: val_auc did not improve from 0.88505
#
# Epoch 00005: val_loss did not improve from 0.00656
# 284/284 [==============================] - 317s 1s/step - loss: 0.0134 - auc: 0.8875 - val_loss: 0.0073 - val_auc: 0.8844 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0129 - auc: 0.9004
# Epoch 00006: val_auc improved from 0.88505 to 0.89093, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00656 to 0.00650, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0129 - auc: 0.9004 - val_loss: 0.0065 - val_auc: 0.8909 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0121 - auc: 0.9162
# Epoch 00007: val_auc improved from 0.89093 to 0.90729, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.00650 to 0.00629, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0121 - auc: 0.9162 - val_loss: 0.0063 - val_auc: 0.9073 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0118 - auc: 0.9218
# Epoch 00008: val_auc did not improve from 0.90729
#
# Epoch 00008: val_loss improved from 0.00629 to 0.00622, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0118 - auc: 0.9218 - val_loss: 0.0062 - val_auc: 0.9046 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0113 - auc: 0.9322
# Epoch 00009: val_auc improved from 0.90729 to 0.91384, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00622 to 0.00609, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0113 - auc: 0.9322 - val_loss: 0.0061 - val_auc: 0.9138 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0105 - auc: 0.9415
# Epoch 00010: val_auc improved from 0.91384 to 0.91806, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00609 to 0.00590, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0105 - auc: 0.9415 - val_loss: 0.0059 - val_auc: 0.9181 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9446
# Epoch 00011: val_auc improved from 0.91806 to 0.92278, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00011: val_loss did not improve from 0.00590
# 284/284 [==============================] - 322s 1s/step - loss: 0.0103 - auc: 0.9446 - val_loss: 0.0061 - val_auc: 0.9228 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0099 - auc: 0.9520
# Epoch 00012: val_auc improved from 0.92278 to 0.92671, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00590
# 284/284 [==============================] - 322s 1s/step - loss: 0.0099 - auc: 0.9520 - val_loss: 0.0060 - val_auc: 0.9267 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0096 - auc: 0.9531
# Epoch 00013: val_auc improved from 0.92671 to 0.92789, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00013: val_loss improved from 0.00590 to 0.00563, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0096 - auc: 0.9531 - val_loss: 0.0056 - val_auc: 0.9279 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9580
# Epoch 00014: val_auc improved from 0.92789 to 0.92801, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00014: val_loss did not improve from 0.00563
# 284/284 [==============================] - 321s 1s/step - loss: 0.0094 - auc: 0.9580 - val_loss: 0.0058 - val_auc: 0.9280 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9601
# Epoch 00015: val_auc did not improve from 0.92801
#
# Epoch 00015: val_loss did not improve from 0.00563
# 284/284 [==============================] - 315s 1s/step - loss: 0.0090 - auc: 0.9601 - val_loss: 0.0058 - val_auc: 0.9269 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9639
# Epoch 00016: val_auc improved from 0.92801 to 0.92890, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00016: val_loss did not improve from 0.00563
# 284/284 [==============================] - 320s 1s/step - loss: 0.0088 - auc: 0.9639 - val_loss: 0.0058 - val_auc: 0.9289 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9639
# Epoch 00017: val_auc improved from 0.92890 to 0.92910, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00017: val_loss did not improve from 0.00563
# 284/284 [==============================] - 320s 1s/step - loss: 0.0087 - auc: 0.9639 - val_loss: 0.0061 - val_auc: 0.9291 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9677
# Epoch 00018: val_auc improved from 0.92910 to 0.92933, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00018: val_loss did not improve from 0.00563
# 284/284 [==============================] - 320s 1s/step - loss: 0.0084 - auc: 0.9677 - val_loss: 0.0061 - val_auc: 0.9293 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9679
# Epoch 00019: val_auc did not improve from 0.92933
#
# Epoch 00019: val_loss did not improve from 0.00563
# 284/284 [==============================] - 314s 1s/step - loss: 0.0084 - auc: 0.9679 - val_loss: 0.0061 - val_auc: 0.9282 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9674
# Epoch 00020: val_auc did not improve from 0.92933
#
# Epoch 00020: val_loss did not improve from 0.00563
# 284/284 [==============================] - 317s 1s/step - loss: 0.0083 - auc: 0.9674 - val_loss: 0.0061 - val_auc: 0.9276 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9670
# Epoch 00021: val_auc did not improve from 0.92933
#
# Epoch 00021: val_loss did not improve from 0.00563
# 284/284 [==============================] - 316s 1s/step - loss: 0.0083 - auc: 0.9670 - val_loss: 0.0061 - val_auc: 0.9290 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9704
# Epoch 00022: val_auc did not improve from 0.92933
#
# Epoch 00022: val_loss did not improve from 0.00563
# 284/284 [==============================] - 316s 1s/step - loss: 0.0080 - auc: 0.9704 - val_loss: 0.0060 - val_auc: 0.9268 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9718
# Epoch 00023: val_auc did not improve from 0.92933
#
# Epoch 00023: val_loss did not improve from 0.00563
# 284/284 [==============================] - 318s 1s/step - loss: 0.0080 - auc: 0.9718 - val_loss: 0.0060 - val_auc: 0.9284 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0080 - auc: 0.9705
# Epoch 00024: val_auc improved from 0.92933 to 0.92935, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL-noisy-student/fold-4-bestAUC.h5
#
# Epoch 00024: val_loss did not improve from 0.00563
# 284/284 [==============================] - 323s 1s/step - loss: 0.0080 - auc: 0.9705 - val_loss: 0.0060 - val_auc: 0.9294 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 564/563 [==============================] - 142s 252ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 238s 252ms/step
# #### FOLD 5 OOF AUC without TTA = 0.929, with TTA = 0.926

# %%
preds_by_fold
# Out:
# array([[0.01773557, 0.0253121 , 0.02233567, 0.02535992, 0.01726748],
#        [0.03913803, 0.02349405, 0.03199035, 0.0118979 , 0.02090635],
#        [0.03283613, 0.01172057, 0.0295886 , 0.01696218, 0.03139112],
#        ...,
#        [0.09454203, 0.12101707, 0.10108165, 0.08252227, 0.08406887],
#        [0.06804595, 0.15587959, 0.12477712, 0.11352823, 0.05669571],
#        [0.02205135, 0.01705657, 0.03351407, 0.01126976, 0.02123974]])

# %% [markdown]
# ## Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred); 
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names); folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{MODEL}/oof.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.927
#      image_name  target      pred  fold
# 0  ISIC_2637011       0  0.054592     0
# 1  ISIC_0076262       0  0.038221     0
# 2  ISIC_0074268       0  0.006339     0
# 3  ISIC_0015719       0  0.014830     0
# 4  ISIC_0082543       0  0.016931     0

# %%
auc_oof = 0.0
for i in range(FOLDS):
  auc_oof += roc_auc_score(oof_tar[i], oof_pred[i]) / FOLDS
print('Average OOF AUC with TTA = %.3f'%auc_oof)
# Out:
# Average OOF AUC with TTA = 0.930

# %% [markdown]
# # Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.
#
# Aqui, hauriem de posar les features amb XGB, CB, o el que sigui
# OptimizeAUC() del llibre de l'Abishek per trobar els pesos de diferents models per a cada fold
#
# I fer servir el OptimizeAUC per veure els pesos de la metadata

# %% [markdown]
# # Submit To Kaggle

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{MODEL}/submission.csv', index=False)
submission.head()

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
out_preds_by_fold = np.append(np.vstack(image_names), preds_by_fold, 1)
submission_by_fold = pd.DataFrame(out_preds_by_fold)

# #submission = submission.sort_values('image_name') 
submission_by_fold.to_csv(f'{MODEL}/preds_by_fold.csv', index=False)
submission_by_fold.head()
# submission.shape

# %%
preds_by_fold.shape

# %%
from scipy.stats import rankdata

ranked_submission = pd.DataFrame(dict(image_name=image_names, target=0))

ranked_submission['target'] = 0
for i in range(FOLDS):
    ranked_submission['target'] += rankdata(preds_by_fold[:,i]) / (FOLDS)

ranked_submission = ranked_submission.sort_values('image_name')

# %%
ranked_submission.head(100)

# %%
ranked_submission['target'].mean()

# %%
ranked_submission.to_csv(f'{MODEL}/submission_ranked.csv', index=False)

plt.hist(ranked_submission.target,bins=100)
plt.show()

# %%
import os
src = f'/content/{MODEL}'
dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}"'
os.system(f"rm -rf {dest}")
os.system(f"cp -rf {src} {dest}")
print (src)
print(dest)

# %%
import re
import json
import requests
import ipykernel
from notebook.notebookapp import list_running_servers
from requests.compat import urljoin

def get_notebook_name():
    """
    Return the full path of the jupyter notebook.
    """
    kernel_id = re.search('kernel-(.*).json', ipykernel.connect.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in response.json():
            if nn['kernel']['id'] == kernel_id:
                notebook_name = nn['notebook']['name']
                return notebook_name

NOTEBOOK_NAME = get_notebook_name()
copyNotebook = f'cp "/content/gdrive/My Drive/Colab Notebooks/{NOTEBOOK_NAME}" "/content/gdrive/My Drive/saved_models/{MODEL}/train.ipynb"'
os.system(copyNotebook)

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission.csv -m "{MODEL}"

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission_ranked.csv -m "{MODEL}-Ranked"
