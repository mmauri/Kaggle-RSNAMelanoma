# %% [markdown]
# # Triple Stratified KFold CV with TFRecords
# This is a simple starter notebook for Kaggle's Melanoma Comp showing triple stratifed KFold with TFRecords. Triple stratified KFold is explained [here][2]. There are many configuration variables below to allow you to experiment. Use either GPU or TPU. You can control which size images are loaded, which efficientNets are used, and whether external data is used. You can experiment with different data augmentation, model architecture, loss, optimizers, and learning schedules. The TFRecords contain meta data, so you can input that into your CNN too.
#
# **NOTE:** this notebook lets you run a different experiment in each fold if you want to run lots of experiments. (Then it is like running multiple holdout validaiton experiments but in that case note that the overall CV score is meaningless because LB will be much higher when the multiple experiments are ensembled to predict test). **If you want a proper CV with a reliable overall CV score you need to choose the same configuration for each fold.**
#
# This notebook follows the 5 step process presented in my "How to compete with GPUs Workshop" [here][1]. Some code sections have been reused from AgentAuers' great notebook [here][3]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/gdrive/My Drive/Kaggle/kaggle.json" ~/.kaggle

# %% [markdown]
# # Initialize Environment

# %%
# !pip install -q efficientnet >> /dev/null

# %%
import cv2, matplotlib.pyplot as plt
import gc
import pandas as pd, numpy as np
#from kaggle_datasets import KaggleDatasets
import tensorflow as tf, re, math
import tensorflow.keras.backend as K
import efficientnet.tfkeras as efn
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Configuration
# In order to be a proper cross validation with a meaningful overall CV score (aligned with LB score), **you need to choose the same** `IMG_SIZES`, `INC2019`, `INC2018`, and `EFF_NETS` **for each fold**. If your goal is to just run lots of experiments, then you can choose to have a different experiment in each fold. Then each fold is like a holdout validation experiment. When you find a configuration you like, you can use that configuration for all folds.
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 but can be any number between 2 and 15
# * IMG_SIZES - is a Python list of length FOLDS. These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - is a list of length FOLDS. These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - is a list of length FOLDS. These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter.
# * EFF_NETS - is a list of length FOLDS. These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %%
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 42

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 



IMG_SIZES = [384,384,384,384,384]
IMG_SIZES =  [512,512,512,512,512]


# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0,0,0,0,0]
INC2018 = [1,1,1,1,1]

# BATCH SIZE AND EPOCHS
BATCH_SIZES = [16]*FOLDS #[32]*FOLDS
EPOCHS = [24]*FOLDS #12 18

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [3,3,3,3,3]
EFF_NETS = [6,6,6,6,6]

EFF_NET_PRETRAIN = 'imagenet' #'noisy-student'

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 11

#Treure de Kaggle
if IMG_SIZES[0]==384:
  #384 images
  GCS1="gs://kds-e73569ee9d44308363027e79908294593e80b1e12e18e57ef065397c" #384
  GCS2="gs://kds-a2fe5a6e1a508cd8db24774c2db3261e943ace55b723c5ed834193fd"#384
elif IMG_SIZES[0]==512:
  #512
  GCS1 = "gs://kds-154649568d837568b1118f54c8293475e4b9686f2f6b0d89c6a2183e"
  GCS2 = "gs://kds-823a9066a531d4a2cb81f281a88a2235b28df4699c8eaf2a0b1f5208"
  

else:
  raise error

MODEL = f'{IMG_SIZES[0]}-EffNetB{EFF_NETS[0]}-BS{BATCH_SIZES[0]}-EPOCHS{EPOCHS[0]}-TTA-INC2018-FOCAL'
print(MODEL)
# Out:
# 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL

# %%
import os
if not os.path.exists(f'/content/{MODEL}'):
    os.mkdir(f'/content/{MODEL}')

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and single GPU")
    strategy = tf.distribute.get_strategy()

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
# Out:
# connecting to TPU...
# Running on TPU  grpc://10.84.243.10:8470
# initializing  TPU ...
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# TPU initialized

# %% [markdown]
# # Step 1: Preprocess
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section. These TFRecords are discussed [here][1]. The advantage of using different input sizes is discussed [here][2]
#
# [1]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/155579
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147

# %%
GCS_PATH = [None]*FOLDS; GCS_PATH2 = [None]*FOLDS

for i,k in enumerate(IMG_SIZES):
    GCS_PATH[i] = GCS1
    GCS_PATH2[i] = GCS2

files_train = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/train*.tfrec')))
files_test  = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/test*.tfrec')))

# %% [markdown]
# # Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation first shown in this notebook [here][1] and successfully used in Melanoma comp by AgentAuers [here][2]. This notebook also uses horizontal flip, hue, saturation, contrast, brightness augmentation similar to last years winner and also similar to AgentAuers' notebook.
#
# Additionally we can decide to use external data by changing the variables `INC2019` and `INC2018` in the preceeding code section. These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][3]
#
# Consider experimenting with different augmenation and/or external data. The code to load TFRecords is taken from AgentAuers' notebook [here][2]. Thank you AgentAuers, this is great work.
#
# [1]: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
# [2]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [3]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %%
ROT_ = 180.0 #90.0 al submit anterior
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

# %%
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['target']


def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

 
def prepare_image(img, augment=True, dim=256):    
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)
                      
    img = tf.reshape(img, [dim,dim, 3])
            
    return img

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
        #todo add color const
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO) 
        #todo add color const     
    
    ds = ds.map(lambda img, imgname_or_label: (prepare_image(img, augment=augment, dim=dim), 
                                               imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %% [markdown]
# # Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN.

# %%
import tensorflow_addons as tfa

EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6]

def build_model(dim=128, ef=0):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EFNS[ef](input_shape=(dim,dim,3),weights=EFF_NET_PRETRAIN,include_top=False)
    #base.trainable = True
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    #loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    loss = tfa.losses.SigmoidFocalCrossEntropy()
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    return model

# %% [markdown]
# # Step 4: Train Schedule
# This is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
lr_start   = 0.000005
lr_max     = 0.00000125 * REPLICAS * BATCH_SIZES[0]
lr_min     = 0.000001
lr_ramp_ep = 5
lr_sus_ep  = 0
lr_decay   = 0.8

def lrfn(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        
    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max
        
    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
        
    return lr


rng = [i for i in range(EPOCHS[0])]
y = [lrfn(x) for x in rng]
plt.plot(rng, [lrfn(x) for x in rng])
print(y[0], y[-1])
# Out:
# 5e-06 3.864289363007639e-06

# %%
def get_lr_callback(batch_size=8):
    lr_start   = 0.000005
    lr_max     = 0.00000125 * REPLICAS * batch_size
    lr_min     = 0.000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback

# %% [markdown]
# ## Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []; oof_tar = []; oof_val = []; oof_names = []; oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_by_fold = np.empty([count_data_items(files_test), FOLDS], dtype=float)

for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25); print('#### FOLD',fold+1)
    print('#### Image Size %i with EfficientNet B%i and batch_size %i'%
          (IMG_SIZES[fold],EFF_NETS[fold],BATCH_SIZES[fold]*REPLICAS))
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[fold] + '/test*.tfrec')))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold])
        
    # SAVE BEST MODEL EACH FOLD
    checkpoint_file = f'{MODEL}/fold-%i-bestAUC.h5'%fold
    sv = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    checkpoint_file = f'{MODEL}/fold-%i-bestloss.h5'%fold
    sv2 = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold]), 
        epochs=EPOCHS[fold], callbacks = [sv,sv2,get_lr_callback(BATCH_SIZES[fold])], 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid,augment=False,shuffle=False,
                repeat=False,dim=IMG_SIZES[fold]), #class_weight = {0:1,1:2},
        verbose=VERBOSE
    )
    
    print('Loading best model val loss...')
    model.load_weights(checkpoint_file)
    
    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold])
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    #oof_pred.append(model.predict(get_dataset(files_valid,dim=IMG_SIZES[fold]),verbose=1))
    
    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))
    
    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold])
    print(ds_test)
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,] 
    tta_mean = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += tta_mean * WGTS[fold]
    #new

    preds_by_fold[:,fold] = tta_mean

    
    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print('#### FOLD %i OOF AUC without TTA = %.3f, with TTA = %.3f'%(fold+1,oof_val[-1],auc))
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] ); y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold]),size=18)
        plt.legend(loc=3)
        plt.show()
        #break
      

    gc.collect()
# Out:
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 1
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b6_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 165527552/165527152 [==============================] - 2s 0us/step
# Training...
# Epoch 1/24
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 284/284 [==============================] - ETA: 0s - loss: 0.0556 - auc: 0.5751
# Epoch 00001: val_auc improved from -inf to 0.65896, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01366, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 358s 1s/step - loss: 0.0556 - auc: 0.5751 - val_loss: 0.0137 - val_auc: 0.6590 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0158 - auc: 0.8096
# Epoch 00002: val_auc improved from 0.65896 to 0.86152, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01366 to 0.00705, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.0158 - auc: 0.8096 - val_loss: 0.0071 - val_auc: 0.8615 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0143 - auc: 0.8662
# Epoch 00003: val_auc improved from 0.86152 to 0.88194, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00705 to 0.00669, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.0143 - auc: 0.8662 - val_loss: 0.0067 - val_auc: 0.8819 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0131 - auc: 0.8947
# Epoch 00004: val_auc improved from 0.88194 to 0.89943, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00669 to 0.00633, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.0131 - auc: 0.8947 - val_loss: 0.0063 - val_auc: 0.8994 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0122 - auc: 0.9163
# Epoch 00005: val_auc improved from 0.89943 to 0.90304, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.00633
# 284/284 [==============================] - 316s 1s/step - loss: 0.0122 - auc: 0.9163 - val_loss: 0.0074 - val_auc: 0.9030 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0118 - auc: 0.9220
# Epoch 00006: val_auc improved from 0.90304 to 0.92205, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00633 to 0.00587, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.0118 - auc: 0.9220 - val_loss: 0.0059 - val_auc: 0.9221 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0106 - auc: 0.9404
# Epoch 00007: val_auc did not improve from 0.92205
#
# Epoch 00007: val_loss did not improve from 0.00587
# 284/284 [==============================] - 311s 1s/step - loss: 0.0106 - auc: 0.9404 - val_loss: 0.0070 - val_auc: 0.9196 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0103 - auc: 0.9457
# Epoch 00008: val_auc did not improve from 0.92205
#
# Epoch 00008: val_loss did not improve from 0.00587
# 284/284 [==============================] - 311s 1s/step - loss: 0.0103 - auc: 0.9457 - val_loss: 0.0065 - val_auc: 0.9178 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9540
# Epoch 00009: val_auc improved from 0.92205 to 0.92658, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00587 to 0.00587, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.0094 - auc: 0.9540 - val_loss: 0.0059 - val_auc: 0.9266 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9625
# Epoch 00010: val_auc improved from 0.92658 to 0.92925, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00010: val_loss did not improve from 0.00587
# 284/284 [==============================] - 316s 1s/step - loss: 0.0087 - auc: 0.9625 - val_loss: 0.0062 - val_auc: 0.9292 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9686
# Epoch 00011: val_auc did not improve from 0.92925
#
# Epoch 00011: val_loss did not improve from 0.00587
# 284/284 [==============================] - 311s 1s/step - loss: 0.0083 - auc: 0.9686 - val_loss: 0.0063 - val_auc: 0.9254 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0077 - auc: 0.9720
# Epoch 00012: val_auc improved from 0.92925 to 0.92981, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00012: val_loss improved from 0.00587 to 0.00587, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.0077 - auc: 0.9720 - val_loss: 0.0059 - val_auc: 0.9298 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0074 - auc: 0.9766
# Epoch 00013: val_auc did not improve from 0.92981
#
# Epoch 00013: val_loss did not improve from 0.00587
# 284/284 [==============================] - 312s 1s/step - loss: 0.0074 - auc: 0.9766 - val_loss: 0.0062 - val_auc: 0.9249 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0069 - auc: 0.9785
# Epoch 00014: val_auc improved from 0.92981 to 0.93085, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00014: val_loss did not improve from 0.00587
# 284/284 [==============================] - 316s 1s/step - loss: 0.0069 - auc: 0.9785 - val_loss: 0.0061 - val_auc: 0.9308 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0067 - auc: 0.9808
# Epoch 00015: val_auc improved from 0.93085 to 0.93368, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00015: val_loss did not improve from 0.00587
# 284/284 [==============================] - 316s 1s/step - loss: 0.0067 - auc: 0.9808 - val_loss: 0.0060 - val_auc: 0.9337 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0065 - auc: 0.9812
# Epoch 00016: val_auc did not improve from 0.93368
#
# Epoch 00016: val_loss did not improve from 0.00587
# 284/284 [==============================] - 312s 1s/step - loss: 0.0065 - auc: 0.9812 - val_loss: 0.0061 - val_auc: 0.9304 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0063 - auc: 0.9827
# Epoch 00017: val_auc did not improve from 0.93368
#
# Epoch 00017: val_loss did not improve from 0.00587
# 284/284 [==============================] - 312s 1s/step - loss: 0.0063 - auc: 0.9827 - val_loss: 0.0061 - val_auc: 0.9324 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0062 - auc: 0.9846
# Epoch 00018: val_auc did not improve from 0.93368
#
# Epoch 00018: val_loss did not improve from 0.00587
# 284/284 [==============================] - 312s 1s/step - loss: 0.0062 - auc: 0.9846 - val_loss: 0.0066 - val_auc: 0.9323 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0061 - auc: 0.9838
# Epoch 00019: val_auc improved from 0.93368 to 0.93377, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00019: val_loss did not improve from 0.00587
# 284/284 [==============================] - 316s 1s/step - loss: 0.0061 - auc: 0.9838 - val_loss: 0.0063 - val_auc: 0.9338 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0059 - auc: 0.9851
# Epoch 00020: val_auc improved from 0.93377 to 0.93422, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00020: val_loss did not improve from 0.00587
# 284/284 [==============================] - 316s 1s/step - loss: 0.0059 - auc: 0.9851 - val_loss: 0.0065 - val_auc: 0.9342 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0058 - auc: 0.9857
# Epoch 00021: val_auc did not improve from 0.93422
#
# Epoch 00021: val_loss did not improve from 0.00587
# 284/284 [==============================] - 313s 1s/step - loss: 0.0058 - auc: 0.9857 - val_loss: 0.0062 - val_auc: 0.9336 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9864
# Epoch 00022: val_auc did not improve from 0.93422
#
# Epoch 00022: val_loss did not improve from 0.00587
# 284/284 [==============================] - 311s 1s/step - loss: 0.0057 - auc: 0.9864 - val_loss: 0.0064 - val_auc: 0.9318 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0058 - auc: 0.9857
# Epoch 00023: val_auc did not improve from 0.93422
#
# Epoch 00023: val_loss did not improve from 0.00587
# 284/284 [==============================] - 312s 1s/step - loss: 0.0058 - auc: 0.9857 - val_loss: 0.0063 - val_auc: 0.9311 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9872
# Epoch 00024: val_auc did not improve from 0.93422
#
# Epoch 00024: val_loss did not improve from 0.00587
# 284/284 [==============================] - 312s 1s/step - loss: 0.0056 - auc: 0.9872 - val_loss: 0.0065 - val_auc: 0.9304 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 562/561 [==============================] - 136s 243ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 231s 244ms/step
# #### FOLD 1 OOF AUC without TTA = 0.934, with TTA = 0.944
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 2
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0549 - auc: 0.5696WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.62219, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01418, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 284/284 [==============================] - 350s 1s/step - loss: 0.0549 - auc: 0.5696 - val_loss: 0.0142 - val_auc: 0.6222 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0159 - auc: 0.8088
# Epoch 00002: val_auc improved from 0.62219 to 0.81940, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01418 to 0.00745, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.0159 - auc: 0.8088 - val_loss: 0.0075 - val_auc: 0.8194 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0140 - auc: 0.8785
# Epoch 00003: val_auc improved from 0.81940 to 0.87268, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00745 to 0.00697, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 284/284 [==============================] - 324s 1s/step - loss: 0.0140 - auc: 0.8785 - val_loss: 0.0070 - val_auc: 0.8727 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0128 - auc: 0.9010
# Epoch 00004: val_auc improved from 0.87268 to 0.89310, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00697 to 0.00670, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0128 - auc: 0.9010 - val_loss: 0.0067 - val_auc: 0.8931 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0124 - auc: 0.9123
# Epoch 00005: val_auc improved from 0.89310 to 0.90390, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00670 to 0.00655, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 284/284 [==============================] - 323s 1s/step - loss: 0.0124 - auc: 0.9123 - val_loss: 0.0066 - val_auc: 0.9039 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0117 - auc: 0.9249
# Epoch 00006: val_auc did not improve from 0.90390
#
# Epoch 00006: val_loss did not improve from 0.00655
# 284/284 [==============================] - 315s 1s/step - loss: 0.0117 - auc: 0.9249 - val_loss: 0.0071 - val_auc: 0.8893 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0108 - auc: 0.9362
# Epoch 00007: val_auc improved from 0.90390 to 0.90629, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00655
# 284/284 [==============================] - 320s 1s/step - loss: 0.0108 - auc: 0.9362 - val_loss: 0.0066 - val_auc: 0.9063 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0097 - auc: 0.9525
# Epoch 00008: val_auc improved from 0.90629 to 0.91547, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00655
# 284/284 [==============================] - 320s 1s/step - loss: 0.0097 - auc: 0.9525 - val_loss: 0.0067 - val_auc: 0.9155 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9560
# Epoch 00009: val_auc did not improve from 0.91547
#
# Epoch 00009: val_loss did not improve from 0.00655
# 284/284 [==============================] - 315s 1s/step - loss: 0.0094 - auc: 0.9560 - val_loss: 0.0071 - val_auc: 0.9109 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9634
# Epoch 00010: val_auc improved from 0.91547 to 0.92074, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00010: val_loss did not improve from 0.00655
# 284/284 [==============================] - 319s 1s/step - loss: 0.0087 - auc: 0.9634 - val_loss: 0.0072 - val_auc: 0.9207 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9668
# Epoch 00011: val_auc did not improve from 0.92074
#
# Epoch 00011: val_loss did not improve from 0.00655
# 284/284 [==============================] - 316s 1s/step - loss: 0.0083 - auc: 0.9668 - val_loss: 0.0071 - val_auc: 0.9159 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0078 - auc: 0.9724
# Epoch 00012: val_auc did not improve from 0.92074
#
# Epoch 00012: val_loss did not improve from 0.00655
# 284/284 [==============================] - 317s 1s/step - loss: 0.0078 - auc: 0.9724 - val_loss: 0.0074 - val_auc: 0.9160 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0073 - auc: 0.9772
# Epoch 00013: val_auc improved from 0.92074 to 0.92106, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00013: val_loss did not improve from 0.00655
# 284/284 [==============================] - 321s 1s/step - loss: 0.0073 - auc: 0.9772 - val_loss: 0.0070 - val_auc: 0.9211 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0069 - auc: 0.9796
# Epoch 00014: val_auc did not improve from 0.92106
#
# Epoch 00014: val_loss did not improve from 0.00655
# 284/284 [==============================] - 316s 1s/step - loss: 0.0069 - auc: 0.9796 - val_loss: 0.0074 - val_auc: 0.9172 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0068 - auc: 0.9807
# Epoch 00015: val_auc did not improve from 0.92106
#
# Epoch 00015: val_loss did not improve from 0.00655
# 284/284 [==============================] - 317s 1s/step - loss: 0.0068 - auc: 0.9807 - val_loss: 0.0081 - val_auc: 0.9145 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0065 - auc: 0.9819
# Epoch 00016: val_auc did not improve from 0.92106
#
# Epoch 00016: val_loss did not improve from 0.00655
# 284/284 [==============================] - 318s 1s/step - loss: 0.0065 - auc: 0.9819 - val_loss: 0.0076 - val_auc: 0.9145 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0063 - auc: 0.9837
# Epoch 00017: val_auc did not improve from 0.92106
#
# Epoch 00017: val_loss did not improve from 0.00655
# 284/284 [==============================] - 320s 1s/step - loss: 0.0063 - auc: 0.9837 - val_loss: 0.0077 - val_auc: 0.9179 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0060 - auc: 0.9852
# Epoch 00018: val_auc did not improve from 0.92106
#
# Epoch 00018: val_loss did not improve from 0.00655
# 284/284 [==============================] - 318s 1s/step - loss: 0.0060 - auc: 0.9852 - val_loss: 0.0082 - val_auc: 0.9191 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0059 - auc: 0.9857
# Epoch 00019: val_auc did not improve from 0.92106
#
# Epoch 00019: val_loss did not improve from 0.00655
# 284/284 [==============================] - 318s 1s/step - loss: 0.0059 - auc: 0.9857 - val_loss: 0.0081 - val_auc: 0.9165 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9862
# Epoch 00020: val_auc did not improve from 0.92106
#
# Epoch 00020: val_loss did not improve from 0.00655
# 284/284 [==============================] - 318s 1s/step - loss: 0.0057 - auc: 0.9862 - val_loss: 0.0081 - val_auc: 0.9154 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9859
# Epoch 00021: val_auc did not improve from 0.92106
#
# Epoch 00021: val_loss did not improve from 0.00655
# 284/284 [==============================] - 316s 1s/step - loss: 0.0057 - auc: 0.9859 - val_loss: 0.0082 - val_auc: 0.9144 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9863
# Epoch 00022: val_auc did not improve from 0.92106
#
# Epoch 00022: val_loss did not improve from 0.00655
# 284/284 [==============================] - 315s 1s/step - loss: 0.0056 - auc: 0.9863 - val_loss: 0.0082 - val_auc: 0.9134 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9877
# Epoch 00023: val_auc did not improve from 0.92106
#
# Epoch 00023: val_loss did not improve from 0.00655
# 284/284 [==============================] - 316s 1s/step - loss: 0.0056 - auc: 0.9877 - val_loss: 0.0084 - val_auc: 0.9144 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0054 - auc: 0.9882
# Epoch 00024: val_auc did not improve from 0.92106
#
# Epoch 00024: val_loss did not improve from 0.00655
# 284/284 [==============================] - 316s 1s/step - loss: 0.0054 - auc: 0.9882 - val_loss: 0.0083 - val_auc: 0.9154 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 562/561 [==============================] - 140s 249ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 235s 249ms/step
# #### FOLD 2 OOF AUC without TTA = 0.921, with TTA = 0.919
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 3
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0559 - auc: 0.5941WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.64647, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01511, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 354s 1s/step - loss: 0.0559 - auc: 0.5941 - val_loss: 0.0151 - val_auc: 0.6465 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0161 - auc: 0.8048
# Epoch 00002: val_auc improved from 0.64647 to 0.84611, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01511 to 0.00709, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0161 - auc: 0.8048 - val_loss: 0.0071 - val_auc: 0.8461 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0141 - auc: 0.8676
# Epoch 00003: val_auc improved from 0.84611 to 0.88893, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00709 to 0.00640, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0141 - auc: 0.8676 - val_loss: 0.0064 - val_auc: 0.8889 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0132 - auc: 0.8962
# Epoch 00004: val_auc improved from 0.88893 to 0.90830, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00640 to 0.00619, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0132 - auc: 0.8962 - val_loss: 0.0062 - val_auc: 0.9083 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0125 - auc: 0.9082
# Epoch 00005: val_auc improved from 0.90830 to 0.91030, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00619 to 0.00603, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0125 - auc: 0.9082 - val_loss: 0.0060 - val_auc: 0.9103 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0116 - auc: 0.9226
# Epoch 00006: val_auc improved from 0.91030 to 0.92777, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00603 to 0.00591, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 324s 1s/step - loss: 0.0116 - auc: 0.9226 - val_loss: 0.0059 - val_auc: 0.9278 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0109 - auc: 0.9356
# Epoch 00007: val_auc improved from 0.92777 to 0.92799, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00591
# 284/284 [==============================] - 320s 1s/step - loss: 0.0109 - auc: 0.9356 - val_loss: 0.0060 - val_auc: 0.9280 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0102 - auc: 0.9452
# Epoch 00008: val_auc improved from 0.92799 to 0.93706, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.00591 to 0.00572, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0102 - auc: 0.9452 - val_loss: 0.0057 - val_auc: 0.9371 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0095 - auc: 0.9547
# Epoch 00009: val_auc improved from 0.93706 to 0.94185, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.00572
# 284/284 [==============================] - 320s 1s/step - loss: 0.0095 - auc: 0.9547 - val_loss: 0.0058 - val_auc: 0.9419 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9598
# Epoch 00010: val_auc improved from 0.94185 to 0.94439, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00010: val_loss did not improve from 0.00572
# 284/284 [==============================] - 321s 1s/step - loss: 0.0090 - auc: 0.9598 - val_loss: 0.0058 - val_auc: 0.9444 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9654
# Epoch 00011: val_auc improved from 0.94439 to 0.94498, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00011: val_loss improved from 0.00572 to 0.00572, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 284/284 [==============================] - 324s 1s/step - loss: 0.0084 - auc: 0.9654 - val_loss: 0.0057 - val_auc: 0.9450 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0081 - auc: 0.9703
# Epoch 00012: val_auc improved from 0.94498 to 0.94561, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00572
# 284/284 [==============================] - 320s 1s/step - loss: 0.0081 - auc: 0.9703 - val_loss: 0.0063 - val_auc: 0.9456 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0073 - auc: 0.9757
# Epoch 00013: val_auc did not improve from 0.94561
#
# Epoch 00013: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0073 - auc: 0.9757 - val_loss: 0.0063 - val_auc: 0.9398 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0074 - auc: 0.9755
# Epoch 00014: val_auc did not improve from 0.94561
#
# Epoch 00014: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0074 - auc: 0.9755 - val_loss: 0.0064 - val_auc: 0.9314 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0070 - auc: 0.9791
# Epoch 00015: val_auc did not improve from 0.94561
#
# Epoch 00015: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0070 - auc: 0.9791 - val_loss: 0.0062 - val_auc: 0.9356 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0066 - auc: 0.9809
# Epoch 00016: val_auc did not improve from 0.94561
#
# Epoch 00016: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0066 - auc: 0.9809 - val_loss: 0.0067 - val_auc: 0.9299 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0065 - auc: 0.9813
# Epoch 00017: val_auc did not improve from 0.94561
#
# Epoch 00017: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0065 - auc: 0.9813 - val_loss: 0.0064 - val_auc: 0.9327 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0064 - auc: 0.9821
# Epoch 00018: val_auc did not improve from 0.94561
#
# Epoch 00018: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0064 - auc: 0.9821 - val_loss: 0.0064 - val_auc: 0.9337 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0061 - auc: 0.9844
# Epoch 00019: val_auc did not improve from 0.94561
#
# Epoch 00019: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0061 - auc: 0.9844 - val_loss: 0.0066 - val_auc: 0.9305 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0058 - auc: 0.9862
# Epoch 00020: val_auc did not improve from 0.94561
#
# Epoch 00020: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0058 - auc: 0.9862 - val_loss: 0.0067 - val_auc: 0.9315 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0060 - auc: 0.9840
# Epoch 00021: val_auc did not improve from 0.94561
#
# Epoch 00021: val_loss did not improve from 0.00572
# 284/284 [==============================] - 315s 1s/step - loss: 0.0060 - auc: 0.9840 - val_loss: 0.0066 - val_auc: 0.9301 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0060 - auc: 0.9862
# Epoch 00022: val_auc did not improve from 0.94561
#
# Epoch 00022: val_loss did not improve from 0.00572
# 284/284 [==============================] - 315s 1s/step - loss: 0.0060 - auc: 0.9862 - val_loss: 0.0065 - val_auc: 0.9295 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0058 - auc: 0.9866
# Epoch 00023: val_auc did not improve from 0.94561
#
# Epoch 00023: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0058 - auc: 0.9866 - val_loss: 0.0065 - val_auc: 0.9295 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9879
# Epoch 00024: val_auc did not improve from 0.94561
#
# Epoch 00024: val_loss did not improve from 0.00572
# 284/284 [==============================] - 316s 1s/step - loss: 0.0056 - auc: 0.9879 - val_loss: 0.0066 - val_auc: 0.9286 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 564/563 [==============================] - 140s 249ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 235s 249ms/step
# #### FOLD 3 OOF AUC without TTA = 0.946, with TTA = 0.954
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 4
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0549 - auc: 0.5942WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.67053, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01444, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 353s 1s/step - loss: 0.0549 - auc: 0.5942 - val_loss: 0.0144 - val_auc: 0.6705 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0157 - auc: 0.8157
# Epoch 00002: val_auc improved from 0.67053 to 0.84265, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01444 to 0.00726, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 324s 1s/step - loss: 0.0157 - auc: 0.8157 - val_loss: 0.0073 - val_auc: 0.8426 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0138 - auc: 0.8787
# Epoch 00003: val_auc improved from 0.84265 to 0.88192, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00726 to 0.00673, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0138 - auc: 0.8787 - val_loss: 0.0067 - val_auc: 0.8819 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0131 - auc: 0.8963
# Epoch 00004: val_auc improved from 0.88192 to 0.91046, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00673 to 0.00645, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.0131 - auc: 0.8963 - val_loss: 0.0065 - val_auc: 0.9105 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0120 - auc: 0.9164
# Epoch 00005: val_auc improved from 0.91046 to 0.91195, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00645 to 0.00619, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0120 - auc: 0.9164 - val_loss: 0.0062 - val_auc: 0.9120 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0121 - auc: 0.9180
# Epoch 00006: val_auc improved from 0.91195 to 0.92044, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00619 to 0.00592, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0121 - auc: 0.9180 - val_loss: 0.0059 - val_auc: 0.9204 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0108 - auc: 0.9400
# Epoch 00007: val_auc improved from 0.92044 to 0.92204, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.00592 to 0.00591, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 328s 1s/step - loss: 0.0108 - auc: 0.9400 - val_loss: 0.0059 - val_auc: 0.9220 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0100 - auc: 0.9464
# Epoch 00008: val_auc improved from 0.92204 to 0.92495, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00591
# 284/284 [==============================] - 324s 1s/step - loss: 0.0100 - auc: 0.9464 - val_loss: 0.0059 - val_auc: 0.9250 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0092 - auc: 0.9584
# Epoch 00009: val_auc improved from 0.92495 to 0.92498, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.00591
# 284/284 [==============================] - 325s 1s/step - loss: 0.0092 - auc: 0.9584 - val_loss: 0.0071 - val_auc: 0.9250 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0088 - auc: 0.9628
# Epoch 00010: val_auc did not improve from 0.92498
#
# Epoch 00010: val_loss did not improve from 0.00591
# 284/284 [==============================] - 320s 1s/step - loss: 0.0088 - auc: 0.9628 - val_loss: 0.0065 - val_auc: 0.9218 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0082 - auc: 0.9669
# Epoch 00011: val_auc improved from 0.92498 to 0.93076, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00011: val_loss improved from 0.00591 to 0.00583, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 284/284 [==============================] - 330s 1s/step - loss: 0.0082 - auc: 0.9669 - val_loss: 0.0058 - val_auc: 0.9308 - lr: 5.3101e-05
# Epoch 12/24
# ...
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0058 - auc: 0.9858
# Epoch 00020: val_auc did not improve from 0.93321
#
# Epoch 00020: val_loss did not improve from 0.00583
# 284/284 [==============================] - 321s 1s/step - loss: 0.0058 - auc: 0.9858 - val_loss: 0.0066 - val_auc: 0.9285 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9867
# Epoch 00021: val_auc did not improve from 0.93321
#
# Epoch 00021: val_loss did not improve from 0.00583
# 284/284 [==============================] - 320s 1s/step - loss: 0.0056 - auc: 0.9867 - val_loss: 0.0068 - val_auc: 0.9297 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9858
# Epoch 00022: val_auc did not improve from 0.93321
#
# Epoch 00022: val_loss did not improve from 0.00583
# 284/284 [==============================] - 320s 1s/step - loss: 0.0057 - auc: 0.9858 - val_loss: 0.0069 - val_auc: 0.9285 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9872
# Epoch 00023: val_auc did not improve from 0.93321
#
# Epoch 00023: val_loss did not improve from 0.00583
# 284/284 [==============================] - 320s 1s/step - loss: 0.0056 - auc: 0.9872 - val_loss: 0.0069 - val_auc: 0.9260 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0053 - auc: 0.9885
# Epoch 00024: val_auc did not improve from 0.93321
#
# Epoch 00024: val_loss did not improve from 0.00583
# 284/284 [==============================] - 320s 1s/step - loss: 0.0053 - auc: 0.9885 - val_loss: 0.0071 - val_auc: 0.9249 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 560/559 [==============================] - 142s 253ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 240s 254ms/step
# #### FOLD 4 OOF AUC without TTA = 0.933, with TTA = 0.935
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.84.243.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.84.243.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 5
# #### Image Size 512 with EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 284/284 [==============================] - ETA: 0s - loss: 0.0555 - auc: 0.6150WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7f0c30f24f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.62438, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.01881, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 284/284 [==============================] - 357s 1s/step - loss: 0.0555 - auc: 0.6150 - val_loss: 0.0188 - val_auc: 0.6244 - lr: 5.0000e-06
# Epoch 2/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0161 - auc: 0.8063
# Epoch 00002: val_auc improved from 0.62438 to 0.84225, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.01881 to 0.00710, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0161 - auc: 0.8063 - val_loss: 0.0071 - val_auc: 0.8422 - lr: 3.6000e-05
# Epoch 3/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0143 - auc: 0.8689
# Epoch 00003: val_auc improved from 0.84225 to 0.87068, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00710 to 0.00689, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 284/284 [==============================] - 330s 1s/step - loss: 0.0143 - auc: 0.8689 - val_loss: 0.0069 - val_auc: 0.8707 - lr: 6.7000e-05
# Epoch 4/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0133 - auc: 0.8932
# Epoch 00004: val_auc improved from 0.87068 to 0.87655, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00689 to 0.00681, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 284/284 [==============================] - 330s 1s/step - loss: 0.0133 - auc: 0.8932 - val_loss: 0.0068 - val_auc: 0.8766 - lr: 9.8000e-05
# Epoch 5/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0123 - auc: 0.9098
# Epoch 00005: val_auc improved from 0.87655 to 0.88913, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.00681
# 284/284 [==============================] - 329s 1s/step - loss: 0.0123 - auc: 0.9098 - val_loss: 0.0080 - val_auc: 0.8891 - lr: 1.2900e-04
# Epoch 6/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0117 - auc: 0.9221
# Epoch 00006: val_auc improved from 0.88913 to 0.90361, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00681 to 0.00615, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 284/284 [==============================] - 327s 1s/step - loss: 0.0117 - auc: 0.9221 - val_loss: 0.0061 - val_auc: 0.9036 - lr: 1.6000e-04
# Epoch 7/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0111 - auc: 0.9360
# Epoch 00007: val_auc improved from 0.90361 to 0.91227, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00615
# 284/284 [==============================] - 322s 1s/step - loss: 0.0111 - auc: 0.9360 - val_loss: 0.0064 - val_auc: 0.9123 - lr: 1.2820e-04
# Epoch 8/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0099 - auc: 0.9500
# Epoch 00008: val_auc improved from 0.91227 to 0.91699, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.00615 to 0.00608, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 284/284 [==============================] - 326s 1s/step - loss: 0.0099 - auc: 0.9500 - val_loss: 0.0061 - val_auc: 0.9170 - lr: 1.0276e-04
# Epoch 9/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0096 - auc: 0.9555
# Epoch 00009: val_auc did not improve from 0.91699
#
# Epoch 00009: val_loss did not improve from 0.00608
# 284/284 [==============================] - 318s 1s/step - loss: 0.0096 - auc: 0.9555 - val_loss: 0.0066 - val_auc: 0.9155 - lr: 8.2408e-05
# Epoch 10/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9647
# Epoch 00010: val_auc improved from 0.91699 to 0.91924, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00010: val_loss did not improve from 0.00608
# 284/284 [==============================] - 322s 1s/step - loss: 0.0087 - auc: 0.9647 - val_loss: 0.0064 - val_auc: 0.9192 - lr: 6.6126e-05
# Epoch 11/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0084 - auc: 0.9667
# Epoch 00011: val_auc improved from 0.91924 to 0.92015, saving model to 512-EffNetB6-BS16-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00011: val_loss did not improve from 0.00608
# 284/284 [==============================] - 322s 1s/step - loss: 0.0084 - auc: 0.9667 - val_loss: 0.0062 - val_auc: 0.9202 - lr: 5.3101e-05
# Epoch 12/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0076 - auc: 0.9742
# Epoch 00012: val_auc did not improve from 0.92015
#
# Epoch 00012: val_loss did not improve from 0.00608
# 284/284 [==============================] - 317s 1s/step - loss: 0.0076 - auc: 0.9742 - val_loss: 0.0066 - val_auc: 0.9167 - lr: 4.2681e-05
# Epoch 13/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0074 - auc: 0.9764
# Epoch 00013: val_auc did not improve from 0.92015
#
# Epoch 00013: val_loss did not improve from 0.00608
# 284/284 [==============================] - 317s 1s/step - loss: 0.0074 - auc: 0.9764 - val_loss: 0.0071 - val_auc: 0.9133 - lr: 3.4345e-05
# Epoch 14/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0070 - auc: 0.9790
# Epoch 00014: val_auc did not improve from 0.92015
#
# Epoch 00014: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0070 - auc: 0.9790 - val_loss: 0.0069 - val_auc: 0.9161 - lr: 2.7676e-05
# Epoch 15/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0067 - auc: 0.9811
# Epoch 00015: val_auc did not improve from 0.92015
#
# Epoch 00015: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0067 - auc: 0.9811 - val_loss: 0.0073 - val_auc: 0.9149 - lr: 2.2341e-05
# Epoch 16/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0065 - auc: 0.9829
# Epoch 00016: val_auc did not improve from 0.92015
#
# Epoch 00016: val_loss did not improve from 0.00608
# 284/284 [==============================] - 317s 1s/step - loss: 0.0065 - auc: 0.9829 - val_loss: 0.0072 - val_auc: 0.9173 - lr: 1.8072e-05
# Epoch 17/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0063 - auc: 0.9841
# Epoch 00017: val_auc did not improve from 0.92015
#
# Epoch 00017: val_loss did not improve from 0.00608
# 284/284 [==============================] - 318s 1s/step - loss: 0.0063 - auc: 0.9841 - val_loss: 0.0073 - val_auc: 0.9138 - lr: 1.4658e-05
# Epoch 18/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0061 - auc: 0.9856
# Epoch 00018: val_auc did not improve from 0.92015
#
# Epoch 00018: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0061 - auc: 0.9856 - val_loss: 0.0072 - val_auc: 0.9132 - lr: 1.1926e-05
# Epoch 19/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0059 - auc: 0.9858
# Epoch 00019: val_auc did not improve from 0.92015
#
# Epoch 00019: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0059 - auc: 0.9858 - val_loss: 0.0072 - val_auc: 0.9106 - lr: 9.7411e-06
# Epoch 20/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0060 - auc: 0.9854
# Epoch 00020: val_auc did not improve from 0.92015
#
# Epoch 00020: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0060 - auc: 0.9854 - val_loss: 0.0072 - val_auc: 0.9096 - lr: 7.9929e-06
# Epoch 21/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9872
# Epoch 00021: val_auc did not improve from 0.92015
#
# Epoch 00021: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0057 - auc: 0.9872 - val_loss: 0.0072 - val_auc: 0.9111 - lr: 6.5943e-06
# Epoch 22/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9876
# Epoch 00022: val_auc did not improve from 0.92015
#
# Epoch 00022: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0056 - auc: 0.9876 - val_loss: 0.0074 - val_auc: 0.9104 - lr: 5.4755e-06
# Epoch 23/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9871
# Epoch 00023: val_auc did not improve from 0.92015
#
# Epoch 00023: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0056 - auc: 0.9871 - val_loss: 0.0074 - val_auc: 0.9099 - lr: 4.5804e-06
# Epoch 24/24
# 284/284 [==============================] - ETA: 0s - loss: 0.0055 - auc: 0.9876
# Epoch 00024: val_auc did not improve from 0.92015
#
# Epoch 00024: val_loss did not improve from 0.00608
# 284/284 [==============================] - 316s 1s/step - loss: 0.0055 - auc: 0.9876 - val_loss: 0.0073 - val_auc: 0.9088 - lr: 3.8643e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 564/563 [==============================] - 140s 249ms/step
# Predicting Test with TTA...
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None,)), types: (tf.float32, tf.int32)>
# 944/943 [==============================] - 237s 251ms/step
# #### FOLD 5 OOF AUC without TTA = 0.920, with TTA = 0.927

# %%
preds_by_fold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9372ce6ceb8a> in <module>()
# ----> 1 preds_by_fold
#
# NameError: name 'preds_by_fold' is not defined

# %% [markdown]
# ## Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred); 
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names); folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{MODEL}/oof.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.936
#      image_name  target      pred  fold
# 0  ISIC_2637011       0  0.039909     0
# 1  ISIC_0076262       0  0.038730     0
# 2  ISIC_0074268       0  0.006396     0
# 3  ISIC_0015719       0  0.006466     0
# 4  ISIC_0082543       0  0.020784     0

# %%
auc_oof = 0.0
for i in range(FOLDS):
  auc_oof += roc_auc_score(oof_tar[i], oof_pred[i]) / FOLDS
print('Average OOF AUC with TTA = %.3f'%auc_oof)
# Out:
# Average OOF AUC with TTA = 0.936

# %% [markdown]
# # Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.
#
# Aqui, hauriem de posar les features amb XGB, CB, o el que sigui
# OptimizeAUC() del llibre de l'Abishek per trobar els pesos de diferents models per a cada fold
#
# I fer servir el OptimizeAUC per veure els pesos de la metadata

# %% [markdown]
# # Submit To Kaggle

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{MODEL}/submission.csv', index=False)
submission.head()
# Out:
#         image_name    target
# 9905  ISIC_0052060  0.020624
# 1443  ISIC_0052349  0.012190
# 3120  ISIC_0058510  0.018504
# 4870  ISIC_0073313  0.015615
# 5494  ISIC_0073502  0.050831

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
out_preds_by_fold = np.append(np.vstack(image_names), preds_by_fold, 1)
submission_by_fold = pd.DataFrame(out_preds_by_fold)

# #submission = submission.sort_values('image_name') 
submission_by_fold.to_csv(f'{MODEL}/preds_by_fold.csv', index=False)
submission_by_fold.head()
# submission.shape
# Out:
#               0  ...                     5
# 0  ISIC_2272503  ...   0.01127157174050808
# 1  ISIC_9821912  ...  0.018324101343750954
# 2  ISIC_4347483  ...  0.013732219114899635
# 3  ISIC_6645719  ...   0.05518374219536781
# 4  ISIC_0456797  ...  0.003535243682563305
#
# [5 rows x 6 columns]

# %%
preds_by_fold.shape
# Out:
# (10982, 5)

# %%
from scipy.stats import rankdata

ranked_submission = pd.DataFrame(dict(image_name=image_names, target=0))

ranked_submission['target'] = 0
for i in range(FOLDS):
    ranked_submission['target'] += rankdata(preds_by_fold[:,i]) / (FOLDS)

ranked_submission = ranked_submission.sort_values('image_name')

# %%
ranked_submission.head(100)
# Out:
#         image_name   target
# 9905  ISIC_0052060   3123.8
# 1443  ISIC_0052349   1649.0
# 3120  ISIC_0058510   2943.8
# 4870  ISIC_0073313   2255.2
# 5494  ISIC_0073502   6432.0
# ...            ...      ...
# 1215  ISIC_0200120  10634.8
# 7001  ISIC_0204399    767.6
# 9720  ISIC_0204875   4068.8
# 4634  ISIC_0205627   3448.2
# 8235  ISIC_0206261   5771.8
#
# [100 rows x 2 columns]

# %%
ranked_submission['target'].mean()
# Out:
# 5491.500000000016

# %%
ranked_submission.to_csv(f'{MODEL}/submission_ranked.csv', index=False)

plt.hist(ranked_submission.target,bins=100)
plt.show()

# %%
import os
src = f'/content/{MODEL}'
dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}"'
os.system(f"rm -rf {dest}")
os.system(f"cp -rf {src} {dest}")
print (src)
print(dest)

# %%
import re
import json
import requests
import ipykernel
from notebook.notebookapp import list_running_servers
from requests.compat import urljoin

def get_notebook_name():
    """
    Return the full path of the jupyter notebook.
    """
    kernel_id = re.search('kernel-(.*).json', ipykernel.connect.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in response.json():
            if nn['kernel']['id'] == kernel_id:
                notebook_name = nn['notebook']['name']
                return notebook_name

NOTEBOOK_NAME = get_notebook_name()
copyNotebook = f'cp "/content/gdrive/My Drive/Colab Notebooks/{NOTEBOOK_NAME}" "/content/gdrive/My Drive/saved_models/{MODEL}/train.ipynb"'
os.system(copyNotebook)

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission.csv -m "{MODEL}"

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission_ranked.csv -m "{MODEL}-Ranked"
