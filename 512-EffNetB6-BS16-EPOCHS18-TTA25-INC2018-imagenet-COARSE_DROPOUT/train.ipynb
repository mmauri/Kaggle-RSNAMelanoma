# %% [markdown]
# # Triple Stratified KFold CV with TFRecords
# This is a simple starter notebook for Kaggle's Melanoma Comp showing triple stratifed KFold with TFRecords. Triple stratified KFold is explained [here][2]. There are many configuration variables below to allow you to experiment. Use either GPU or TPU. You can control which size images are loaded, which efficientNets are used, and whether external data is used. You can experiment with different data augmentation, model architecture, loss, optimizers, and learning schedules. The TFRecords contain meta data, so you can input that into your CNN too.
#
# **NOTE:** this notebook lets you run a different experiment in each fold if you want to run lots of experiments. (Then it is like running multiple holdout validaiton experiments but in that case note that the overall CV score is meaningless because LB will be much higher when the multiple experiments are ensembled to predict test). **If you want a proper CV with a reliable overall CV score you need to choose the same configuration for each fold.**
#
# This notebook follows the 5 step process presented in my "How to compete with GPUs Workshop" [here][1]. Some code sections have been reused from AgentAuers' great notebook [here][3]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/gdrive/My Drive/Kaggle/kaggle.json" ~/.kaggle

# %%
# install tf 2.2 following kaggle post instructions

# !pip install tensorflow~=2.2.0 tensorflow_gcs_config~=2.2.0
import tensorflow as tf
import requests
import os
resp = requests.post("http://{}:8475/requestversion/{}".format(os.environ["COLAB_TPU_ADDR"].split(":")[0], tf.__version__))
if resp.status_code != 200:
  print("Failed to switch the TPU to TF {}".format(version))
# Out:
# Collecting tensorflow~=2.2.0
#   Downloading https://files.pythonhosted.org/packages/3d/be/679ce5254a8c8d07470efb4a4c00345fae91f766e64f1c2aece8796d7218/tensorflow-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████████████████████████| 516.2MB 15kB/s
# Collecting tensorflow_gcs_config~=2.2.0
#   Downloading https://files.pythonhosted.org/packages/67/0b/c6fe9b75ba3999c10b7ab77e7d4019c90344bb79609a9378355ca6712598/tensorflow_gcs_config-2.2.0-py3-none-any.whl (392kB)
#      |████████████████████████████████| 399kB 41.3MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.1.0)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 64.7MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (3.12.4)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.15.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.4.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (2.10.0)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/a4/f5/926ae53d6a226ec0fda5208e0e581cffed895ccc89e36ba76a8e60895b78/tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454kB)
#      |████████████████████████████████| 460kB 62.8MB/s
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.6.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (0.34.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.30.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow~=2.2.0) (1.18.5)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (0.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (49.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.0.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (1.7.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow~=2.2.0) (3.1.0)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow, tensorflow-gcs-config
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
#   Found existing installation: tensorflow-gcs-config 2.3.0
#     Uninstalling tensorflow-gcs-config-2.3.0:
#       Successfully uninstalled tensorflow-gcs-config-2.3.0
# Successfully installed tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0 tensorflow-gcs-config-2.2.0

# %% [markdown]
# # Initialize Environment

# %%
# !pip install -q efficientnet >> /dev/null

# %%
import cv2, matplotlib.pyplot as plt
import gc
import pandas as pd, numpy as np
#from kaggle_datasets import KaggleDatasets
import tensorflow as tf, re, math
import tensorflow.keras.backend as K
import efficientnet.tfkeras as efn
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %% [markdown]
# ## Configuration
# In order to be a proper cross validation with a meaningful overall CV score (aligned with LB score), **you need to choose the same** `IMG_SIZES`, `INC2019`, `INC2018`, and `EFF_NETS` **for each fold**. If your goal is to just run lots of experiments, then you can choose to have a different experiment in each fold. Then each fold is like a holdout validation experiment. When you find a configuration you like, you can use that configuration for all folds.
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 but can be any number between 2 and 15
# * IMG_SIZES - is a Python list of length FOLDS. These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - is a list of length FOLDS. These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - is a list of length FOLDS. These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter.
# * EFF_NETS - is a list of length FOLDS. These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %%
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 42

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 

IMG_SIZES = [384,384,384,384,384]
IMG_SIZES = [768]*FOLDS
IMG_SIZES =  [512,512,512,512,512]


# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0,0,0,0,0]
INC2018 = [1,1,1,1,1]

# BATCH SIZE AND EPOCHS
BATCH_SIZES = [16]*FOLDS #[32]*FOLDS
EPOCHS = [18]*FOLDS #12 18

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [7,7,7,7,7]
EFF_NETS = [3,3,3,3,3]
EFF_NETS = [6,6,6,6,6]

#MODEL_NAME = 'ResNet152' #EfficientNetB0


DROP_FREQ = [0.75] * FOLDS # between 0 and 1
DROP_CT = [8] * FOLDS # may slow training if CT>16
DROP_SIZE = [0.2] *FOLDS # between 0 and 1

EFF_NET_PRETRAIN = 'imagenet' #''noisy-student

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 25

#Treure de Kaggle
if IMG_SIZES[0]==384:
  #384 images
  GCS1="gs://kds-71b679af6661316328cfa122f5342b4a84fe0c7c1135d809fbee8ca4" #384
  GCS2="gs://kds-9fc526a7f92f5454bc790655a916878883ad270d1e13c91e7d527659"#384
elif IMG_SIZES[0]==512:
  #512
  GCS1='gs://kds-458e4ec4a30e5d927b21efd0633fb2c0a091245fe8db3c415fde5da6'
  GCS2='gs://kds-203bea6cc14c2866536ac303b09a6e77a6b3d0a371e96b680836433c'
elif IMG_SIZES[0]==768:
  GCS1='gs://kds-cfb16ed5f55adb5ab35a75a2fe74c3dc11a4b869dc8cfb3d9b1759e1'
  GCS2='gs://kds-79d9c56dcae7978f98a6bbe8318ac6866ba4778fc95c5871fcfd0f03'
  
  

else:
  raise error

MODEL = f'{IMG_SIZES[0]}-EffNetB{EFF_NETS[0]}-BS{BATCH_SIZES[0]}-EPOCHS{EPOCHS[0]}-TTA{TTA}-INC2018-{EFF_NET_PRETRAIN}-COARSE_DROPOUT'
#MODEL = f'{IMG_SIZES[0]}-{MODEL_NAME}-BS{BATCH_SIZES[0]}-EPOCHS{EPOCHS[0]}-TTA{TTA}-INC2018-FOCAL-{EFF_NET_PRETRAIN}-COARSE_DROPOUT'
print(MODEL)
# Out:
# 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT

# %%
import os
if not os.path.exists(f'/content/{MODEL}'):
    os.mkdir(f'/content/{MODEL}')

# %%
dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}/"'
print(dest)
if not os.path.exists(dest):
    # !mkdir {dest}
# Out:
# "/content/gdrive/My Drive/saved_models/512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/"

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and single GPU")
    strategy = tf.distribute.get_strategy()

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
# Out:
# connecting to TPU...
# Running on TPU  grpc://10.13.29.170:8470
# initializing  TPU ...
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# TPU initialized

# %% [markdown]
# # Step 1: Preprocess
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section. These TFRecords are discussed [here][1]. The advantage of using different input sizes is discussed [here][2]
#
# [1]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/155579
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147

# %%
GCS_PATH = [None]*FOLDS; GCS_PATH2 = [None]*FOLDS

for i,k in enumerate(IMG_SIZES):
    GCS_PATH[i] = GCS1
    GCS_PATH2[i] = GCS2

files_train = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/train*.tfrec')))
files_test  = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/test*.tfrec')))

# %% [markdown]
# # Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation first shown in this notebook [here][1] and successfully used in Melanoma comp by AgentAuers [here][2]. This notebook also uses horizontal flip, hue, saturation, contrast, brightness augmentation similar to last years winner and also similar to AgentAuers' notebook.
#
# Additionally we can decide to use external data by changing the variables `INC2019` and `INC2018` in the preceeding code section. These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][3]
#
# Consider experimenting with different augmenation and/or external data. The code to load TFRecords is taken from AgentAuers' notebook [here][2]. Thank you AgentAuers, this is great work.
#
# [1]: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
# [2]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [3]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %%
ROT_ = 180.0 #90.0 al submit anterior
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def dropout(image, DIM=256, PROBABILITY = 0.75, CT = 8, SZ = 0.2):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image with CT squares of side size SZ*DIM removed
    
    # DO DROPOUT WITH PROBABILITY DEFINED ABOVE
    P = tf.cast( tf.random.uniform([],0,1)<PROBABILITY, tf.int32)
    if (P==0)|(CT==0)|(SZ==0): return image
    
    for k in range(CT):
        # CHOOSE RANDOM LOCATION
        x = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        y = tf.cast( tf.random.uniform([],0,DIM),tf.int32)
        # COMPUTE SQUARE 
        WIDTH = tf.cast( SZ*DIM,tf.int32) * P
        ya = tf.math.maximum(0,y-WIDTH//2)
        yb = tf.math.minimum(DIM,y+WIDTH//2)
        xa = tf.math.maximum(0,x-WIDTH//2)
        xb = tf.math.minimum(DIM,x+WIDTH//2)
        # DROPOUT IMAGE
        one = image[ya:yb,0:xa,:]
        # two = tf.zeros([yb-ya,xb-xa,3],tf.bfloat16) 
        two = tf.zeros([yb-ya,xb-xa,3])
        three = image[ya:yb,xb:DIM,:]
        middle = tf.concat([one,two,three],axis=1)
        image = tf.concat([image[0:ya,:,:],middle,image[yb:DIM,:,:]],axis=0)
            
    # RESHAPE HACK SO TPU COMPILER KNOWS SHAPE OF OUTPUT TENSOR 
    image = tf.reshape(image,[DIM,DIM,3])
    return image

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

# %%
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    #return example['image'], example['target']
    return example['image'], tf.cast(example['target'],tf.float32)
    # return example['image'], tf.cast(example['target'],tf.bfloat16)


def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

 
def prepare_image(img, augment=True, dim=256, droprate=0, dropct=0, dropsize=0):    
    img = tf.image.decode_jpeg(img, channels=3)
    # img = tf.cast(img, tf.bfloat16) / 255.0
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        if (droprate!=0)&(dropct!=0)&(dropsize!=0): 
            img = dropout(img, DIM=dim, PROBABILITY=droprate, CT=dropct, SZ=dropsize)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)

    # img = tf.cast(img, tf.bfloat16)              
    img = tf.reshape(img, [dim,dim, 3])
        
    return img

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256,
                droprate=0, dropct=0, dropsize=0):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*2) #if too large causes OOM in GPU CPU
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO)      
    
    ds = ds.map(lambda img, imgname_or_label: (
                prepare_image(img, augment=augment, dim=dim, 
                              droprate=droprate, dropct=dropct, dropsize=dropsize), 
                imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %% [markdown]
# # Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN.

# %%
import tensorflow_addons as tfa

EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7, efn.EfficientNetL2]

def build_model(dim=128, ef=0):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EFNS[ef](input_shape=(dim,dim,3),weights=EFF_NET_PRETRAIN,include_top=False)
    #base.trainable = True
    #print(base.trainable)
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    # loss = tfa.losses.SigmoidFocalCrossEntropy()
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    return model

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
#from tensorflow.keras.applications.resnet_v2
from tensorflow.keras.applications import DenseNet121
import tensorflow.keras.applications.inception_resnet_v2 as InceptionResnetV2
from tensorflow.keras.models import Sequential , Model
from tensorflow.keras.layers import Dense, Conv2D, ReLU, Dropout, Flatten, Activation, GlobalAveragePooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization

# %%
import tensorflow_addons as tfa

bool_focal_loss = True
bool_label_smoothing = False

def get_model():
    name = MODEL_NAME
    img_size = IMG_SIZES[0]

    if name == "EfficientNetB0":        
        base_model = tf.keras.applications.EfficientNetB0(weights='noisy-student',
                               include_top = False,
                               input_shape=(img_size,img_size,3)
                              )            
    elif name == 'ResNet50':
        base_model = ResNet50(weights='imagenet',
                              include_top=False,
                              input_shape=(img_size,img_size,3))
    elif name == 'ResNet152':
        base_model = ResNet152V2(weights='imagenet',
                              include_top=False,
                              input_shape=(img_size,img_size,3))
    elif name == 'DenseNet121':       
        base_model = DenseNet121(weights='imagenet',
                                 include_top=False,
                                 input_shape=(img_size,img_size,3))
    elif name == 'MobileNet':
        base_model = MobileNet(weights='imagenet', 
                               include_top=False,
                               input_shape=(img_size,img_size,3))
    elif name == 'IncepResnet':       
        base_model = InceptionResNetV2(weights='imagenet',
                                       include_top=False,
                                       input_shape=(img_size,img_size,3))
    elif name=="ResNet50V2":
        base_model = ResNet50V2(weights='imagenet',
                                       include_top=False,
                                       input_shape=(img_size,img_size,3))

          
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    # x = L.Dense(1024,activation='relu')(x)
    # x = L.Dropout(0.5)(x,training=True)
    predictions = Dense(1 ,activation='sigmoid')(x)
    
    if bool_focal_loss : 
        my_loss= tfa.losses.SigmoidFocalCrossEntropy(reduction=tf.keras.losses.Reduction.AUTO)
    elif bool_label_smoothing :
        my_loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1)
    else :
        my_loss = 'binary_crossentropy'

    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model = Model(inputs=base_model.input, outputs=predictions)
    #model.compile(optimizer=opt, loss=my_loss, metrics=['accuracy', tf.keras.metrics.AUC()])
    model.compile(optimizer=opt,loss=my_loss,metrics=['AUC'])  
    
    return model

# %% [markdown]
# # Step 4: Train Schedule
# This is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
lr_start   = 0.000005
lr_max     = 0.00000125 * REPLICAS * BATCH_SIZES[0]
lr_min     = 0.000001
lr_ramp_ep = 5
lr_sus_ep  = 0
lr_decay   = 0.8

def lrfn(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        
    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max
        
    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
        
    return lr


rng = [i for i in range(EPOCHS[0])]
y = [lrfn(x) for x in rng]
plt.plot(rng, [lrfn(x) for x in rng])
print(y[0], y[-1])
# Out:
# 5e-06 1.1926396801024009e-05

# %%
def get_lr_callback(batch_size=8):
    lr_start   = 0.000005
    lr_max     = 0.00000125 * REPLICAS * batch_size
    lr_min     = 0.000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback

# %% [markdown]
# ## Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []; oof_tar = []; oof_val = []; oof_names = []; oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_by_fold = np.empty([count_data_items(files_test), FOLDS], dtype=float)

for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
  #if fold==4:
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25); print('#### FOLD',fold+1)
    print('#### Image Size %i with {MODEL_NAME} EfficientNet B%i and batch_size %i'%
          (IMG_SIZES[fold],EFF_NETS[fold],BATCH_SIZES[fold]*REPLICAS))
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[fold] + '/test*.tfrec')))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold])
        # model = get_model()
        
    # SAVE BEST MODEL EACH FOLD
    checkpoint_file_best_AUC = f'{MODEL}/fold-%i-bestAUC.h5'%fold
    sv = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file_best_AUC, monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    checkpoint_file_best_loss = f'{MODEL}/fold-%i-bestloss.h5'%fold
    sv2 = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file_best_loss, monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold],
                droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold]), 
        epochs=EPOCHS[fold], callbacks = [sv,sv2,get_lr_callback(BATCH_SIZES[fold])], 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid,augment=False,shuffle=False,
                repeat=False,dim=IMG_SIZES[fold], batch_size=BATCH_SIZES[fold]), #class_weight = {0:1,1:2},
        verbose=VERBOSE
    )
    
    #save a copy iof the model to gdrive
    dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}/"'
    os.system(f"cp -rf {checkpoint_file_best_loss} {dest}")
    os.system(f"cp -rf {checkpoint_file_best_AUC} {dest}")
    print('Loading best model val loss...')
    model.load_weights(checkpoint_file_best_loss)

    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold],
            droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    #oof_pred.append(model.predict(get_dataset(files_valid,dim=IMG_SIZES[fold]),verbose=1))

    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))

    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold],
            droprate=DROP_FREQ[fold], dropct=DROP_CT[fold], dropsize=DROP_SIZE[fold])
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,] 
    tta_mean = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += tta_mean * WGTS[fold]
    #new

    preds_by_fold[:,fold] = tta_mean


    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print('#### FOLD %i OOF AUC without TTA = %.3f, with TTA = %.3f'%(fold+1,oof_val[-1],auc))
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] ); y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold]),size=18)
        plt.legend(loc=3)
        plt.show()
        #break
      
    del model
    z = gc.collect()
# Out:
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 1
# #### Image Size 512 with {MODEL_NAME} EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b6_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 165527552/165527152 [==============================] - 2s 0us/step
# Training...
# Epoch 1/18
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 284/284 [==============================] - ETA: 0s - loss: 0.4609 - auc: 0.6337
# Epoch 00001: val_auc improved from -inf to 0.67844, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.23121, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 353s 1s/step - loss: 0.4609 - auc: 0.6337 - val_loss: 0.2312 - val_auc: 0.6784 - lr: 5.0000e-06
# Epoch 2/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2370 - auc: 0.8129
# Epoch 00002: val_auc improved from 0.67844 to 0.82959, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.23121 to 0.16870, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.2370 - auc: 0.8129 - val_loss: 0.1687 - val_auc: 0.8296 - lr: 3.6000e-05
# Epoch 3/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2248 - auc: 0.8705
# Epoch 00003: val_auc improved from 0.82959 to 0.87546, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.16870 to 0.16542, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.2248 - auc: 0.8705 - val_loss: 0.1654 - val_auc: 0.8755 - lr: 6.7000e-05
# Epoch 4/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2188 - auc: 0.8846
# Epoch 00004: val_auc improved from 0.87546 to 0.89596, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.16542 to 0.16280, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.2188 - auc: 0.8846 - val_loss: 0.1628 - val_auc: 0.8960 - lr: 9.8000e-05
# Epoch 5/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2143 - auc: 0.8970
# Epoch 00005: val_auc improved from 0.89596 to 0.89987, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.16280 to 0.16183, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.2143 - auc: 0.8970 - val_loss: 0.1618 - val_auc: 0.8999 - lr: 1.2900e-04
# Epoch 6/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2093 - auc: 0.9092
# Epoch 00006: val_auc did not improve from 0.89987
#
# Epoch 00006: val_loss did not improve from 0.16183
# 284/284 [==============================] - 311s 1s/step - loss: 0.2093 - auc: 0.9092 - val_loss: 0.1632 - val_auc: 0.8928 - lr: 1.6000e-04
# Epoch 7/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2056 - auc: 0.9167
# Epoch 00007: val_auc improved from 0.89987 to 0.91111, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.16183 to 0.16160, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2056 - auc: 0.9167 - val_loss: 0.1616 - val_auc: 0.9111 - lr: 1.2820e-04
# Epoch 8/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1982 - auc: 0.9309
# Epoch 00008: val_auc did not improve from 0.91111
#
# Epoch 00008: val_loss improved from 0.16160 to 0.16023, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 315s 1s/step - loss: 0.1982 - auc: 0.9309 - val_loss: 0.1602 - val_auc: 0.9093 - lr: 1.0276e-04
# Epoch 9/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1943 - auc: 0.9392
# Epoch 00009: val_auc improved from 0.91111 to 0.91319, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.16023 to 0.15936, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.1943 - auc: 0.9392 - val_loss: 0.1594 - val_auc: 0.9132 - lr: 8.2408e-05
# Epoch 10/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1921 - auc: 0.9414
# Epoch 00010: val_auc did not improve from 0.91319
#
# Epoch 00010: val_loss did not improve from 0.15936
# 284/284 [==============================] - 311s 1s/step - loss: 0.1921 - auc: 0.9414 - val_loss: 0.1596 - val_auc: 0.9104 - lr: 6.6126e-05
# Epoch 11/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1885 - auc: 0.9465
# Epoch 00011: val_auc did not improve from 0.91319
#
# Epoch 00011: val_loss did not improve from 0.15936
# 284/284 [==============================] - 311s 1s/step - loss: 0.1885 - auc: 0.9465 - val_loss: 0.1595 - val_auc: 0.9118 - lr: 5.3101e-05
# Epoch 12/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1867 - auc: 0.9507
# Epoch 00012: val_auc improved from 0.91319 to 0.91854, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00012: val_loss improved from 0.15936 to 0.15875, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.1867 - auc: 0.9507 - val_loss: 0.1588 - val_auc: 0.9185 - lr: 4.2681e-05
# Epoch 13/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1833 - auc: 0.9531
# Epoch 00013: val_auc improved from 0.91854 to 0.92404, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestAUC.h5
#
# Epoch 00013: val_loss improved from 0.15875 to 0.15837, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-0-bestloss.h5
# 284/284 [==============================] - 318s 1s/step - loss: 0.1833 - auc: 0.9531 - val_loss: 0.1584 - val_auc: 0.9240 - lr: 3.4345e-05
# Epoch 14/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1808 - auc: 0.9597
# Epoch 00014: val_auc did not improve from 0.92404
#
# Epoch 00014: val_loss did not improve from 0.15837
# 284/284 [==============================] - 312s 1s/step - loss: 0.1808 - auc: 0.9597 - val_loss: 0.1586 - val_auc: 0.9233 - lr: 2.7676e-05
# Epoch 15/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1795 - auc: 0.9601
# Epoch 00015: val_auc did not improve from 0.92404
#
# Epoch 00015: val_loss did not improve from 0.15837
# 284/284 [==============================] - 311s 1s/step - loss: 0.1795 - auc: 0.9601 - val_loss: 0.1631 - val_auc: 0.9203 - lr: 2.2341e-05
# Epoch 16/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1777 - auc: 0.9640
# Epoch 00016: val_auc did not improve from 0.92404
#
# Epoch 00016: val_loss did not improve from 0.15837
# 284/284 [==============================] - 311s 1s/step - loss: 0.1777 - auc: 0.9640 - val_loss: 0.1601 - val_auc: 0.9187 - lr: 1.8072e-05
# Epoch 17/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1780 - auc: 0.9612
# Epoch 00017: val_auc did not improve from 0.92404
#
# Epoch 00017: val_loss did not improve from 0.15837
# 284/284 [==============================] - 311s 1s/step - loss: 0.1780 - auc: 0.9612 - val_loss: 0.1610 - val_auc: 0.9199 - lr: 1.4658e-05
# Epoch 18/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1764 - auc: 0.9618
# Epoch 00018: val_auc did not improve from 0.92404
#
# Epoch 00018: val_loss did not improve from 0.15837
# 284/284 [==============================] - 310s 1s/step - loss: 0.1764 - auc: 0.9618 - val_loss: 0.1610 - val_auc: 0.9208 - lr: 1.1926e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 1277/1276 [==============================] - 323s 253ms/step
# Predicting Test with TTA...
# 2145/2144 [==============================] - 547s 255ms/step
# #### FOLD 1 OOF AUC without TTA = 0.924, with TTA = 0.926
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 2
# #### Image Size 512 with {MODEL_NAME} EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# 284/284 [==============================] - ETA: 0s - loss: 0.4440 - auc: 0.6412
# Epoch 00001: val_auc improved from -inf to 0.67681, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.22729, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 347s 1s/step - loss: 0.4440 - auc: 0.6412 - val_loss: 0.2273 - val_auc: 0.6768 - lr: 5.0000e-06
# Epoch 2/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2374 - auc: 0.8139
# Epoch 00002: val_auc improved from 0.67681 to 0.81126, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.22729 to 0.16960, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2374 - auc: 0.8139 - val_loss: 0.1696 - val_auc: 0.8113 - lr: 3.6000e-05
# Epoch 3/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2249 - auc: 0.8664
# Epoch 00003: val_auc improved from 0.81126 to 0.84409, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.16960 to 0.16858, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2249 - auc: 0.8664 - val_loss: 0.1686 - val_auc: 0.8441 - lr: 6.7000e-05
# Epoch 4/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2173 - auc: 0.8838
# Epoch 00004: val_auc improved from 0.84409 to 0.86222, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.16858 to 0.16628, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2173 - auc: 0.8838 - val_loss: 0.1663 - val_auc: 0.8622 - lr: 9.8000e-05
# Epoch 5/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2129 - auc: 0.8976
# Epoch 00005: val_auc improved from 0.86222 to 0.87131, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.16628 to 0.16552, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2129 - auc: 0.8976 - val_loss: 0.1655 - val_auc: 0.8713 - lr: 1.2900e-04
# Epoch 6/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2081 - auc: 0.9131
# Epoch 00006: val_auc improved from 0.87131 to 0.87303, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.16552 to 0.16509, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.2081 - auc: 0.9131 - val_loss: 0.1651 - val_auc: 0.8730 - lr: 1.6000e-04
# Epoch 7/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2025 - auc: 0.9221
# Epoch 00007: val_auc improved from 0.87303 to 0.88110, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.16509 to 0.16383, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2025 - auc: 0.9221 - val_loss: 0.1638 - val_auc: 0.8811 - lr: 1.2820e-04
# Epoch 8/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1988 - auc: 0.9295
# Epoch 00008: val_auc improved from 0.88110 to 0.88486, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.16383 to 0.16359, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.1988 - auc: 0.9295 - val_loss: 0.1636 - val_auc: 0.8849 - lr: 1.0276e-04
# Epoch 9/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1932 - auc: 0.9387
# Epoch 00009: val_auc improved from 0.88486 to 0.89893, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.16359 to 0.16185, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-1-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.1932 - auc: 0.9387 - val_loss: 0.1619 - val_auc: 0.8989 - lr: 8.2408e-05
# Epoch 10/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1877 - auc: 0.9460
# Epoch 00010: val_auc did not improve from 0.89893
#
# Epoch 00010: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1877 - auc: 0.9460 - val_loss: 0.1627 - val_auc: 0.8855 - lr: 6.6126e-05
# Epoch 11/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1870 - auc: 0.9480
# Epoch 00011: val_auc did not improve from 0.89893
#
# Epoch 00011: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1870 - auc: 0.9480 - val_loss: 0.1637 - val_auc: 0.8925 - lr: 5.3101e-05
# Epoch 12/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1845 - auc: 0.9503
# Epoch 00012: val_auc did not improve from 0.89893
#
# Epoch 00012: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1845 - auc: 0.9503 - val_loss: 0.1637 - val_auc: 0.8887 - lr: 4.2681e-05
# Epoch 13/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1829 - auc: 0.9559
# Epoch 00013: val_auc did not improve from 0.89893
#
# Epoch 00013: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1829 - auc: 0.9559 - val_loss: 0.1637 - val_auc: 0.8924 - lr: 3.4345e-05
# Epoch 14/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1812 - auc: 0.9577
# Epoch 00014: val_auc did not improve from 0.89893
#
# Epoch 00014: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1812 - auc: 0.9577 - val_loss: 0.1639 - val_auc: 0.8862 - lr: 2.7676e-05
# Epoch 15/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1784 - auc: 0.9590
# Epoch 00015: val_auc did not improve from 0.89893
#
# Epoch 00015: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1784 - auc: 0.9590 - val_loss: 0.1638 - val_auc: 0.8734 - lr: 2.2341e-05
# Epoch 16/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1769 - auc: 0.9616
# Epoch 00016: val_auc did not improve from 0.89893
#
# Epoch 00016: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1769 - auc: 0.9616 - val_loss: 0.1660 - val_auc: 0.8777 - lr: 1.8072e-05
# Epoch 17/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1771 - auc: 0.9632
# Epoch 00017: val_auc did not improve from 0.89893
#
# Epoch 00017: val_loss did not improve from 0.16185
# 284/284 [==============================] - 314s 1s/step - loss: 0.1771 - auc: 0.9632 - val_loss: 0.1644 - val_auc: 0.8789 - lr: 1.4658e-05
# Epoch 18/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1764 - auc: 0.9623
# Epoch 00018: val_auc did not improve from 0.89893
#
# Epoch 00018: val_loss did not improve from 0.16185
# 284/284 [==============================] - 312s 1s/step - loss: 0.1764 - auc: 0.9623 - val_loss: 0.1650 - val_auc: 0.8794 - lr: 1.1926e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 1277/1276 [==============================] - 327s 256ms/step
# Predicting Test with TTA...
# 2145/2144 [==============================] - 553s 258ms/step
# #### FOLD 2 OOF AUC without TTA = 0.899, with TTA = 0.911
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 3
# #### Image Size 512 with {MODEL_NAME} EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# 284/284 [==============================] - ETA: 0s - loss: 0.4639 - auc: 0.6518
# Epoch 00001: val_auc improved from -inf to 0.73029, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.21869, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 348s 1s/step - loss: 0.4639 - auc: 0.6518 - val_loss: 0.2187 - val_auc: 0.7303 - lr: 5.0000e-06
# Epoch 2/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2366 - auc: 0.8137
# Epoch 00002: val_auc improved from 0.73029 to 0.85618, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.21869 to 0.16721, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.2366 - auc: 0.8137 - val_loss: 0.1672 - val_auc: 0.8562 - lr: 3.6000e-05
# Epoch 3/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2273 - auc: 0.8587
# Epoch 00003: val_auc improved from 0.85618 to 0.88750, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.16721 to 0.16359, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 319s 1s/step - loss: 0.2273 - auc: 0.8587 - val_loss: 0.1636 - val_auc: 0.8875 - lr: 6.7000e-05
# Epoch 4/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2173 - auc: 0.8846
# Epoch 00004: val_auc improved from 0.88750 to 0.91516, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.16359 to 0.16232, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.2173 - auc: 0.8846 - val_loss: 0.1623 - val_auc: 0.9152 - lr: 9.8000e-05
# Epoch 5/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2153 - auc: 0.8956
# Epoch 00005: val_auc did not improve from 0.91516
#
# Epoch 00005: val_loss did not improve from 0.16232
# 284/284 [==============================] - 313s 1s/step - loss: 0.2153 - auc: 0.8956 - val_loss: 0.1667 - val_auc: 0.9124 - lr: 1.2900e-04
# Epoch 6/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2105 - auc: 0.9032
# Epoch 00006: val_auc did not improve from 0.91516
#
# Epoch 00006: val_loss did not improve from 0.16232
# 284/284 [==============================] - 313s 1s/step - loss: 0.2105 - auc: 0.9032 - val_loss: 0.1626 - val_auc: 0.8870 - lr: 1.6000e-04
# Epoch 7/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2064 - auc: 0.9148
# Epoch 00007: val_auc improved from 0.91516 to 0.93074, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.16232 to 0.16064, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.2064 - auc: 0.9148 - val_loss: 0.1606 - val_auc: 0.9307 - lr: 1.2820e-04
# Epoch 8/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1998 - auc: 0.9276
# Epoch 00008: val_auc improved from 0.93074 to 0.93127, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.16064 to 0.15819, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.1998 - auc: 0.9276 - val_loss: 0.1582 - val_auc: 0.9313 - lr: 1.0276e-04
# Epoch 9/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1956 - auc: 0.9342
# Epoch 00009: val_auc improved from 0.93127 to 0.93636, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.15819
# 284/284 [==============================] - 318s 1s/step - loss: 0.1956 - auc: 0.9342 - val_loss: 0.1638 - val_auc: 0.9364 - lr: 8.2408e-05
# Epoch 10/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1918 - auc: 0.9407
# Epoch 00010: val_auc improved from 0.93636 to 0.93938, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.15819 to 0.15738, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.1918 - auc: 0.9407 - val_loss: 0.1574 - val_auc: 0.9394 - lr: 6.6126e-05
# Epoch 11/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1893 - auc: 0.9460
# Epoch 00011: val_auc did not improve from 0.93938
#
# Epoch 00011: val_loss improved from 0.15738 to 0.15673, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.1893 - auc: 0.9460 - val_loss: 0.1567 - val_auc: 0.9305 - lr: 5.3101e-05
# Epoch 12/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1852 - auc: 0.9517
# Epoch 00012: val_auc did not improve from 0.93938
#
# Epoch 00012: val_loss improved from 0.15673 to 0.15592, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.1852 - auc: 0.9517 - val_loss: 0.1559 - val_auc: 0.9322 - lr: 4.2681e-05
# Epoch 13/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1838 - auc: 0.9537
# Epoch 00013: val_auc did not improve from 0.93938
#
# Epoch 00013: val_loss did not improve from 0.15592
# 284/284 [==============================] - 314s 1s/step - loss: 0.1838 - auc: 0.9537 - val_loss: 0.1580 - val_auc: 0.9292 - lr: 3.4345e-05
# Epoch 14/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1821 - auc: 0.9541
# Epoch 00014: val_auc did not improve from 0.93938
#
# Epoch 00014: val_loss improved from 0.15592 to 0.15533, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-2-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.1821 - auc: 0.9541 - val_loss: 0.1553 - val_auc: 0.9229 - lr: 2.7676e-05
# Epoch 15/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1809 - auc: 0.9551
# Epoch 00015: val_auc did not improve from 0.93938
#
# Epoch 00015: val_loss did not improve from 0.15533
# 284/284 [==============================] - 313s 1s/step - loss: 0.1809 - auc: 0.9551 - val_loss: 0.1571 - val_auc: 0.9235 - lr: 2.2341e-05
# Epoch 16/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1796 - auc: 0.9591
# Epoch 00016: val_auc did not improve from 0.93938
#
# Epoch 00016: val_loss did not improve from 0.15533
# 284/284 [==============================] - 313s 1s/step - loss: 0.1796 - auc: 0.9591 - val_loss: 0.1559 - val_auc: 0.9298 - lr: 1.8072e-05
# Epoch 17/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1780 - auc: 0.9614
# Epoch 00017: val_auc did not improve from 0.93938
#
# Epoch 00017: val_loss did not improve from 0.15533
# 284/284 [==============================] - 313s 1s/step - loss: 0.1780 - auc: 0.9614 - val_loss: 0.1557 - val_auc: 0.9283 - lr: 1.4658e-05
# Epoch 18/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1772 - auc: 0.9625
# Epoch 00018: val_auc did not improve from 0.93938
#
# Epoch 00018: val_loss did not improve from 0.15533
# 284/284 [==============================] - 313s 1s/step - loss: 0.1772 - auc: 0.9625 - val_loss: 0.1561 - val_auc: 0.9262 - lr: 1.1926e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 1280/1279 [==============================] - 328s 257ms/step
# Predicting Test with TTA...
# 2145/2144 [==============================] - 555s 259ms/step
# #### FOLD 3 OOF AUC without TTA = 0.939, with TTA = 0.947
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 4
# #### Image Size 512 with {MODEL_NAME} EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# 284/284 [==============================] - ETA: 0s - loss: 0.4535 - auc: 0.6622
# Epoch 00001: val_auc improved from -inf to 0.70693, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.21864, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 350s 1s/step - loss: 0.4535 - auc: 0.6622 - val_loss: 0.2186 - val_auc: 0.7069 - lr: 5.0000e-06
# Epoch 2/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2348 - auc: 0.8206
# Epoch 00002: val_auc improved from 0.70693 to 0.85906, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.21864 to 0.16721, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.2348 - auc: 0.8206 - val_loss: 0.1672 - val_auc: 0.8591 - lr: 3.6000e-05
# Epoch 3/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2251 - auc: 0.8658
# Epoch 00003: val_auc improved from 0.85906 to 0.87733, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.16721 to 0.16589, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.2251 - auc: 0.8658 - val_loss: 0.1659 - val_auc: 0.8773 - lr: 6.7000e-05
# Epoch 4/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2182 - auc: 0.8828
# Epoch 00004: val_auc improved from 0.87733 to 0.88875, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00004: val_loss did not improve from 0.16589
# 284/284 [==============================] - 317s 1s/step - loss: 0.2182 - auc: 0.8828 - val_loss: 0.1664 - val_auc: 0.8887 - lr: 9.8000e-05
# Epoch 5/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2131 - auc: 0.9004
# Epoch 00005: val_auc improved from 0.88875 to 0.90688, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.16589
# 284/284 [==============================] - 317s 1s/step - loss: 0.2131 - auc: 0.9004 - val_loss: 0.1712 - val_auc: 0.9069 - lr: 1.2900e-04
# Epoch 6/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2074 - auc: 0.9100
# Epoch 00006: val_auc did not improve from 0.90688
#
# Epoch 00006: val_loss improved from 0.16589 to 0.16385, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.2074 - auc: 0.9100 - val_loss: 0.1639 - val_auc: 0.9057 - lr: 1.6000e-04
# Epoch 7/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2035 - auc: 0.9183
# Epoch 00007: val_auc improved from 0.90688 to 0.91633, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.16385 to 0.16336, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.2035 - auc: 0.9183 - val_loss: 0.1634 - val_auc: 0.9163 - lr: 1.2820e-04
# Epoch 8/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1985 - auc: 0.9292
# Epoch 00008: val_auc did not improve from 0.91633
#
# Epoch 00008: val_loss did not improve from 0.16336
# 284/284 [==============================] - 313s 1s/step - loss: 0.1985 - auc: 0.9292 - val_loss: 0.1642 - val_auc: 0.9159 - lr: 1.0276e-04
# Epoch 9/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1928 - auc: 0.9406
# Epoch 00009: val_auc did not improve from 0.91633
#
# Epoch 00009: val_loss improved from 0.16336 to 0.16291, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.1928 - auc: 0.9406 - val_loss: 0.1629 - val_auc: 0.9097 - lr: 8.2408e-05
# Epoch 10/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1894 - auc: 0.9430
# Epoch 00010: val_auc did not improve from 0.91633
#
# Epoch 00010: val_loss improved from 0.16291 to 0.15986, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.1894 - auc: 0.9430 - val_loss: 0.1599 - val_auc: 0.9148 - lr: 6.6126e-05
# Epoch 11/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1858 - auc: 0.9529
# Epoch 00011: val_auc improved from 0.91633 to 0.92760, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestAUC.h5
#
# Epoch 00011: val_loss did not improve from 0.15986
# 284/284 [==============================] - 317s 1s/step - loss: 0.1858 - auc: 0.9529 - val_loss: 0.1603 - val_auc: 0.9276 - lr: 5.3101e-05
# Epoch 12/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1829 - auc: 0.9574
# Epoch 00012: val_auc did not improve from 0.92760
#
# Epoch 00012: val_loss improved from 0.15986 to 0.15950, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-3-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.1829 - auc: 0.9574 - val_loss: 0.1595 - val_auc: 0.9184 - lr: 4.2681e-05
# Epoch 13/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1806 - auc: 0.9579
# Epoch 00013: val_auc did not improve from 0.92760
#
# Epoch 00013: val_loss did not improve from 0.15950
# 284/284 [==============================] - 314s 1s/step - loss: 0.1806 - auc: 0.9579 - val_loss: 0.1608 - val_auc: 0.9158 - lr: 3.4345e-05
# Epoch 14/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1793 - auc: 0.9611
# Epoch 00014: val_auc did not improve from 0.92760
#
# Epoch 00014: val_loss did not improve from 0.15950
# 284/284 [==============================] - 314s 1s/step - loss: 0.1793 - auc: 0.9611 - val_loss: 0.1599 - val_auc: 0.9171 - lr: 2.7676e-05
# Epoch 15/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1781 - auc: 0.9614
# Epoch 00015: val_auc did not improve from 0.92760
#
# Epoch 00015: val_loss did not improve from 0.15950
# 284/284 [==============================] - 314s 1s/step - loss: 0.1781 - auc: 0.9614 - val_loss: 0.1611 - val_auc: 0.9188 - lr: 2.2341e-05
# Epoch 16/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1753 - auc: 0.9636
# Epoch 00016: val_auc did not improve from 0.92760
#
# Epoch 00016: val_loss did not improve from 0.15950
# 284/284 [==============================] - 314s 1s/step - loss: 0.1753 - auc: 0.9636 - val_loss: 0.1605 - val_auc: 0.9125 - lr: 1.8072e-05
# Epoch 17/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1750 - auc: 0.9645
# Epoch 00017: val_auc did not improve from 0.92760
#
# Epoch 00017: val_loss did not improve from 0.15950
# 284/284 [==============================] - 314s 1s/step - loss: 0.1750 - auc: 0.9645 - val_loss: 0.1600 - val_auc: 0.9143 - lr: 1.4658e-05
# Epoch 18/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1753 - auc: 0.9646
# Epoch 00018: val_auc did not improve from 0.92760
#
# Epoch 00018: val_loss did not improve from 0.15950
# 284/284 [==============================] - 314s 1s/step - loss: 0.1753 - auc: 0.9646 - val_loss: 0.1609 - val_auc: 0.9137 - lr: 1.1926e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 1273/1272 [==============================] - 330s 259ms/step
# Predicting Test with TTA...
# 2145/2144 [==============================] - 558s 260ms/step
# #### FOLD 4 OOF AUC without TTA = 0.928, with TTA = 0.932
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.13.29.170:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.13.29.170:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 5
# #### Image Size 512 with {MODEL_NAME} EfficientNet B6 and batch_size 128
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/18
# 284/284 [==============================] - ETA: 0s - loss: 0.4479 - auc: 0.6518
# Epoch 00001: val_auc improved from -inf to 0.70236, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.21805, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 348s 1s/step - loss: 0.4479 - auc: 0.6518 - val_loss: 0.2181 - val_auc: 0.7024 - lr: 5.0000e-06
# Epoch 2/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2374 - auc: 0.8106
# Epoch 00002: val_auc improved from 0.70236 to 0.82199, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.21805 to 0.16769, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.2374 - auc: 0.8106 - val_loss: 0.1677 - val_auc: 0.8220 - lr: 3.6000e-05
# Epoch 3/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2256 - auc: 0.8629
# Epoch 00003: val_auc improved from 0.82199 to 0.85656, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.16769 to 0.16508, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 325s 1s/step - loss: 0.2256 - auc: 0.8629 - val_loss: 0.1651 - val_auc: 0.8566 - lr: 6.7000e-05
# Epoch 4/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2198 - auc: 0.8782
# Epoch 00004: val_auc did not improve from 0.85656
#
# Epoch 00004: val_loss improved from 0.16508 to 0.16438, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.2198 - auc: 0.8782 - val_loss: 0.1644 - val_auc: 0.8546 - lr: 9.8000e-05
# Epoch 5/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2127 - auc: 0.8995
# Epoch 00005: val_auc improved from 0.85656 to 0.88923, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.16438 to 0.16038, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 321s 1s/step - loss: 0.2127 - auc: 0.8995 - val_loss: 0.1604 - val_auc: 0.8892 - lr: 1.2900e-04
# Epoch 6/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2092 - auc: 0.9097
# Epoch 00006: val_auc improved from 0.88923 to 0.89097, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00006: val_loss did not improve from 0.16038
# 284/284 [==============================] - 318s 1s/step - loss: 0.2092 - auc: 0.9097 - val_loss: 0.1624 - val_auc: 0.8910 - lr: 1.6000e-04
# Epoch 7/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2026 - auc: 0.9210
# Epoch 00007: val_auc improved from 0.89097 to 0.90476, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.16038 to 0.15978, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 322s 1s/step - loss: 0.2026 - auc: 0.9210 - val_loss: 0.1598 - val_auc: 0.9048 - lr: 1.2820e-04
# Epoch 8/18
# 284/284 [==============================] - ETA: 0s - loss: 0.2002 - auc: 0.9284
# Epoch 00008: val_auc did not improve from 0.90476
#
# Epoch 00008: val_loss improved from 0.15978 to 0.15759, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 317s 1s/step - loss: 0.2002 - auc: 0.9284 - val_loss: 0.1576 - val_auc: 0.8998 - lr: 1.0276e-04
# Epoch 9/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1967 - auc: 0.9343
# Epoch 00009: val_auc improved from 0.90476 to 0.90919, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.15759 to 0.15674, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 320s 1s/step - loss: 0.1967 - auc: 0.9343 - val_loss: 0.1567 - val_auc: 0.9092 - lr: 8.2408e-05
# Epoch 10/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1904 - auc: 0.9443
# Epoch 00010: val_auc did not improve from 0.90919
#
# Epoch 00010: val_loss did not improve from 0.15674
# 284/284 [==============================] - 314s 1s/step - loss: 0.1904 - auc: 0.9443 - val_loss: 0.1575 - val_auc: 0.8998 - lr: 6.6126e-05
# Epoch 11/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1876 - auc: 0.9479
# Epoch 00011: val_auc did not improve from 0.90919
#
# Epoch 00011: val_loss did not improve from 0.15674
# 284/284 [==============================] - 314s 1s/step - loss: 0.1876 - auc: 0.9479 - val_loss: 0.1572 - val_auc: 0.9081 - lr: 5.3101e-05
# Epoch 12/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1873 - auc: 0.9523
# Epoch 00012: val_auc improved from 0.90919 to 0.91423, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00012: val_loss improved from 0.15674 to 0.15551, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 322s 1s/step - loss: 0.1873 - auc: 0.9523 - val_loss: 0.1555 - val_auc: 0.9142 - lr: 4.2681e-05
# Epoch 13/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1855 - auc: 0.9526
# Epoch 00013: val_auc improved from 0.91423 to 0.92000, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00013: val_loss improved from 0.15551 to 0.15532, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestloss.h5
# 284/284 [==============================] - 322s 1s/step - loss: 0.1855 - auc: 0.9526 - val_loss: 0.1553 - val_auc: 0.9200 - lr: 3.4345e-05
# Epoch 14/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1823 - auc: 0.9582
# Epoch 00014: val_auc improved from 0.92000 to 0.92050, saving model to 512-EffNetB6-BS16-EPOCHS18-TTA25-INC2018-imagenet-COARSE_DROPOUT/fold-4-bestAUC.h5
#
# Epoch 00014: val_loss did not improve from 0.15532
# 284/284 [==============================] - 317s 1s/step - loss: 0.1823 - auc: 0.9582 - val_loss: 0.1567 - val_auc: 0.9205 - lr: 2.7676e-05
# Epoch 15/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1804 - auc: 0.9569
# Epoch 00015: val_auc did not improve from 0.92050
#
# Epoch 00015: val_loss did not improve from 0.15532
# 284/284 [==============================] - 314s 1s/step - loss: 0.1804 - auc: 0.9569 - val_loss: 0.1568 - val_auc: 0.9181 - lr: 2.2341e-05
# Epoch 16/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1786 - auc: 0.9606
# Epoch 00016: val_auc did not improve from 0.92050
#
# Epoch 00016: val_loss did not improve from 0.15532
# 284/284 [==============================] - 314s 1s/step - loss: 0.1786 - auc: 0.9606 - val_loss: 0.1566 - val_auc: 0.9189 - lr: 1.8072e-05
# Epoch 17/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1792 - auc: 0.9604
# Epoch 00017: val_auc did not improve from 0.92050
#
# Epoch 00017: val_loss did not improve from 0.15532
# 284/284 [==============================] - 313s 1s/step - loss: 0.1792 - auc: 0.9604 - val_loss: 0.1564 - val_auc: 0.9184 - lr: 1.4658e-05
# Epoch 18/18
# 284/284 [==============================] - ETA: 0s - loss: 0.1761 - auc: 0.9634
# Epoch 00018: val_auc did not improve from 0.92050
#
# Epoch 00018: val_loss did not improve from 0.15532
# 284/284 [==============================] - 314s 1s/step - loss: 0.1761 - auc: 0.9634 - val_loss: 0.1574 - val_auc: 0.9199 - lr: 1.1926e-05
# Loading best model val loss...
# Predicting OOF with TTA...
# 1281/1280 [==============================] - 331s 258ms/step
# Predicting Test with TTA...
# 1068/2144 [=============>................] - ETA: 4:40

# %%
preds_by_fold

# %% [markdown]
# ## Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred); 
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names); folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{MODEL}/oof.csv',index=False)
df_oof.head()

# %%
auc_oof = 0.0
for i in range(FOLDS):
  auc_oof += roc_auc_score(oof_tar[i], oof_pred[i]) / FOLDS
print('Average OOF AUC with TTA = %.3f'%auc_oof)

# %% [markdown]
# # Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.
#
# Aqui, hauriem de posar les features amb XGB, CB, o el que sigui
# OptimizeAUC() del llibre de l'Abishek per trobar els pesos de diferents models per a cada fold
#
# I fer servir el OptimizeAUC per veure els pesos de la metadata

# %% [markdown]
# # Submit To Kaggle

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{MODEL}/submission.csv', index=False)
submission.head()

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
out_preds_by_fold = np.append(np.vstack(image_names), preds_by_fold, 1)
submission_by_fold = pd.DataFrame(out_preds_by_fold)

# #submission = submission.sort_values('image_name') 
submission_by_fold.to_csv(f'{MODEL}/preds_by_fold.csv', index=False)
submission_by_fold.head()
# submission.shape

# %%
preds_by_fold.shape

# %%
from scipy.stats import rankdata

ranked_submission = pd.DataFrame(dict(image_name=image_names, target=0))

ranked_submission['target'] = 0
for i in range(FOLDS):
    ranked_submission['target'] += rankdata(preds_by_fold[:,i]) / (FOLDS)

ranked_submission = ranked_submission.sort_values('image_name')

# %%
ranked_submission.head(100)

# %%
ranked_submission['target'].mean()

# %%
ranked_submission.to_csv(f'{MODEL}/submission_ranked.csv', index=False)

plt.hist(ranked_submission.target,bins=100)
plt.show()

# %%
import os
src = f'/content/{MODEL}'
dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}"'
os.system(f"rm -rf {dest}")
os.system(f"cp -rf {src} {dest}")
print (src)
print(dest)

# %%
import re
import json
import requests
import ipykernel
from notebook.notebookapp import list_running_servers
from requests.compat import urljoin

def get_notebook_name():
    """
    Return the full path of the jupyter notebook.
    """
    kernel_id = re.search('kernel-(.*).json', ipykernel.connect.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in response.json():
            if nn['kernel']['id'] == kernel_id:
                notebook_name = nn['notebook']['name']
                return notebook_name

NOTEBOOK_NAME = get_notebook_name()
copyNotebook = f'cp "/content/gdrive/My Drive/Colab Notebooks/{NOTEBOOK_NAME}" "/content/gdrive/My Drive/saved_models/{MODEL}/train.ipynb"'
os.system(copyNotebook)

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission.csv -m "{MODEL}"

# %%
#!kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission_ranked.csv -m "{MODEL}-Ranked"
