# %% [markdown]
# # Triple Stratified KFold CV with TFRecords
# This is a simple starter notebook for Kaggle's Melanoma Comp showing triple stratifed KFold with TFRecords. Triple stratified KFold is explained [here][2]. There are many configuration variables below to allow you to experiment. Use either GPU or TPU. You can control which size images are loaded, which efficientNets are used, and whether external data is used. You can experiment with different data augmentation, model architecture, loss, optimizers, and learning schedules. The TFRecords contain meta data, so you can input that into your CNN too.
#
# **NOTE:** this notebook lets you run a different experiment in each fold if you want to run lots of experiments. (Then it is like running multiple holdout validaiton experiments but in that case note that the overall CV score is meaningless because LB will be much higher when the multiple experiments are ensembled to predict test). **If you want a proper CV with a reliable overall CV score you need to choose the same configuration for each fold.**
#
# This notebook follows the 5 step process presented in my "How to compete with GPUs Workshop" [here][1]. Some code sections have been reused from AgentAuers' great notebook [here][3]
#
# [1]: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/165526
# [3]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/gdrive/My Drive/Kaggle/kaggle.json" ~/.kaggle

# %% [markdown]
# # Initialize Environment

# %%
# !pip install -q efficientnet >> /dev/null

# %%
import cv2, matplotlib.pyplot as plt
import gc
import pandas as pd, numpy as np
#from kaggle_datasets import KaggleDatasets
import tensorflow as tf, re, math
import tensorflow.keras.backend as K
import efficientnet.tfkeras as efn
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Configuration
# In order to be a proper cross validation with a meaningful overall CV score (aligned with LB score), **you need to choose the same** `IMG_SIZES`, `INC2019`, `INC2018`, and `EFF_NETS` **for each fold**. If your goal is to just run lots of experiments, then you can choose to have a different experiment in each fold. Then each fold is like a holdout validation experiment. When you find a configuration you like, you can use that configuration for all folds.
# * DEVICE - is GPU or TPU
# * SEED - a different seed produces a different triple stratified kfold split.
# * FOLDS - number of folds. Best set to 3, 5, or 15 but can be any number between 2 and 15
# * IMG_SIZES - is a Python list of length FOLDS. These are the image sizes to use each fold
# * INC2019 - This includes the new half of the 2019 competition data. The second half of the 2019 data is the comp data from 2018 plus 2017
# * INC2018 - This includes the second half of the 2019 competition data which is the comp data from 2018 plus 2017
# * BATCH_SIZES - is a list of length FOLDS. These are batch sizes for each fold. For maximum speed, it is best to use the largest batch size your GPU or TPU allows.
# * EPOCHS - is a list of length FOLDS. These are maximum epochs. Note that each fold, the best epoch model is saved and used. So if epochs is too large, it won't matter.
# * EFF_NETS - is a list of length FOLDS. These are the EfficientNets to use each fold. The number refers to the B. So a number of `0` refers to EfficientNetB0, and `1` refers to EfficientNetB1, etc.
# * WGTS - this should be `1/FOLDS` for each fold. This is the weight when ensembling the folds to predict the test set. If you want a weird ensemble, you can use different weights.
# * TTA - test time augmentation. Each test image is randomly augmented and predicted TTA times and the average prediction is used. TTA is also applied to OOF during validation.

# %%
DEVICE = "TPU" #or "GPU"

# USE DIFFERENT SEED FOR DIFFERENT STRATIFIED KFOLD
SEED = 42

# NUMBER OF FOLDS. USE 3, 5, OR 15 
FOLDS = 5

# WHICH IMAGE SIZES TO LOAD EACH FOLD
# CHOOSE 128, 192, 256, 384, 512, 768 


IMG_SIZES =  [512,512,512,512,512]
IMG_SIZES = [384,384,384,384,384] 

# INCLUDE OLD COMP DATA? YES=1 NO=0
INC2019 = [0,0,0,0,0]
INC2018 = [1,1,1,1,1]

# BATCH SIZE AND EPOCHS
BATCH_SIZES = [32]*FOLDS #[32]*FOLDS
EPOCHS = [24]*FOLDS #12 18

# WHICH EFFICIENTNET B? TO USE
EFF_NETS = [3,3,3,3,3]
EFF_NETS = [6,6,6,6,6]

EFF_NET_PRETRAIN = 'imagenet' #'noisy-student'

# WEIGHTS FOR FOLD MODELS WHEN PREDICTING TEST
WGTS = [1/FOLDS]*FOLDS

# TEST TIME AUGMENTATION STEPS
TTA = 11

#Treure de Kaggle
if IMG_SIZES[0]==384:
  #384 images
  GCS1="gs://kds-e73569ee9d44308363027e79908294593e80b1e12e18e57ef065397c" #384
  GCS2="gs://kds-a2fe5a6e1a508cd8db24774c2db3261e943ace55b723c5ed834193fd"#384
elif IMG_SIZES[0]==512:
  #512
  GCS1 = "gs://kds-4f5e437bc05e29f3e95419fa289ea3a6b01ac2fefcb772ca07cc3b5f"
  GCS2 = "gs://kds-6e8721559463b8ae97c4fcb0a82ed0b4181b934709aa15043a995f83"
else:
  raise error

MODEL = f'{IMG_SIZES[0]}-EffNetB{EFF_NETS[0]}-BS{BATCH_SIZES[0]}-EPOCHS{EPOCHS[0]}-TTA-INC2018-FOCAL'
print(MODEL)
# Out:
# 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL

# %%
import os
if not os.path.exists(f'/content/{MODEL}'):
    os.mkdir(f'/content/{MODEL}')

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and single GPU")
    strategy = tf.distribute.get_strategy()

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
# Out:
# connecting to TPU...
# Running on TPU  grpc://10.95.189.18:8470
# initializing  TPU ...
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# TPU initialized

# %% [markdown]
# # Step 1: Preprocess
# Preprocess has already been done and saved to TFRecords. Here we choose which size to load. We can use either 128x128, 192x192, 256x256, 384x384, 512x512, 768x768 by changing the `IMG_SIZES` variable in the preceeding code section. These TFRecords are discussed [here][1]. The advantage of using different input sizes is discussed [here][2]
#
# [1]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/155579
# [2]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/160147

# %%
GCS_PATH = [None]*FOLDS; GCS_PATH2 = [None]*FOLDS

for i,k in enumerate(IMG_SIZES):
    GCS_PATH[i] = GCS1
    GCS_PATH2[i] = GCS2

files_train = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/train*.tfrec')))
files_test  = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[0] + '/test*.tfrec')))

# %% [markdown]
# # Step 2: Data Augmentation
# This notebook uses rotation, sheer, zoom, shift augmentation first shown in this notebook [here][1] and successfully used in Melanoma comp by AgentAuers [here][2]. This notebook also uses horizontal flip, hue, saturation, contrast, brightness augmentation similar to last years winner and also similar to AgentAuers' notebook.
#
# Additionally we can decide to use external data by changing the variables `INC2019` and `INC2018` in the preceeding code section. These variables respectively indicate whether to load last year 2019 data and/or year 2018 + 2017 data. These datasets are discussed [here][3]
#
# Consider experimenting with different augmenation and/or external data. The code to load TFRecords is taken from AgentAuers' notebook [here][2]. Thank you AgentAuers, this is great work.
#
# [1]: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
# [2]: https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once
# [3]: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/164910

# %%
ROT_ = 180.0 #90.0 al submit anterior
SHR_ = 2.0
HZOOM_ = 8.0
WZOOM_ = 8.0
HSHIFT_ = 8.0
WSHIFT_ = 8.0

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))


def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

# %%
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
        'patient_id'                   : tf.io.FixedLenFeature([], tf.int64),
        'sex'                          : tf.io.FixedLenFeature([], tf.int64),
        'age_approx'                   : tf.io.FixedLenFeature([], tf.int64),
        'anatom_site_general_challenge': tf.io.FixedLenFeature([], tf.int64),
        'diagnosis'                    : tf.io.FixedLenFeature([], tf.int64),
        'target'                       : tf.io.FixedLenFeature([], tf.int64)
    }           
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['target']


def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_name'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_name'] if return_image_name else 0

 
def prepare_image(img, augment=True, dim=256):    
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    
    if augment:
        img = transform(img,DIM=dim)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)
                      
    img = tf.reshape(img, [dim,dim, 3])
            
    return img

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
def get_dataset(files, augment = False, shuffle = False, repeat = False, 
                labeled=True, return_image_names=True, batch_size=16, dim=256):
    
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO)
    ds = ds.cache()
    
    if repeat:
        ds = ds.repeat()
    
    if shuffle: 
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)
        
    if labeled: 
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
        #todo add color const
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names), 
                    num_parallel_calls=AUTO) 
        #todo add color const     
    
    ds = ds.map(lambda img, imgname_or_label: (prepare_image(img, augment=augment, dim=dim), 
                                               imgname_or_label), 
                num_parallel_calls=AUTO)
    
    ds = ds.batch(batch_size * REPLICAS)
    ds = ds.prefetch(AUTO)
    return ds

# %% [markdown]
# # Step 3: Build Model
# This is a common model architecute. Consider experimenting with different backbones, custom heads, losses, and optimizers. Also consider inputing meta features into your CNN.

# %%
import tensorflow_addons as tfa

EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6]

def build_model(dim=128, ef=0):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EFNS[ef](input_shape=(dim,dim,3),weights=EFF_NET_PRETRAIN,include_top=False)
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    #loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05) 
    loss = tfa.losses.SigmoidFocalCrossEntropy()
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    return model

# %% [markdown]
# # Step 4: Train Schedule
# This is a common train schedule for transfer learning. The learning rate starts near zero, then increases to a maximum, then decays over time. Consider changing the schedule and/or learning rates. Note how the learning rate max is larger with larger batches sizes. This is a good practice to follow.

# %%
lr_start   = 0.000005
lr_max     = 0.00000125 * REPLICAS * BATCH_SIZES[0]
lr_min     = 0.000001
lr_ramp_ep = 5
lr_sus_ep  = 0
lr_decay   = 0.8

def lrfn(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        
    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max
        
    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
        
    return lr


rng = [i for i in range(EPOCHS[0])]
y = [lrfn(x) for x in rng]
plt.plot(rng, [lrfn(x) for x in rng])
print(y[0], y[-1])
# Out:
# 5e-06 6.746593124524759e-06

# %%
def get_lr_callback(batch_size=8):
    lr_start   = 0.000005
    lr_max     = 0.00000125 * REPLICAS * batch_size
    lr_min     = 0.000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback

# %% [markdown]
# ## Train Model
# Our model will be trained for the number of FOLDS and EPOCHS you chose in the configuration above. Each fold the model with lowest validation loss will be saved and used to predict OOF and test. Adjust the variables `VERBOSE` and `DISPLOY_PLOT` below to determine what output you want displayed. The variable `VERBOSE=1 or 2` will display the training and validation loss and auc for each epoch as text. The variable `DISPLAY_PLOT` shows this information as a plot.

# %%
# USE VERBOSE=0 for silent, VERBOSE=1 for interactive, VERBOSE=2 for commit
VERBOSE = 1
DISPLAY_PLOT = True

skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
oof_pred = []; oof_tar = []; oof_val = []; oof_names = []; oof_folds = [] 
preds = np.zeros((count_data_items(files_test),1))
preds_by_fold = np.empty([count_data_items(files_test), FOLDS], dtype=float)

for fold,(idxT,idxV) in enumerate(skf.split(np.arange(15))):
    # DISPLAY FOLD INFO
    if DEVICE=='TPU':
        if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print('#'*25); print('#### FOLD',fold+1)
    print('#### Image Size %i with EfficientNet B%i and batch_size %i'%
          (IMG_SIZES[fold],EFF_NETS[fold],BATCH_SIZES[fold]*REPLICAS))
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    files_train = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxT])
    if INC2019[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2+1])
        print('#### Using 2019 external data')
    if INC2018[fold]:
        files_train += tf.io.gfile.glob([GCS_PATH2[fold] + '/train%.2i*.tfrec'%x for x in idxT*2])
        print('#### Using 2018+2017 external data')
    np.random.shuffle(files_train); print('#'*25)
    files_valid = tf.io.gfile.glob([GCS_PATH[fold] + '/train%.2i*.tfrec'%x for x in idxV])
    files_test = np.sort(np.array(tf.io.gfile.glob(GCS_PATH[fold] + '/test*.tfrec')))
    
    # BUILD MODEL
    K.clear_session()
    with strategy.scope():
        model = build_model(dim=IMG_SIZES[fold],ef=EFF_NETS[fold])
        
    # SAVE BEST MODEL EACH FOLD
    checkpoint_file = f'{MODEL}/fold-%i-bestAUC.h5'%fold
    sv = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_auc', verbose=1, save_best_only=True,
        save_weights_only=True, mode='max', save_freq='epoch')
    
    checkpoint_file = f'{MODEL}/fold-%i-bestloss.h5'%fold
    sv2 = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_file, monitor='val_loss', verbose=1, save_best_only=True,
        save_weights_only=True, mode='min', save_freq='epoch')
   
    # TRAIN
    print('Training...')
    history = model.fit(
        get_dataset(files_train, augment=True, shuffle=True, repeat=True,
                dim=IMG_SIZES[fold], batch_size = BATCH_SIZES[fold]), 
        epochs=EPOCHS[fold], callbacks = [sv,sv2,get_lr_callback(BATCH_SIZES[fold])], 
        steps_per_epoch=count_data_items(files_train)/BATCH_SIZES[fold]//REPLICAS,
        validation_data=get_dataset(files_valid,augment=False,shuffle=False,
                repeat=False,dim=IMG_SIZES[fold]), #class_weight = {0:1,1:2},
        verbose=VERBOSE
    )
    
    print('Loading best model val loss...')
    model.load_weights(checkpoint_file)
    
    # PREDICT OOF USING TTA
    print('Predicting OOF with TTA...')
    ds_valid = get_dataset(files_valid,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold])
    ct_valid = count_data_items(files_valid); STEPS = TTA * ct_valid/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_valid,steps=STEPS,verbose=VERBOSE)[:TTA*ct_valid,] 
    oof_pred.append( np.mean(pred.reshape((ct_valid,TTA),order='F'),axis=1) )                 
    #oof_pred.append(model.predict(get_dataset(files_valid,dim=IMG_SIZES[fold]),verbose=1))
    
    # GET OOF TARGETS AND NAMES
    ds_valid = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
            labeled=True, return_image_names=True)
    oof_tar.append( np.array([target.numpy() for img, target in iter(ds_valid.unbatch())]) )
    oof_folds.append( np.ones_like(oof_tar[-1],dtype='int8')*fold )
    ds = get_dataset(files_valid, augment=False, repeat=False, dim=IMG_SIZES[fold],
                labeled=False, return_image_names=True)
    oof_names.append( np.array([img_name.numpy().decode("utf-8") for img, img_name in iter(ds.unbatch())]))
    
    # PREDICT TEST USING TTA
    print('Predicting Test with TTA...')
    ds_test = get_dataset(files_test,labeled=False,return_image_names=False,augment=True,
            repeat=True,shuffle=False,dim=IMG_SIZES[fold],batch_size=BATCH_SIZES[fold])
    ct_test = count_data_items(files_test); STEPS = TTA * ct_test/BATCH_SIZES[fold]/REPLICAS
    pred = model.predict(ds_test,steps=STEPS,verbose=VERBOSE)[:TTA*ct_test,] 
    tta_mean = np.mean(pred.reshape((ct_test,TTA),order='F'),axis=1)
    preds[:,0] += tta_mean * WGTS[fold]
    #new

    preds_by_fold[:,fold] = tta_mean

    
    # REPORT RESULTS
    auc = roc_auc_score(oof_tar[-1],oof_pred[-1])
    oof_val.append(np.max( history.history['val_auc'] ))
    print('#### FOLD %i OOF AUC without TTA = %.3f, with TTA = %.3f'%(fold+1,oof_val[-1],auc))
    
    # PLOT TRAINING
    if DISPLAY_PLOT:
        plt.figure(figsize=(15,5))
        plt.plot(np.arange(EPOCHS[fold]),history.history['auc'],'-o',label='Train AUC',color='#ff7f0e')
        plt.plot(np.arange(EPOCHS[fold]),history.history['val_auc'],'-o',label='Val AUC',color='#1f77b4')
        x = np.argmax( history.history['val_auc'] ); y = np.max( history.history['val_auc'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max auc\n%.2f'%y,size=14)
        plt.ylabel('AUC',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(EPOCHS[fold]),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(np.arange(EPOCHS[fold]),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.title('FOLD %i - Image Size %i, EfficientNet B%i, inc2019=%i, inc2018=%i'%
                (fold+1,IMG_SIZES[fold],EFF_NETS[fold],INC2019[fold],INC2018[fold]),size=18)
        plt.legend(loc=3)
        plt.show()
        #break
      

    gc.collect()
# Out:
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 1
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0889 - auc: 0.5315WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.62871, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.04240, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 142/142 [==============================] - 204s 1s/step - loss: 0.0889 - auc: 0.5315 - val_loss: 0.0424 - val_auc: 0.6287 - lr: 5.0000e-06
# Epoch 2/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0173 - auc: 0.7733
# Epoch 00002: val_auc improved from 0.62871 to 0.83864, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.04240 to 0.00726, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0173 - auc: 0.7733 - val_loss: 0.0073 - val_auc: 0.8386 - lr: 6.8000e-05
# Epoch 3/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0139 - auc: 0.8734
# Epoch 00003: val_auc improved from 0.83864 to 0.88129, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00726 to 0.00702, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0139 - auc: 0.8734 - val_loss: 0.0070 - val_auc: 0.8813 - lr: 1.3100e-04
# Epoch 4/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0128 - auc: 0.9013
# Epoch 00004: val_auc improved from 0.88129 to 0.88273, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00004: val_loss did not improve from 0.00702
# 142/142 [==============================] - 173s 1s/step - loss: 0.0128 - auc: 0.9013 - val_loss: 0.0078 - val_auc: 0.8827 - lr: 1.9400e-04
# Epoch 5/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0123 - auc: 0.9146
# Epoch 00005: val_auc improved from 0.88273 to 0.90596, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00702 to 0.00637, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0123 - auc: 0.9146 - val_loss: 0.0064 - val_auc: 0.9060 - lr: 2.5700e-04
# Epoch 6/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0115 - auc: 0.9255
# Epoch 00006: val_auc did not improve from 0.90596
#
# Epoch 00006: val_loss did not improve from 0.00637
# 142/142 [==============================] - 169s 1s/step - loss: 0.0115 - auc: 0.9255 - val_loss: 0.0065 - val_auc: 0.9039 - lr: 3.2000e-04
# Epoch 7/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0107 - auc: 0.9404
# Epoch 00007: val_auc improved from 0.90596 to 0.90702, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00007: val_loss did not improve from 0.00637
# 142/142 [==============================] - 173s 1s/step - loss: 0.0107 - auc: 0.9404 - val_loss: 0.0069 - val_auc: 0.9070 - lr: 2.5620e-04
# Epoch 8/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0098 - auc: 0.9506
# Epoch 00008: val_auc improved from 0.90702 to 0.90878, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00008: val_loss did not improve from 0.00637
# 142/142 [==============================] - 173s 1s/step - loss: 0.0098 - auc: 0.9506 - val_loss: 0.0065 - val_auc: 0.9088 - lr: 2.0516e-04
# Epoch 9/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0092 - auc: 0.9579
# Epoch 00009: val_auc improved from 0.90878 to 0.91921, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.00637
# 142/142 [==============================] - 173s 1s/step - loss: 0.0092 - auc: 0.9579 - val_loss: 0.0067 - val_auc: 0.9192 - lr: 1.6433e-04
# Epoch 10/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0087 - auc: 0.9637
# Epoch 00010: val_auc improved from 0.91921 to 0.92169, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00010: val_loss improved from 0.00637 to 0.00594, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0087 - auc: 0.9637 - val_loss: 0.0059 - val_auc: 0.9217 - lr: 1.3166e-04
# Epoch 11/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0078 - auc: 0.9712
# Epoch 00011: val_auc did not improve from 0.92169
#
# Epoch 00011: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0078 - auc: 0.9712 - val_loss: 0.0064 - val_auc: 0.9216 - lr: 1.0553e-04
# Epoch 12/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0075 - auc: 0.9740
# Epoch 00012: val_auc improved from 0.92169 to 0.92900, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-0-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00594
# 142/142 [==============================] - 173s 1s/step - loss: 0.0075 - auc: 0.9740 - val_loss: 0.0062 - val_auc: 0.9290 - lr: 8.4624e-05
# Epoch 13/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0069 - auc: 0.9776
# Epoch 00013: val_auc did not improve from 0.92900
#
# Epoch 00013: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0069 - auc: 0.9776 - val_loss: 0.0074 - val_auc: 0.9198 - lr: 6.7899e-05
# Epoch 14/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0065 - auc: 0.9814
# Epoch 00014: val_auc did not improve from 0.92900
#
# Epoch 00014: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0065 - auc: 0.9814 - val_loss: 0.0074 - val_auc: 0.9257 - lr: 5.4519e-05
# Epoch 15/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0061 - auc: 0.9847
# Epoch 00015: val_auc did not improve from 0.92900
#
# Epoch 00015: val_loss did not improve from 0.00594
# 142/142 [==============================] - 168s 1s/step - loss: 0.0061 - auc: 0.9847 - val_loss: 0.0071 - val_auc: 0.9246 - lr: 4.3815e-05
# Epoch 16/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9862
# Epoch 00016: val_auc did not improve from 0.92900
#
# Epoch 00016: val_loss did not improve from 0.00594
# 142/142 [==============================] - 168s 1s/step - loss: 0.0056 - auc: 0.9862 - val_loss: 0.0070 - val_auc: 0.9234 - lr: 3.5252e-05
# Epoch 17/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0055 - auc: 0.9876
# Epoch 00017: val_auc did not improve from 0.92900
#
# Epoch 00017: val_loss did not improve from 0.00594
# 142/142 [==============================] - 168s 1s/step - loss: 0.0055 - auc: 0.9876 - val_loss: 0.0071 - val_auc: 0.9258 - lr: 2.8402e-05
# Epoch 18/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0052 - auc: 0.9890
# Epoch 00018: val_auc did not improve from 0.92900
#
# Epoch 00018: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0052 - auc: 0.9890 - val_loss: 0.0072 - val_auc: 0.9251 - lr: 2.2922e-05
# Epoch 19/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0053 - auc: 0.9888
# Epoch 00019: val_auc did not improve from 0.92900
#
# Epoch 00019: val_loss did not improve from 0.00594
# 142/142 [==============================] - 168s 1s/step - loss: 0.0053 - auc: 0.9888 - val_loss: 0.0076 - val_auc: 0.9245 - lr: 1.8537e-05
# Epoch 20/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0049 - auc: 0.9905
# Epoch 00020: val_auc did not improve from 0.92900
#
# Epoch 00020: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0049 - auc: 0.9905 - val_loss: 0.0075 - val_auc: 0.9247 - lr: 1.5030e-05
# Epoch 21/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0049 - auc: 0.9902
# Epoch 00021: val_auc did not improve from 0.92900
#
# Epoch 00021: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0049 - auc: 0.9902 - val_loss: 0.0074 - val_auc: 0.9270 - lr: 1.2224e-05
# Epoch 22/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0046 - auc: 0.9915
# Epoch 00022: val_auc did not improve from 0.92900
#
# Epoch 00022: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0046 - auc: 0.9915 - val_loss: 0.0076 - val_auc: 0.9271 - lr: 9.9791e-06
# Epoch 23/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0047 - auc: 0.9914
# Epoch 00023: val_auc did not improve from 0.92900
#
# Epoch 00023: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0047 - auc: 0.9914 - val_loss: 0.0076 - val_auc: 0.9253 - lr: 8.1832e-06
# Epoch 24/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0047 - auc: 0.9915
# Epoch 00024: val_auc did not improve from 0.92900
#
# Epoch 00024: val_loss did not improve from 0.00594
# 142/142 [==============================] - 169s 1s/step - loss: 0.0047 - auc: 0.9915 - val_loss: 0.0076 - val_auc: 0.9265 - lr: 6.7466e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 281/280 [==============================] - 73s 260ms/step
# Predicting Test with TTA...
# 472/471 [==============================] - 125s 264ms/step
# #### FOLD 1 OOF AUC without TTA = 0.929, with TTA = 0.931
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 2
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0872 - auc: 0.5928WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.63286, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05137, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 142/142 [==============================] - 204s 1s/step - loss: 0.0872 - auc: 0.5928 - val_loss: 0.0514 - val_auc: 0.6329 - lr: 5.0000e-06
# Epoch 2/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0170 - auc: 0.7712
# Epoch 00002: val_auc improved from 0.63286 to 0.79353, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05137 to 0.00758, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0170 - auc: 0.7712 - val_loss: 0.0076 - val_auc: 0.7935 - lr: 6.8000e-05
# Epoch 3/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0137 - auc: 0.8829
# Epoch 00003: val_auc improved from 0.79353 to 0.86440, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00758 to 0.00713, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0137 - auc: 0.8829 - val_loss: 0.0071 - val_auc: 0.8644 - lr: 1.3100e-04
# Epoch 4/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0125 - auc: 0.9051
# Epoch 00004: val_auc improved from 0.86440 to 0.88384, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00713 to 0.00705, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 142/142 [==============================] - 176s 1s/step - loss: 0.0125 - auc: 0.9051 - val_loss: 0.0071 - val_auc: 0.8838 - lr: 1.9400e-04
# Epoch 5/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0123 - auc: 0.9148
# Epoch 00005: val_auc improved from 0.88384 to 0.89922, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00705 to 0.00654, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0123 - auc: 0.9148 - val_loss: 0.0065 - val_auc: 0.8992 - lr: 2.5700e-04
# Epoch 6/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0113 - auc: 0.9281
# Epoch 00006: val_auc did not improve from 0.89922
#
# Epoch 00006: val_loss did not improve from 0.00654
# 142/142 [==============================] - 169s 1s/step - loss: 0.0113 - auc: 0.9281 - val_loss: 0.0076 - val_auc: 0.8733 - lr: 3.2000e-04
# Epoch 7/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0107 - auc: 0.9405
# Epoch 00007: val_auc improved from 0.89922 to 0.91422, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.00654 to 0.00622, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0107 - auc: 0.9405 - val_loss: 0.0062 - val_auc: 0.9142 - lr: 2.5620e-04
# Epoch 8/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0096 - auc: 0.9543
# Epoch 00008: val_auc did not improve from 0.91422
#
# Epoch 00008: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0096 - auc: 0.9543 - val_loss: 0.0069 - val_auc: 0.8954 - lr: 2.0516e-04
# Epoch 9/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0090 - auc: 0.9622
# Epoch 00009: val_auc improved from 0.91422 to 0.91951, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.00622
# 142/142 [==============================] - 173s 1s/step - loss: 0.0090 - auc: 0.9622 - val_loss: 0.0065 - val_auc: 0.9195 - lr: 1.6433e-04
# Epoch 10/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0083 - auc: 0.9679
# Epoch 00010: val_auc did not improve from 0.91951
#
# Epoch 00010: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0083 - auc: 0.9679 - val_loss: 0.0067 - val_auc: 0.9192 - lr: 1.3166e-04
# Epoch 11/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0075 - auc: 0.9757
# Epoch 00011: val_auc did not improve from 0.91951
#
# Epoch 00011: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0075 - auc: 0.9757 - val_loss: 0.0074 - val_auc: 0.9047 - lr: 1.0553e-04
# Epoch 12/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0071 - auc: 0.9786
# Epoch 00012: val_auc did not improve from 0.91951
#
# Epoch 00012: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0071 - auc: 0.9786 - val_loss: 0.0074 - val_auc: 0.9104 - lr: 8.4624e-05
# Epoch 13/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0066 - auc: 0.9816
# Epoch 00013: val_auc improved from 0.91951 to 0.92239, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-1-bestAUC.h5
#
# Epoch 00013: val_loss did not improve from 0.00622
# 142/142 [==============================] - 173s 1s/step - loss: 0.0066 - auc: 0.9816 - val_loss: 0.0071 - val_auc: 0.9224 - lr: 6.7899e-05
# Epoch 14/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0060 - auc: 0.9855
# Epoch 00014: val_auc did not improve from 0.92239
#
# Epoch 00014: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0060 - auc: 0.9855 - val_loss: 0.0077 - val_auc: 0.8986 - lr: 5.4519e-05
# Epoch 15/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9868
# Epoch 00015: val_auc did not improve from 0.92239
#
# Epoch 00015: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0057 - auc: 0.9868 - val_loss: 0.0080 - val_auc: 0.9040 - lr: 4.3815e-05
# Epoch 16/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0056 - auc: 0.9874
# Epoch 00016: val_auc did not improve from 0.92239
#
# Epoch 00016: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0056 - auc: 0.9874 - val_loss: 0.0078 - val_auc: 0.9114 - lr: 3.5252e-05
# Epoch 17/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0051 - auc: 0.9902
# Epoch 00017: val_auc did not improve from 0.92239
#
# Epoch 00017: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0051 - auc: 0.9902 - val_loss: 0.0080 - val_auc: 0.9065 - lr: 2.8402e-05
# Epoch 18/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0050 - auc: 0.9910
# Epoch 00018: val_auc did not improve from 0.92239
#
# Epoch 00018: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0050 - auc: 0.9910 - val_loss: 0.0082 - val_auc: 0.9032 - lr: 2.2922e-05
# Epoch 19/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0048 - auc: 0.9907
# Epoch 00019: val_auc did not improve from 0.92239
#
# Epoch 00019: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0048 - auc: 0.9907 - val_loss: 0.0083 - val_auc: 0.9026 - lr: 1.8537e-05
# Epoch 20/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0049 - auc: 0.9908
# Epoch 00020: val_auc did not improve from 0.92239
#
# Epoch 00020: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0049 - auc: 0.9908 - val_loss: 0.0082 - val_auc: 0.9047 - lr: 1.5030e-05
# Epoch 21/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0046 - auc: 0.9917
# Epoch 00021: val_auc did not improve from 0.92239
#
# Epoch 00021: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0046 - auc: 0.9917 - val_loss: 0.0084 - val_auc: 0.9044 - lr: 1.2224e-05
# Epoch 22/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0045 - auc: 0.9923
# Epoch 00022: val_auc did not improve from 0.92239
#
# Epoch 00022: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0045 - auc: 0.9923 - val_loss: 0.0084 - val_auc: 0.9062 - lr: 9.9791e-06
# Epoch 23/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0043 - auc: 0.9930
# Epoch 00023: val_auc did not improve from 0.92239
#
# Epoch 00023: val_loss did not improve from 0.00622
# 142/142 [==============================] - 169s 1s/step - loss: 0.0043 - auc: 0.9930 - val_loss: 0.0087 - val_auc: 0.9018 - lr: 8.1832e-06
# Epoch 24/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0045 - auc: 0.9931
# Epoch 00024: val_auc did not improve from 0.92239
#
# Epoch 00024: val_loss did not improve from 0.00622
# 142/142 [==============================] - 168s 1s/step - loss: 0.0045 - auc: 0.9931 - val_loss: 0.0088 - val_auc: 0.9020 - lr: 6.7466e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 281/280 [==============================] - 73s 259ms/step
# Predicting Test with TTA...
# 472/471 [==============================] - 123s 260ms/step
# #### FOLD 2 OOF AUC without TTA = 0.922, with TTA = 0.922
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 3
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0846 - auc: 0.6006WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.66366, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05763, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 206s 1s/step - loss: 0.0846 - auc: 0.6006 - val_loss: 0.0576 - val_auc: 0.6637 - lr: 5.0000e-06
# Epoch 2/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0174 - auc: 0.7733
# Epoch 00002: val_auc improved from 0.66366 to 0.84941, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05763 to 0.00697, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0174 - auc: 0.7733 - val_loss: 0.0070 - val_auc: 0.8494 - lr: 6.8000e-05
# Epoch 3/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0141 - auc: 0.8740
# Epoch 00003: val_auc improved from 0.84941 to 0.89552, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00697 to 0.00636, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0141 - auc: 0.8740 - val_loss: 0.0064 - val_auc: 0.8955 - lr: 1.3100e-04
# Epoch 4/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0129 - auc: 0.9020
# Epoch 00004: val_auc improved from 0.89552 to 0.91960, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00636 to 0.00597, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0129 - auc: 0.9020 - val_loss: 0.0060 - val_auc: 0.9196 - lr: 1.9400e-04
# Epoch 5/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0123 - auc: 0.9101
# Epoch 00005: val_auc improved from 0.91960 to 0.92178, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.00597
# 142/142 [==============================] - 172s 1s/step - loss: 0.0123 - auc: 0.9101 - val_loss: 0.0060 - val_auc: 0.9218 - lr: 2.5700e-04
# Epoch 6/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0115 - auc: 0.9259
# Epoch 00006: val_auc improved from 0.92178 to 0.93663, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00597 to 0.00589, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0115 - auc: 0.9259 - val_loss: 0.0059 - val_auc: 0.9366 - lr: 3.2000e-04
# Epoch 7/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0109 - auc: 0.9360
# Epoch 00007: val_auc improved from 0.93663 to 0.93913, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.00589 to 0.00572, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 179s 1s/step - loss: 0.0109 - auc: 0.9360 - val_loss: 0.0057 - val_auc: 0.9391 - lr: 2.5620e-04
# Epoch 8/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0097 - auc: 0.9519
# Epoch 00008: val_auc did not improve from 0.93913
#
# Epoch 00008: val_loss did not improve from 0.00572
# 142/142 [==============================] - 169s 1s/step - loss: 0.0097 - auc: 0.9519 - val_loss: 0.0064 - val_auc: 0.9180 - lr: 2.0516e-04
# Epoch 9/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0094 - auc: 0.9562
# Epoch 00009: val_auc improved from 0.93913 to 0.94089, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00009: val_loss improved from 0.00572 to 0.00550, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0094 - auc: 0.9562 - val_loss: 0.0055 - val_auc: 0.9409 - lr: 1.6433e-04
# Epoch 10/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0085 - auc: 0.9666
# Epoch 00010: val_auc did not improve from 0.94089
#
# Epoch 00010: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0085 - auc: 0.9666 - val_loss: 0.0066 - val_auc: 0.9277 - lr: 1.3166e-04
# Epoch 11/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0082 - auc: 0.9698
# Epoch 00011: val_auc did not improve from 0.94089
#
# Epoch 00011: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0082 - auc: 0.9698 - val_loss: 0.0060 - val_auc: 0.9333 - lr: 1.0553e-04
# Epoch 12/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0074 - auc: 0.9757
# Epoch 00012: val_auc improved from 0.94089 to 0.94095, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-2-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00550
# 142/142 [==============================] - 174s 1s/step - loss: 0.0074 - auc: 0.9757 - val_loss: 0.0060 - val_auc: 0.9410 - lr: 8.4624e-05
# Epoch 13/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0071 - auc: 0.9788
# Epoch 00013: val_auc did not improve from 0.94095
#
# Epoch 00013: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0071 - auc: 0.9788 - val_loss: 0.0065 - val_auc: 0.9379 - lr: 6.7899e-05
# Epoch 14/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0065 - auc: 0.9821
# Epoch 00014: val_auc did not improve from 0.94095
#
# Epoch 00014: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0065 - auc: 0.9821 - val_loss: 0.0064 - val_auc: 0.9340 - lr: 5.4519e-05
# Epoch 15/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0061 - auc: 0.9846
# Epoch 00015: val_auc did not improve from 0.94095
#
# Epoch 00015: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0061 - auc: 0.9846 - val_loss: 0.0064 - val_auc: 0.9370 - lr: 4.3815e-05
# Epoch 16/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0059 - auc: 0.9850
# Epoch 00016: val_auc did not improve from 0.94095
#
# Epoch 00016: val_loss did not improve from 0.00550
# 142/142 [==============================] - 170s 1s/step - loss: 0.0059 - auc: 0.9850 - val_loss: 0.0064 - val_auc: 0.9348 - lr: 3.5252e-05
# Epoch 17/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9862
# Epoch 00017: val_auc did not improve from 0.94095
#
# Epoch 00017: val_loss did not improve from 0.00550
# 142/142 [==============================] - 170s 1s/step - loss: 0.0057 - auc: 0.9862 - val_loss: 0.0067 - val_auc: 0.9312 - lr: 2.8402e-05
# Epoch 18/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9874
# Epoch 00018: val_auc did not improve from 0.94095
#
# Epoch 00018: val_loss did not improve from 0.00550
# 142/142 [==============================] - 170s 1s/step - loss: 0.0057 - auc: 0.9874 - val_loss: 0.0067 - val_auc: 0.9331 - lr: 2.2922e-05
# Epoch 19/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0055 - auc: 0.9882
# Epoch 00019: val_auc did not improve from 0.94095
#
# Epoch 00019: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0055 - auc: 0.9882 - val_loss: 0.0065 - val_auc: 0.9356 - lr: 1.8537e-05
# Epoch 20/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0050 - auc: 0.9904
# Epoch 00020: val_auc did not improve from 0.94095
#
# Epoch 00020: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0050 - auc: 0.9904 - val_loss: 0.0069 - val_auc: 0.9336 - lr: 1.5030e-05
# Epoch 21/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0052 - auc: 0.9894
# Epoch 00021: val_auc did not improve from 0.94095
#
# Epoch 00021: val_loss did not improve from 0.00550
# 142/142 [==============================] - 170s 1s/step - loss: 0.0052 - auc: 0.9894 - val_loss: 0.0068 - val_auc: 0.9325 - lr: 1.2224e-05
# Epoch 22/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0049 - auc: 0.9917
# Epoch 00022: val_auc did not improve from 0.94095
#
# Epoch 00022: val_loss did not improve from 0.00550
# 142/142 [==============================] - 170s 1s/step - loss: 0.0049 - auc: 0.9917 - val_loss: 0.0070 - val_auc: 0.9329 - lr: 9.9791e-06
# Epoch 23/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0048 - auc: 0.9917
# Epoch 00023: val_auc did not improve from 0.94095
#
# Epoch 00023: val_loss did not improve from 0.00550
# 142/142 [==============================] - 170s 1s/step - loss: 0.0048 - auc: 0.9917 - val_loss: 0.0070 - val_auc: 0.9326 - lr: 8.1832e-06
# Epoch 24/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0051 - auc: 0.9902
# Epoch 00024: val_auc did not improve from 0.94095
#
# Epoch 00024: val_loss did not improve from 0.00550
# 142/142 [==============================] - 169s 1s/step - loss: 0.0051 - auc: 0.9902 - val_loss: 0.0070 - val_auc: 0.9351 - lr: 6.7466e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 282/281 [==============================] - 73s 260ms/step
# Predicting Test with TTA...
# 472/471 [==============================] - 124s 262ms/step
# #### FOLD 3 OOF AUC without TTA = 0.941, with TTA = 0.950
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 4
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0878 - auc: 0.5300WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.56248, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05123, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 207s 1s/step - loss: 0.0878 - auc: 0.5300 - val_loss: 0.0512 - val_auc: 0.5625 - lr: 5.0000e-06
# Epoch 2/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0172 - auc: 0.7712
# Epoch 00002: val_auc improved from 0.56248 to 0.82951, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05123 to 0.00716, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 181s 1s/step - loss: 0.0172 - auc: 0.7712 - val_loss: 0.0072 - val_auc: 0.8295 - lr: 6.8000e-05
# Epoch 3/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0141 - auc: 0.8749
# Epoch 00003: val_auc improved from 0.82951 to 0.87152, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00716 to 0.00673, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 179s 1s/step - loss: 0.0141 - auc: 0.8749 - val_loss: 0.0067 - val_auc: 0.8715 - lr: 1.3100e-04
# Epoch 4/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0127 - auc: 0.9020
# Epoch 00004: val_auc improved from 0.87152 to 0.88174, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00673 to 0.00673, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0127 - auc: 0.9020 - val_loss: 0.0067 - val_auc: 0.8817 - lr: 1.9400e-04
# Epoch 5/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0121 - auc: 0.9170
# Epoch 00005: val_auc improved from 0.88174 to 0.89725, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00005: val_loss improved from 0.00673 to 0.00649, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0121 - auc: 0.9170 - val_loss: 0.0065 - val_auc: 0.8972 - lr: 2.5700e-04
# Epoch 6/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0116 - auc: 0.9275
# Epoch 00006: val_auc improved from 0.89725 to 0.89977, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00649 to 0.00636, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0116 - auc: 0.9275 - val_loss: 0.0064 - val_auc: 0.8998 - lr: 3.2000e-04
# Epoch 7/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0108 - auc: 0.9397
# Epoch 00007: val_auc improved from 0.89977 to 0.91849, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# Epoch 00007: val_loss improved from 0.00636 to 0.00629, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0108 - auc: 0.9397 - val_loss: 0.0063 - val_auc: 0.9185 - lr: 2.5620e-04
# Epoch 8/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0098 - auc: 0.9512
# Epoch 00008: val_auc improved from 0.91849 to 0.92166, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-3-bestAUC.h5
#
# ...
#
# Epoch 00019: val_loss did not improve from 0.00591
# 142/142 [==============================] - 169s 1s/step - loss: 0.0050 - auc: 0.9903 - val_loss: 0.0078 - val_auc: 0.9080 - lr: 1.8537e-05
# Epoch 20/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0051 - auc: 0.9904
# Epoch 00020: val_auc did not improve from 0.93159
#
# Epoch 00020: val_loss did not improve from 0.00591
# 142/142 [==============================] - 169s 1s/step - loss: 0.0051 - auc: 0.9904 - val_loss: 0.0078 - val_auc: 0.9122 - lr: 1.5030e-05
# Epoch 21/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0048 - auc: 0.9913
# Epoch 00021: val_auc did not improve from 0.93159
#
# Epoch 00021: val_loss did not improve from 0.00591
# 142/142 [==============================] - 169s 1s/step - loss: 0.0048 - auc: 0.9913 - val_loss: 0.0077 - val_auc: 0.9085 - lr: 1.2224e-05
# Epoch 22/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0046 - auc: 0.9922
# Epoch 00022: val_auc did not improve from 0.93159
#
# Epoch 00022: val_loss did not improve from 0.00591
# 142/142 [==============================] - 169s 1s/step - loss: 0.0046 - auc: 0.9922 - val_loss: 0.0079 - val_auc: 0.9088 - lr: 9.9791e-06
# Epoch 23/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0045 - auc: 0.9923
# Epoch 00023: val_auc did not improve from 0.93159
#
# Epoch 00023: val_loss did not improve from 0.00591
# 142/142 [==============================] - 169s 1s/step - loss: 0.0045 - auc: 0.9923 - val_loss: 0.0080 - val_auc: 0.9096 - lr: 8.1832e-06
# Epoch 24/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0045 - auc: 0.9925
# Epoch 00024: val_auc did not improve from 0.93159
#
# Epoch 00024: val_loss did not improve from 0.00591
# 142/142 [==============================] - 169s 1s/step - loss: 0.0045 - auc: 0.9925 - val_loss: 0.0081 - val_auc: 0.9083 - lr: 6.7466e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 280/279 [==============================] - 72s 258ms/step
# Predicting Test with TTA...
# 472/471 [==============================] - 123s 260ms/step
# #### FOLD 4 OOF AUC without TTA = 0.932, with TTA = 0.935
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.95.189.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.95.189.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# #########################
# #### FOLD 5
# #### Image Size 384 with EfficientNet B6 and batch_size 256
# #### Using 2018+2017 external data
# #########################
# Training...
# Epoch 1/24
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 142/142 [==============================] - ETA: 0s - loss: 0.0902 - auc: 0.5868WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function sigmoid_focal_crossentropy at 0x7fde8c7671e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Epoch 00001: val_auc improved from -inf to 0.62758, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00001: val_loss improved from inf to 0.05551, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 142/142 [==============================] - 207s 1s/step - loss: 0.0902 - auc: 0.5868 - val_loss: 0.0555 - val_auc: 0.6276 - lr: 5.0000e-06
# Epoch 2/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0171 - auc: 0.7778
# Epoch 00002: val_auc improved from 0.62758 to 0.81442, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00002: val_loss improved from 0.05551 to 0.00722, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0171 - auc: 0.7778 - val_loss: 0.0072 - val_auc: 0.8144 - lr: 6.8000e-05
# Epoch 3/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0141 - auc: 0.8744
# Epoch 00003: val_auc improved from 0.81442 to 0.85960, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00003: val_loss improved from 0.00722 to 0.00682, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0141 - auc: 0.8744 - val_loss: 0.0068 - val_auc: 0.8596 - lr: 1.3100e-04
# Epoch 4/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0128 - auc: 0.9005
# Epoch 00004: val_auc improved from 0.85960 to 0.88643, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00004: val_loss improved from 0.00682 to 0.00643, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0128 - auc: 0.9005 - val_loss: 0.0064 - val_auc: 0.8864 - lr: 1.9400e-04
# Epoch 5/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0121 - auc: 0.9153
# Epoch 00005: val_auc improved from 0.88643 to 0.89981, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00005: val_loss did not improve from 0.00643
# 142/142 [==============================] - 173s 1s/step - loss: 0.0121 - auc: 0.9153 - val_loss: 0.0064 - val_auc: 0.8998 - lr: 2.5700e-04
# Epoch 6/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0115 - auc: 0.9265
# Epoch 00006: val_auc improved from 0.89981 to 0.90080, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00006: val_loss improved from 0.00643 to 0.00607, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 142/142 [==============================] - 177s 1s/step - loss: 0.0115 - auc: 0.9265 - val_loss: 0.0061 - val_auc: 0.9008 - lr: 3.2000e-04
# Epoch 7/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0108 - auc: 0.9388
# Epoch 00007: val_auc did not improve from 0.90080
#
# Epoch 00007: val_loss did not improve from 0.00607
# 142/142 [==============================] - 169s 1s/step - loss: 0.0108 - auc: 0.9388 - val_loss: 0.0062 - val_auc: 0.8931 - lr: 2.5620e-04
# Epoch 8/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0099 - auc: 0.9519
# Epoch 00008: val_auc improved from 0.90080 to 0.90494, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00008: val_loss improved from 0.00607 to 0.00600, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestloss.h5
# 142/142 [==============================] - 178s 1s/step - loss: 0.0099 - auc: 0.9519 - val_loss: 0.0060 - val_auc: 0.9049 - lr: 2.0516e-04
# Epoch 9/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0092 - auc: 0.9606
# Epoch 00009: val_auc improved from 0.90494 to 0.90995, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00009: val_loss did not improve from 0.00600
# 142/142 [==============================] - 173s 1s/step - loss: 0.0092 - auc: 0.9606 - val_loss: 0.0063 - val_auc: 0.9099 - lr: 1.6433e-04
# Epoch 10/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0086 - auc: 0.9653
# Epoch 00010: val_auc did not improve from 0.90995
#
# Epoch 00010: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0086 - auc: 0.9653 - val_loss: 0.0061 - val_auc: 0.9034 - lr: 1.3166e-04
# Epoch 11/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0079 - auc: 0.9722
# Epoch 00011: val_auc did not improve from 0.90995
#
# Epoch 00011: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0079 - auc: 0.9722 - val_loss: 0.0064 - val_auc: 0.9069 - lr: 1.0553e-04
# Epoch 12/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0072 - auc: 0.9778
# Epoch 00012: val_auc improved from 0.90995 to 0.91014, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00012: val_loss did not improve from 0.00600
# 142/142 [==============================] - 174s 1s/step - loss: 0.0072 - auc: 0.9778 - val_loss: 0.0063 - val_auc: 0.9101 - lr: 8.4624e-05
# Epoch 13/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0069 - auc: 0.9794
# Epoch 00013: val_auc improved from 0.91014 to 0.91140, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00013: val_loss did not improve from 0.00600
# 142/142 [==============================] - 173s 1s/step - loss: 0.0069 - auc: 0.9794 - val_loss: 0.0063 - val_auc: 0.9114 - lr: 6.7899e-05
# Epoch 14/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0064 - auc: 0.9830
# Epoch 00014: val_auc improved from 0.91140 to 0.91225, saving model to 384-EffNetB6-BS32-EPOCHS24-TTA-INC2018-FOCAL/fold-4-bestAUC.h5
#
# Epoch 00014: val_loss did not improve from 0.00600
# 142/142 [==============================] - 174s 1s/step - loss: 0.0064 - auc: 0.9830 - val_loss: 0.0062 - val_auc: 0.9123 - lr: 5.4519e-05
# Epoch 15/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0062 - auc: 0.9842
# Epoch 00015: val_auc did not improve from 0.91225
#
# Epoch 00015: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0062 - auc: 0.9842 - val_loss: 0.0066 - val_auc: 0.9071 - lr: 4.3815e-05
# Epoch 16/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0057 - auc: 0.9871
# Epoch 00016: val_auc did not improve from 0.91225
#
# Epoch 00016: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0057 - auc: 0.9871 - val_loss: 0.0067 - val_auc: 0.9094 - lr: 3.5252e-05
# Epoch 17/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0055 - auc: 0.9881
# Epoch 00017: val_auc did not improve from 0.91225
#
# Epoch 00017: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0055 - auc: 0.9881 - val_loss: 0.0069 - val_auc: 0.9068 - lr: 2.8402e-05
# Epoch 18/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0052 - auc: 0.9891
# Epoch 00018: val_auc did not improve from 0.91225
#
# Epoch 00018: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0052 - auc: 0.9891 - val_loss: 0.0069 - val_auc: 0.9068 - lr: 2.2922e-05
# Epoch 19/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0052 - auc: 0.9898
# Epoch 00019: val_auc did not improve from 0.91225
#
# Epoch 00019: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0052 - auc: 0.9898 - val_loss: 0.0071 - val_auc: 0.9057 - lr: 1.8537e-05
# Epoch 20/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0051 - auc: 0.9898
# Epoch 00020: val_auc did not improve from 0.91225
#
# Epoch 00020: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0051 - auc: 0.9898 - val_loss: 0.0072 - val_auc: 0.9068 - lr: 1.5030e-05
# Epoch 21/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0048 - auc: 0.9911
# Epoch 00021: val_auc did not improve from 0.91225
#
# Epoch 00021: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0048 - auc: 0.9911 - val_loss: 0.0072 - val_auc: 0.9065 - lr: 1.2224e-05
# Epoch 22/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0048 - auc: 0.9912
# Epoch 00022: val_auc did not improve from 0.91225
#
# Epoch 00022: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0048 - auc: 0.9912 - val_loss: 0.0073 - val_auc: 0.9040 - lr: 9.9791e-06
# Epoch 23/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0048 - auc: 0.9910
# Epoch 00023: val_auc did not improve from 0.91225
#
# Epoch 00023: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0048 - auc: 0.9910 - val_loss: 0.0072 - val_auc: 0.9055 - lr: 8.1832e-06
# Epoch 24/24
# 142/142 [==============================] - ETA: 0s - loss: 0.0046 - auc: 0.9919
# Epoch 00024: val_auc did not improve from 0.91225
#
# Epoch 00024: val_loss did not improve from 0.00600
# 142/142 [==============================] - 169s 1s/step - loss: 0.0046 - auc: 0.9919 - val_loss: 0.0074 - val_auc: 0.9048 - lr: 6.7466e-06
# Loading best model val loss...
# Predicting OOF with TTA...
# 282/281 [==============================] - 74s 262ms/step
# Predicting Test with TTA...
# 472/471 [==============================] - 124s 262ms/step
# #### FOLD 5 OOF AUC without TTA = 0.912, with TTA = 0.912

# %%
preds_by_fold
# Out:
# array([[0.01316648, 0.01362924, 0.01466012, 0.01729303, 0.01220743],
#        [0.01843293, 0.03537856, 0.0402361 , 0.03069603, 0.01927132],
#        [0.01230867, 0.01607432, 0.03301413, 0.0126435 , 0.03271807],
#        ...,
#        [0.04970971, 0.03941309, 0.02140792, 0.02879437, 0.05667988],
#        [0.07777616, 0.04417971, 0.0700378 , 0.09754557, 0.11539655],
#        [0.02450245, 0.0355408 , 0.02807517, 0.01598759, 0.00926896]])

# %% [markdown]
# ## Calculate OOF AUC
# The OOF (out of fold) predictions are saved to disk. If you wish to ensemble multiple models, use the OOF to determine what are the best weights to blend your models with. Choose weights that maximize OOF CV score when used to blend OOF. Then use those same weights to blend your test predictions.

# %%
# COMPUTE OVERALL OOF AUC
oof = np.concatenate(oof_pred); 
true = np.concatenate(oof_tar);
names = np.concatenate(oof_names); folds = np.concatenate(oof_folds)
auc = roc_auc_score(true,oof)
print('Overall OOF AUC with TTA = %.3f'%auc)

# SAVE OOF TO DISK
df_oof = pd.DataFrame(dict(
    image_name = names, target=true, pred = oof, fold=folds))
df_oof.to_csv(f'{MODEL}/oof.csv',index=False)
df_oof.head()
# Out:
# Overall OOF AUC with TTA = 0.929
#      image_name  target      pred  fold
# 0  ISIC_2637011       0  0.033791     0
# 1  ISIC_0076262       0  0.024794     0
# 2  ISIC_0074268       0  0.004210     0
# 3  ISIC_0015719       0  0.008218     0
# 4  ISIC_0082543       0  0.024168     0

# %%
auc_oof = 0.0
for i in range(FOLDS):
  auc_oof += roc_auc_score(oof_tar[i], oof_pred[i]) / FOLDS
print('Average OOF AUC with TTA = %.3f'%auc_oof)
# Out:
# Average OOF AUC with TTA = 0.930

# %% [markdown]
# # Step 5: Post process
# There are ways to modify predictions based on patient information to increase CV LB. You can experiment with that here on your OOF.
#
# Aqui, hauriem de posar les features amb XGB, CB, o el que sigui
# OptimizeAUC() del llibre de l'Abishek per trobar els pesos de diferents models per a cada fold
#
# I fer servir el OptimizeAUC per veure els pesos de la metadata

# %% [markdown]
# # Submit To Kaggle

# %%
ds = get_dataset(files_test, augment=False, repeat=False, dim=IMG_SIZES[fold],
                 labeled=False, return_image_names=True)

image_names = np.array([img_name.numpy().decode("utf-8") 
                        for img, img_name in iter(ds.unbatch())])

# %%
submission = pd.DataFrame(dict(image_name=image_names, target=preds[:,0]))
submission = submission.sort_values('image_name') 
submission.to_csv(f'{MODEL}/submission.csv', index=False)
submission.head()
# Out:
#         image_name    target
# 9905  ISIC_0052060  0.033372
# 1443  ISIC_0052349  0.023386
# 3120  ISIC_0058510  0.015989
# 4870  ISIC_0073313  0.018314
# 5494  ISIC_0073502  0.065248

# %%
plt.hist(submission.target,bins=100)
plt.show()

# %%
out_preds_by_fold = np.append(np.vstack(image_names), preds_by_fold, 1)
submission_by_fold = pd.DataFrame(out_preds_by_fold)

# #submission = submission.sort_values('image_name') 
submission_by_fold.to_csv(f'{MODEL}/preds_by_fold.csv', index=False)
submission_by_fold.head()
# submission.shape
# Out:
#               0  ...                     5
# 0  ISIC_2272503  ...   0.01220743265002966
# 1  ISIC_9821912  ...   0.01927131973206997
# 2  ISIC_4347483  ...  0.032718073576688766
# 3  ISIC_6645719  ...  0.050811007618904114
# 4  ISIC_0456797  ...  0.006155507173389196
#
# [5 rows x 6 columns]

# %%
preds_by_fold.shape
# Out:
# (10982, 5)

# %%
from scipy.stats import rankdata

ranked_submission = pd.DataFrame(dict(image_name=image_names, target=0))

ranked_submission['target'] = 0
for i in range(FOLDS):
    ranked_submission['target'] += rankdata(preds_by_fold[:,i]) / (FOLDS)

ranked_submission = ranked_submission.sort_values('image_name')

# %%
ranked_submission.head(100)
# Out:
#         image_name   target
# 9905  ISIC_0052060   3809.0
# 1443  ISIC_0052349   2655.6
# 3120  ISIC_0058510   1531.8
# 4870  ISIC_0073313   1922.0
# 5494  ISIC_0073502   6323.6
# ...            ...      ...
# 1215  ISIC_0200120  10699.6
# 7001  ISIC_0204399   1178.4
# 9720  ISIC_0204875   2876.4
# 4634  ISIC_0205627   2218.0
# 8235  ISIC_0206261   4731.2
#
# [100 rows x 2 columns]

# %%
ranked_submission['target'].mean()
# Out:
# 5491.500000000024

# %%
ranked_submission.to_csv(f'{MODEL}/submission_ranked.csv', index=False)

plt.hist(ranked_submission.target,bins=100)
plt.show()

# %%
import os
src = f'/content/{MODEL}'
dest = f'"/content/gdrive/My Drive/saved_models/{MODEL}"'
os.system(f"rm -rf {dest}")
os.system(f"cp -rf {src} {dest}")
print (src)
print(dest)

# %%
import re
import json
import requests
import ipykernel
from notebook.notebookapp import list_running_servers
from requests.compat import urljoin

def get_notebook_name():
    """
    Return the full path of the jupyter notebook.
    """
    kernel_id = re.search('kernel-(.*).json', ipykernel.connect.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in response.json():
            if nn['kernel']['id'] == kernel_id:
                notebook_name = nn['notebook']['name']
                return notebook_name

NOTEBOOK_NAME = get_notebook_name()
copyNotebook = f'cp "/content/gdrive/My Drive/Colab Notebooks/{NOTEBOOK_NAME}" "/content/gdrive/My Drive/saved_models/{MODEL}/train.ipynb"'
os.system(copyNotebook)

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission.csv -m "{MODEL}"

# %%
# !kaggle competitions submit -c siim-isic-melanoma-classification -f {MODEL}/submission_ranked.csv -m "{MODEL}-Ranked"
